# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from bs4 import BeautifulSoup
import requests

# %%
header = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) '\
           'AppleWebKit/537.36 (KHTML, like Gecko) '\
           'Chrome/75.0.3770.80 Safari/537.36'}
resp = requests.get("https://www.bestbuy.com/site/playstation-5/ps5-games/pcmcat1587395108347.c?id=pcmcat1587395108347", headers = header)
resp
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(resp.text, 'html5lib')
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head>
# 				<!-- platview-njs: version=20.43.4 | blueprint: id=plp-holiday-browse-l -->
#
# <!-- start simple component shop-plp-seo-metadata-1f8383c1-69f8-4a4c-826e-5b72dafe32f4 - shop-plp-seo-metadata v1 -->
#
# 			<title>PS5 Games: Video Games for PlayStation 5 - Best Buy</title>
# 			<meta content="IE=Edge,chrome=1" http-equiv="X-UA-Compatible"/><meta content="telephone=no" name="format-detection"/><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="no-cache" http-equiv="pragma"/><meta content="no-cache" http-equiv="cache-control"/><meta content="-1" http-equiv="expires"/><meta content="width=1024" name="viewport"/><meta content="Shop online for PS5 Games at BestBuy.com. Choose from a huge selection of the most popular video games for the PlayStation 5 console at Best Buy." name="description"/><meta content="ps5 games, playstation 5 games, playstation video games, ps5 video games" name="keywords"/><meta content='{"query":"pcmcat1587395108347","queryType":"browse"}' name="opt-targeting"/>
# 			<link href="//www.bestbuy.com/favicon.ico" rel="icon" type="image/x-icon"/><link href="https://www.bestbuy.com/site/playstation-5/ps5-games/pcmcat1587395108347.c?id=pcmcat1587395108347" rel="canonical"/><link href="https://www.bestbuy.com/site/searchpage.jsp?_dyncharset=UTF-8&amp;browsedCategory=pcmcat1587395108347&amp;cp=2&amp;id=pcat17071&amp;iht=n&amp;ks=960&amp;list=y&amp;sc=Global&amp;st=categoryid%24pcmcat1587395108347&amp;type=page&amp;usc=All%20Categories" rel="next"/>
# 			<script type="application/ld+json">{"@context":"http://schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"item":{"@id":"https://www.bestbuy.com/","name":"Best Buy"}},{"@type":"ListItem","position":2,"item":{"@id":"https://www.bestbuy.com/site/electronics/video-games/abcat0700000.c?id=abcat0700000","name":"Video Games"}},{"@type":"ListItem","position":3,"item":{"@id":"https://www.bestbuy.com/site/video-games/playstation-5/pcmcat1572034351415.c?id=pcmcat1572034351415","name":"PlayStation 5"}}]}</script><script type="text/javascript">(function () {
#   window.plpData = {
#     data: {},
#     listenerList: [],
#     listen: function listen(cb) {
#       cb(this.data);
#       this.listenerList.push(cb);
#     },
#     setData: function setData(data) {
#       var _this = this;
#
#       this.data = data;
#       this.listenerList.forEach(function (cb) {
#         cb(_this.data);
#       });
#     },
#     unlisten: function unlisten(cb) {
#       var index = this.listenerList.indexOf(cb);
#       this.listenerList.splice(index, 1);
#     }
#   };
# })();</script>
#
# 		<!-- end simple component shop-plp-seo-metadata-1f8383c1-69f8-4a4c-826e-5b72dafe32f4 - shop-plp-seo-metadata v1 --><!-- start simple component shop-global-metadata-4034590c-e602-4660-8853-0abdf29f2cbd - shop-global-metadata v1 --><link href="https://pisces.bbystatic.com/image2/BestBuy_US/Gallery/favicon-32-72227.png" rel="icon" sizes="32x32"/>
# <meta content="BestBuy.com" name="application-name"/>
# <meta content="BestBuy - Let's talk about what's possible." name="msapplication-tooltip"/>
# <meta content="/~assets/bby/_com/shop/global-metadata/dist/client/IEconfig.xml" name="msapplication-config"/>
# <link href="https://pisces.bbystatic.com/image2/BestBuy_US/Gallery/Favicon-152-72229.png" rel="apple-touch-icon-precomposed"/><!-- end simple component shop-global-metadata-4034590c-e602-4660-8853-0abdf29f2cbd - shop-global-metadata v1 --><!-- start simple component shop-optimizely-36288a8a-7a75-4ce6-8756-e883acb8820d - shop-optimizely v1 --><script src="/~assets/bby/_js/ext/optmzly/8143030612.js"></script><!-- end simple component shop-optimizely-36288a8a-7a75-4ce6-8756-e883acb8820d - shop-optimizely v1 -->
#
#
# 		<script>
# 			document.domain = 'bestbuy.com';
#
# 			if (typeof window.rdpClass === 'undefined') {
# 				window.rdpClass = {};
# 			}
#
# 			window.rdpClass.deviceClass = 'l';
#
# 			if (typeof window._metaLayer === 'undefined') {
# 				window._metaLayer = {};
# 			}
#
# 			window._metaLayer.device_deviceClass = 'l';
# 			window._metaLayer.user_rzTier = "None";
# 			window._metaLayer.env_falcor = '/api/tcfb';
# 			window._metaLayer.env_assets = "\u002F~assets\u002Fbby\u002F_com";
# 			window._metaLayer.env_piscesUrl = "https:\u002F\u002Fpisces.bbystatic.com";
# 			window._metaLayer.env_pisces = "https:\u002F\u002Fpisces.bbystatic.com";
# 		</script>
# 		<script src="https://nexus.ensighten.com/bestbuy/privacy_init/Bootstrap.js"></script>
# 		<script src="https://www.bestbuy.com/~assets/bby/_js/ext/bbydyn/dyn_digital_gvp.js"></script>
# 		<link href="/~assets/bby/_com/sc-pattern-library/4.1.4/dist/css/pattern-library.min.css" media="all" rel="stylesheet"/>
# 		<script>
# 						function _setUpConfigService () {
# 							window.configService = getConfigService({"abt1501evar":"abTest68","allowDealsContext":"[pcmcat1563299784494, pcmcat225600050002, pcmcat309500050010]","priceViewOfferProductPriceGlobal":true,"AutoCompare_enableRecommendations":true,"CompareAddStructureEnabled":true,"HF_enableDynamicStoreLocator":true,"HF_enableNotificationManager":true,"HF_logoImageHash":"968d1f5f01d288d23e3b2c71de31967a","HF_notificationsHideWaitTimeMS":3000,"HF_shoppingHistoryToastEnabled":false,"HF_shoppingHistoryToastVersion":"V1","PLPFacetRedirectDelay":1,"TestLiveConfig":"Works","attachSuggestPageTypes":"browse,pdp","basketAddProbability":1,"beagleApiPath":"/wireless","blueAssistEnabled":true,"bonusContentFlag":true,"clickToCallClientKey":"n9fzQiKTTx7cBIT1FiRj8x0B3lqX/kMFgbwW8uRRuqc=","clickToCallGetEndpoint":"https://bbytagservices.bestbuy.com/Generic/BBYClickToCallServiceREST/api/click2Call","clickToCallPostEndpoint":"https://bbytagservices.bestbuy.com/Generic/BBYClickToCallServiceREST/api/click2Call","compareDisabled":false,"coralAssetId":"522e93e4-a28b-498d-b1cb-8fd0f6d468f7","components":"[shop:[attach-modal:[useAttachSuggest:true], complete-your-purchase:[singleSelectDCS:[[department:4, class:205]]], office-365:[useNew365Render:true], solution-banner:[enableSolutionAssemblerLinks:true], solution-button:[enableSolutionAssemblerLinks:true]]]","custTimeline_accountFingerprint":"0.2.0","custTimeline_compareWhitelist":"[]","custTimeline_enableExperience":"[]","custTimeline_enableInGlobalNav":true,"custTimeline_enableListener":false,"custTimeline_experienceFingerprint":"3.0.16","custTimeline_headerExperienceFingerprint":"2.1.11","custTimeline_headerStatusFingerprint":"2.0.17","custTimeline_initialForcedCollapsed":false,"custTimeline_listenerFingerprint":"1.10.9","custTimeline_loaderFingerprint":"1.0.648","custTimeline_shoppingHistoryWhitelist":"[browse,home]","custTimeline_showRecommendationsInShoppingHistory":true,"custTimeline_useIndividualDataTopics":true,"disableAddToCartStips":true,"disableBuyingOptionsStips":true,"disableCmmStips":true,"disableCompareStips":true,"disableConditionalOptionsStips":true,"disableDynamicPricingCalls":true,"disableEnlargeImageStips":true,"disableFridayInStoreOnlyStips":true,"disableHolidayIspuDateStips":true,"disableHolidayLsaStips":true,"disableHolidayVddcStips":true,"disableIspuAvailabilityStips":true,"disablePLPCheckMarkMessagingAndDescription":true,"disablePriceStips":true,"disableRewardsStips":true,"disableSaturdayInStoreOnlyStips":true,"disableShelfRequests":false,"disableShippingPuckStips":true,"disableTextWidgetStips":true,"dynamicPricingProbability":1,"dynamicPricingRender":true,"enableAbCys":false,"enableBrandImage":false,"enableClickToCall":true,"enableCys":true,"enableDynamicGWP":true,"enableEcoRebates":true,"enableEmailSubmissionModal":true,"enableEndOfLifeInventory":true,"enableEnsighten":true,"enableFulfillmentCompare":true,"enableFulfillmentPLP":true,"enableGeoVars":true,"enableGetLocationCache":true,"enableGuidedBuyingPlpIntegration":true,"enableGvpCyp":true,"enableImageFixStips":true,"enableInStoreOnlyButton":false,"enableInkSubscription":true,"enableIspuPLP":true,"enableLegacyAvailability":false,"enableLocationProfileApi":true,"enableLocationProfileApiRead":true,"enableMobileStoreSet":true,"enableMoveAddToCartButton":true,"enableNewAddToCartButtonPDP":true,"enableNewAddToCartButtonPLP":true,"enableNewButtonStateForHydrateSku":true,"enableNotifyInStockV2":true,"enableNotifyMe":true,"enablePDPCompareTray":true,"enablePhoenixInTheCloudPLP":true,"enablePhoenixPDP":true,"enablePmgStips":false,"enableSaveForLater":true,"enableSearchSurveyPLP":true,"enableShelfDisplayV2":true,"enableShoppingAssistant":true,"enableSmallViewChat":true,"enableSolutionAssemblerLinks":true,"enableStoreFacetStips":true,"enableStorePickupFacet":true,"enableStorePickupFacetCount":true,"enableSubscribeSave":true,"enable_store_finder_redesign":"on","enhancedShippingEnabled":true,"felEnabled":false,"flex_unifiedPriceBlockEnabled":t ...
# 						}
#
# 						function _setUpEventManager () {
# 							var EventManager = window.EventManager.default;
# 			window.EventManager = EventManager;
# 						}
# 					</script><script src="/~assets/bby/_com/gvp-optimized-dfe2518bba2052d009ec74dd21d53ff1.min.js"></script>
#
# 			</head>
# 			<body class="size-l">
# 				<script>
# 					analyticsQ.dispatch({"type":"TRACK_DATA","deviceClass":"l","pageType":"browse,list,category","templateName":"BRCL","blueprintName":"plp-holiday-browse-l"});
# 					window._do_not_use_me = {"pageType":"browse,list,category"};
# 				</script>
#
#
# <div class="None" data-version="1.0.77" id="shop-master-ad-cb9267cd-75a3-4249-be90-d8648e6b4bda">
# 			<link href="https://assets.bbystatic.com/shop/master-ad/dist/client/client-7d407b525504828efaada300ca0d343a.css" rel="stylesheet"/>
# 			<div class="shop-master-ad"></div>
# 			<script>
# 			if ('noModule' in HTMLScriptElement.prototype) {
# 				(function(document){
#
# 						var scriptEl = document.createElement('script');
# 						scriptEl.src = 'https://assets.bbystatic.com/shop/master-ad/dist/client/client-d12fb053a08d59775f6a81881bf59cb2.mjs';
# 						scriptEl.type = 'module';
# 						scriptEl.async = false;
# 						document.getElementById('shop-master-ad-cb9267cd-75a3-4249-be90-d8648e6b4bda').appendChild(scriptEl);
#
# 				})(document);
# 			} else {
# 				(function(document){
#
# 						var scriptEl = document.createElement('script');
# 						scriptEl.src = 'https://assets.bbystatic.com/shop/master-ad/dist/client/client-78f6a1ebb9911c1a3e418fbfafe07c1e.js';
# 						scriptEl.noModule = true;
# 						scriptEl.defer = true;
# 						scriptEl.async = false;
# 						document.getElementById('shop-master-ad-cb9267cd-75a3-4249-be90-d8648e6b4bda').appendChild(scriptEl);
#
# 				})(document);
# 			}
# 		</script>
# 			<script>
# 			initializer.initializeComponent({"creatorNamespace":"shop","componentId":"master-ad","contractVersion":"v1","componentVersion":"1.0.77"}, 'shop-master-ad-cb9267cd-75a3-4249-be90-d8648e6b4bda', "{\"app\":{\"instanceId\":\"shop-master-ad-cb9267cd-75a3-4249-be90-d8648e6b4bda\",\"pageType\":\"PLP\",\"query\":\"pcmcat1587395108347\",\"skuListString\":\"6255151%7C6427993%7C6430146%7C6430159%7C6432588%7C6407594%7C6430152%7C6415352%7C6426004%7C6420086%7C6430149%7C6442231%7C6414016%7C6442144%7C6433147%7C6426009%7C6413929%7C6414078%7C6439253%7C6435019\",\"skuListArray\":[\"6255151\",\"6427993\",\"6430146\",\"6430159\",\"6432588\",\"6407594\",\"6430152\",\"6415352\",\"6426004\",\"6420086\",\"6430149\",\"6442231\",\"6414016\",\"6442144\",\"6433147\",\"6426009\",\"6413929\",\"6414078\",\"6439253\",\"6435019\"],\"skuListSize\":20,\"pageNumber\":1,\"categoryId\":\"pcmcat1587395108347\",\"breadCrumb\":{\"adsenseUberCatName\":\"Video Games\",\"adsenseParentCatName\":\"PlayStation 5\",\"adsenseCatName\":\"PS5 Games\",\"segmented\":[\"BestBuyDesktopWeb\",\"video_games\",\"playstation_5\",\"ps5_games\"],\"criteoCategory\":\"Video Games\\u003EPlayStation 5\\u003EPS5 Games\",\"slotName\":\"\\u002F6011\\u002FBestBuyDesktopWeb\\u002Fvideo_games\\u002Fplaystation_5\\u002Fps5_games\"},\"dedicatedCarouselEnvironment\":\"d\",\"dedicatedCarouselPageId\":\"viewCategory_API_desktop\",\"passed\":true,\"enableOnetag\":true,\"enableIAS\":true,\"IASCallTimeout\":5000,\"IASpubid\":931017,\"enableDedicatedSponsoredCarousel\":true,\"displayAdDelay\":500,\"maskingApiUrl\":\"https:\\u002F\\u002Fbby.us\\u002Fmask\\u002Fparty\\u002F\",\"displayAdLazyLoadEnabled\":false,\"deviceClass\":\"l\"},\"metaLayer\":{\"env_assets\":\"https:\\u002F\\u002Fassets.bbystatic.com\",\"env_piscesUrl\":\"https:\\u002F\\u002Fpisces.bbystatic.com\",\"env_appServer\":\"https:\\u002F\\u002Fwww.bestbuy.com\"}}", 'en-US');
# 		</script>
# 		</div><div class="None" data-version="3.6.14" id="shop-header-8919cfdd-6d7e-4b7d-9088-6310979fbb32">
# 			<link href="/~assets/bby/_com/shop/header/dist/client/client-d71f162684dd124fb1b356c74b6c4eaa.css" rel="stylesheet"/>
# 			<div class="shop-header"><div data-reactroot="" id="large-header"><header id="header-block"><a class="skip" href="#headerskip" title="Skip to content">Skip to content</a><button class="btn-default-link a11y-survey-link-sv" type="button">Accessibility Survey</button><div data-business-name="" data-first-name="" data-gamers-club-unlocked="" data-has-total-tech-support="" data-is-authenticated="" data-tier="" id="hf_accountMenuLink"><span class="hide_elem" id="isAuthenticated"><span>false</span></span><span class="hide_elem" id="firstName"></span><span class="hide_elem" id="businessName"><span> </span></span><span class="hide_elem" id="hasTotalTechSupport"><span>false</span></span><span class="hide_elem" id="tierCode"><span>None</span></span><span class="hide_elem" id="gamersClubUnlocked"><span>false</span></span></div><div class="header-large"><div class="top-navigation-section"><div class="top-navigation-container"><div class="bby-logo-lv"><a class="" data-lid="hdr_lgo" data-t="header-primary-logo" href="https://www.bestbuy.com" title="BestBuy.com"><img alt="BestBuy.com Logo" class="logo" src="https://pisces.bbystatic.com/image2/BestBuy_US/Gallery/BestBuy_Logo_2020-190616.png"/></a></div><div class="right-container"><nav aria-label="Deals and Gifts" class="top-nav-items"><ul><li><a class="link" data-lid="hdr_crd" href="/site/misc/financing-rewards/pcmcat102500050032.c?id=pcmcat102500050032">Credit Cards</a></li><li><a class="link" data-lid="hdr_td_topdeals" href="/site/electronics/top-deals/pcmcat1563299784494.c?id=pcmcat1563299784494">Top Deals</a></li><li><a class="link" data-lid="hdr_dotd" href="/site/misc/deal-of-the-day/pcmcat248000050016.c?id=pcmcat248000050016">Deal of the Day</a></li><li><a class="link" data-lid="hdr_gft_crd" href="/site/electronics/gift-cards/cat09000.c?id=cat09000">Gift Cards</a></li><li><a class="link" data-lid="hdr_health" href="/site/health-fitness-sports/health-wellness/pcmcat1603917798858.c?id=pcmcat1603917798858">Health &amp; Wellness</a></li><li><a class="link" data-lid="hdr_bbfb" href="/site/electronics/bestbuy-business/pcmcat230900050001.c?id=pcmcat230900050001">For Your Business</a></li><li><a class="link" data-lid="hdr_jude" href="/site/misc/st-jude-childrens-research-hospital/pcmcat315700050022.c?id=pcmcat315700050022">Donate to St. Jude</a></li></ul></nav><div class="middle-container"><div class="search-bar-container"><div class="shop-search-bar"><div class="appContainer lv"><form action="https://www.bestbuy.com/site/searchpage.jsp" class="search-bar input-field" method="GET" name="frmSearch"><input aria-label="Type to search. Navigate forward to hear suggestions" autocomplete="off" class="search-input" id="gh-search-input" maxlength="90" name="st" placeholder="Search Best Buy" type="text" value=""/><button aria-label="Clear search bar text" class="clear-search-icon hidden" id="header-clear-search-icon"><span aria-hidden="true" class="header-close-icon"><svg fill="#0046be" height="20" viewBox="0 0 100 100" width="20"><use href="/~assets/bby/_img/int/plsvgdef-frontend/svg/Close_Cancel_Line.svg#Close_Cancel_Line" xlink:href="/~assets/bby/_img/int/plsvgdef-frontend/svg/Close_Cancel_Line.svg#Close_Cancel_Line"></use></svg></span></button><button aria-label="submit search" class="header-search-button" title="submit search" type="submit"><span aria-hidden="true" class="header-search-icon"><svg fill="#0046be" height="22" viewBox="0 0 100 100" width="22"><use href="/~assets/bby/_img/int/plsvgdef-frontend/svg/Search_Line_Sm.svg#Search_Line_Sm" xlink:href="/~assets/bby/_img/int/plsvgdef-frontend/svg/Search_Line_Sm.svg#Search_Line_Sm"></use></svg></span></button><input name="_dyncharset" type="hidden" value="UTF-8"/><input id="search-session-id" name="_dynSessConf" type="hidden" value=""/><input name="id" type="hidden" value="pcat17071"/><input name="type" type="hidden" value="page"/><input name="sc" type="hidden" value="Global"/><input name="cp" type="hidden" value="1"/><input name="nrp" type="h ...
# 			<link href="/~assets/bby/_com/shop/location-tooltip/dist/client/client-7cf0cb4495495c7f6ccf5493d86ca1d5.css" rel="stylesheet"/>
# 			<div class="shop-location-tooltip"><div class="" id="lt-container"><div class="appContainer"><div class="location-tooltip-lv" data-cy="location-tooltip-default-lv"><a aria-disabled="false" class="btn-unstyled store-loc-btn" data-lid="hdr_stl" href="/site/store-locator" role="button" tabindex="0"><span class="gvpHeadicon storeLocIcon flyBtn"><svg aria-hidden="true" fill="#fff" height="31" role="img" viewBox="0 0 100 100" width="30"><use href="/~assets/bby/_img/int/plsvgdef-frontend/svg/Store_Line_Sm.svg#Store_Line_Sm" xlink:href="/~assets/bby/_img/int/plsvgdef-frontend/svg/Store_Line_Sm.svg#Store_Line_Sm"></use></svg></span><div class="store-display-name" data-cy="location-tooltip-default-title">Store Locator</div></a></div></div></div></div>
# 			<script>
# 			if ('noModule' in HTMLScriptElement.prototype) {
# 				(function(document){
#
# 						var scriptEl = document.createElement('script');
# 						scriptEl.src = '/~assets/bby/_com/shop/location-tooltip/dist/client/client-e05026f96f52ecbdd098b2f602adb2a1.mjs';
# 						scriptEl.type = 'module';
# 						if (window.navigator.userAgent.indexOf("Edge") === -1) {
# 							scriptEl.async = false;
# 						}
# 						document.getElementById('shop-location-tooltip-74a54585-a602-4c06-b03e-e097cfacf95c').appendChild(scriptEl);
#
# 				})(document);
# 			} else {
# 				(function(document){
#
# 						var scriptEl = document.createElement('script');
# 						scriptEl.src = '/~assets/bby/_com/shop/location-tooltip/dist/client/client-d0ab41ad357cf2752cd42ec24c5ec9bf.js';
# 						scriptEl.noModule = true;
# 						scriptEl.defer = true;
# 						if (window.navigator.userAgent.indexOf("Edge") === -1) {
# 							scriptEl.async = false;
# 						}
# 						document.getElementById('shop-location-tooltip-74a54585-a602-4c06-b03e-e097cfacf95c').appendChild(scriptEl);
#
# 				})(document);
# 			}
# 		</script>
# 			<script>
# 			initializer.initializeComponent({"creatorNamespace":"shop","componentId":"location-tooltip","contractVersion":"v1","componentVersion":"1.0.12"}, 'shop-location-tooltip-74a54585-a602-4c06-b03e-e097cfacf95c', "{\"app\":{\"instanceId\":\"shop-location-tooltip-74a54585-a602-4c06-b03e-e097cfacf95c\"},\"isHeaderMenuOpen\":false,\"isMenuOpen\":false,\"params\":{\"deviceClass\":\"l\"}}", 'en-US');
# 		</script>
# 		</div></div><div class="cart-icon-container"><div><div class="None" data-version="1.2.2" id="shop-cart-icon-4edfb587-c3eb-4bf9-aca2-dff30fad9735">
# 			<link href="/~assets/bby/_com/shop/cart-icon/dist/client/client-0f5789c5b930ff2d6bbb4568850125cf.css" rel="stylesheet"/>
# 			<div class="shop-cart-icon"><div class="appContainer" data-reactroot=""><div class="bby-cart lv"><a aria-label="Cart, 0 item" class="cart-link" data-lid="hdr_carticon" href="https://www.bestbuy.com/cart" title="Cart"><img alt="cart icon" src="/~assets/bby/_com/shop/cart-icon/dist/client/images/1905cd7135529612f63c727e038008c3.svg"/><span class="cart-label">Cart</span></a></div></div></div>
# 			<script defer="" src="/~assets/bby/_com/shop/cart-icon/dist/client/client-ea96fead036efd35c6380d7186774e53.js"></script>
# 			<script>
# 			initializer.initializeComponent({"creatorNamespace":"shop","componentId":"cart-icon","contractVersion":"v1","componentVersion":"1.2.2"}, "shop-cart-icon-4edfb587-c3eb-4bf9-aca2-dff30fad9735", "{\"app\":{\"instanceId\":\"shop-cart-icon-4edfb587-c3eb-4bf9-aca2-dff30fad9735\",\"deviceClass\":\"l\",\"piscesBaseUrl\":\"https:\\u002F\\u002Fpisces.bbystatic.com\",\"isModalOpen\":false,\"skuId\":\"something\"},\"metaLayer\":{\"env_assets\":\"\\u002F~assets\\u002Fbby\\u002F_com\",\"env_piscesUrl\":\"https:\\u002F\\u002Fpisces.bbystatic.com\",\"env_appServer\":\"https:\\u002F\\u002Fwww.bestbuy.com\"}}", "en-US");
# 		</script>
# 		</div></div><div><div class="None" data-version="1.2043.12" id="pricing-price-change-notification-b922520d-06db-4936-a534-5e43cb3a9a76">
#
# 			<div class="pricing-price-change-notification"><div class="appContainer" data-reactroot="" style="position:relative"></div></div>
# 			<script>
# 			if ('noModule' in HTMLScriptElement.prototype) {
# 				(function(document){
#
# 						var scriptEl = document.createElement('script');
# 						scriptEl.src = 'https://assets.bbystatic.com/pricing/price-change-notification/dist/client/client-9da7b077e2810ca064ef40d035cf313d.mjs';
# 						scriptEl.type = 'module';
# 						if (window.navigator.userAgent.indexOf("Edge") === -1) {
# 							scriptEl.async = false;
# 						}
# 						document.getElementById('pricing-price-change-notification-b922520d-06db-4936-a534-5e43cb3a9a76').appendChild(scriptEl);
#
# 				})(document);
# 			} else {
# 				(function(document){
#
# 						var scriptEl = document.createElement('script');
# 						scriptEl.src = 'https://assets.bbystatic.com/pricing/price-change-notification/dist/client/client-6d4ebff6a7c6bce85efcf90699303e93.js';
# 						scriptEl.noModule = true;
# 						scriptEl.defer = true;
# 						if (window.navigator.userAgent.indexOf("Edge") === -1) {
# 							scriptEl.async = false;
# 						}
# 						document.getElementById('pricing-price-change-notification-b922520d-06db-4936-a534-5e43cb3a9a76').appendChild(scriptEl);
#
# 				})(document);
# 			}
# 		</script>
# 			<script>
# 			initializer.initializeComponent({"creatorNamespace":"pricing","componentId":"price-change-notification","contractVersion":"v1","componentVersion":"1.2043.12"}, "pricing-price-change-notification-b922520d-06db-4936-a534-5e43cb3a9a76", "{\"app\":{\"instanceId\":\"pricing-price-change-notification-b922520d-06db-4936-a534-5e43cb3a9a76\",\"config\":{\"interruptionDuration\":7000,\"ignoreClickAway\":false,\"fetchPacman\":true,\"pacmanTtlms\":10800000,\"fetched\":true,\"fbiState\":\"on\",\"fbiSvThrottle\":false,\"browseOffsetSelector\":\"button[data-lid*=hdr_shistory]\",\"browseOffsetX\":16,\"browseOffsetY\":10},\"isModalOpen\":false},\"metaLayer\":{\"env_assets\":\"https:\\u002F\\u002Fassets.bbystatic.com\",\"env_piscesUrl\":\"https:\\u002F\\u002Fpisces.bbystatic.com\"}}", "en-US");
# 		</script>
# 		</div></div></div></div></div></div></div></div><div class="fullbleed-wrapper"><div class="navigation-container"><div id="server-side-flyout"></div><nav aria-label="utility" class="utility-navigation"><ul class="utility-navigation-list"><li class="utility-navigation-list-item"><button class="btn-unstyled menuHeader flyBtn" data-lid="hdr_signin"><a class="BtnTxt" href="https://www.bestbuy.com/site/customer/myaccount" style="color:white">Account</a></button></li><li class="utility-navigation-list-item"><button class="btn-unstyled menuHeader flyBtn" data-lid="hdr_shistory"><a class="BtnTxt" href="https://www.bestbuy.com/site/customer/lists/manage/recently-viewed" style="color:white">Recently Viewed</a></button></li><li class="utility-navigation-list-item"><button class="btn-unstyled menuHeader flyBtn" data-lid="hdr_oStatus"><a class="BtnTxt" href="https://www.bestbuy.com/profile/ss/guestorderlookup" style="color:white">Order Status</a></button></li><li class="utility-navigation-list-item"><button class="btn-unstyled menuHeader flyBtn" data-lid="hdr_saved"><a class="BtnTxt" href="https://www.bestbuy.com/site/customer/lists/manage/saveditems" style="color:white">Saved Items</a></button></li></ul></nav></div></div></div><div><div class="None" data-version="0.1.7" id="shop-interruptions-manager-f4a141ee-db06-4b13-93cc-a4b0b2a5aaaa">
#
# 			<div class="shop-interruptions-manager"></div>
# 			<script>
# 			if ('noModule' in HTMLScriptElement.prototype) {
# 				(function(document){
#
# 						var scriptEl = document.createElement('script');
# 						scriptEl.src = '/~assets/bby/_com/shop/interruptions-manager/dist/client/client-6ca391413ddf4ac92550b3fdfaf8e470.mjs';
# 						scriptEl.type = 'module';
# 						if (window.navigator.userAgent.indexOf("Edge") === -1) {
# 							scriptEl.async = false;
# 						}
# 						document.getElementById('shop-interruptions-manager-f4a141ee-db06-4b13-93cc-a4b0b2a5aaaa').appendChild(scriptEl);
#
# 				})(document);
# 			} else {
# 				(function(document){
#
# 						var scriptEl = document.createElement('script');
# 						scriptEl.src = '/~assets/bby/_com/shop/interruptions-manager/dist/client/client-fa8b92cd6a0ea7af188730fc4d17cce0.js';
# 						scriptEl.noModule = true;
# 						scriptEl.defer = true;
# 						if (window.navigator.userAgent.indexOf("Edge") === -1) {
# 							scriptEl.async = false;
# 						}
# 						document.getElementById('shop-interruptions-manager-f4a141ee-db06-4b13-93cc-a4b0b2a5aaaa').appendChild(scriptEl);
#
# 				})(document);
# 			}
# 		</script>
# 			<script>
# 			initializer.initializeComponent({"creatorNamespace":"shop","componentId":"interruptions-manager","contractVersion":"v1","componentVersion":"0.1.7"}, "shop-interruptions-manager-f4a141ee-db06-4b13-93cc-a4b0b2a5aaaa", "{\"app\":{\"hasBusinessRulesError\":false,\"businessRules\":{\"blacklist\":{\"price-change-notification\":[{\"url\":\"\\u002Fcart\",\"deviceClass\":\"s,l\",\"placement\":\"top\",\"reason\":\"PCN notification is not allowed on cart\"},{\"url\":\"\\u002Fsite\\u002Fcustomer\\u002Fmyaccount\",\"deviceClass\":\"l\",\"placement\":\"top\",\"reason\":\"PCN notification is not allowed on bestbuy.com\"}],\"total-tech-support-toast-notification\":[{\"url\":\"\\u002F\",\"deviceClass\":\"s,l\",\"placement\":\"header\",\"reason\":\"tts toast disabled\"},{\"url\":\"\\u002Fsite\\u002Fblack-friday\\u002Fsale-ad\",\"deviceClass\":\"s,l\",\"placement\":\"header\",\"reason\":\"tts toast disabled\"},{\"url\":\"\\u002Fsite\\u002Felectronics\\u002Ftop-deals\\u002Fpcmcat1563299784494.c?id=pcmcat1563299784494\",\"deviceClass\":\"s,l\",\"placement\":\"header\",\"reason\":\"tts toast disabled\"},{\"url\":\"\\u002Fsite\\u002Fmisc\\u002Fdeal-of-the-day\\u002Fpcmcat248000050016.c?id=pcmcat248000050016\",\"deviceClass\":\"s,l\",\"placement\":\"header\",\"reason\":\"tts toast disabled\"},{\"url\":\"\\u002Fsite\\u002Fmisc\\u002Fcyber-monday\\u002Fpcmcat309500050010.c?id=pcmcat309500050010\",\"deviceClass\":\"s,l\",\"placement\":\"header\",\"reason\":\"tts toast disabled\"},{\"url\":\"\\u002Fsite\\u002Felectronics\\u002Fblack-friday\\u002Fpcmcat225600050002.c?id=pcmcat225600050002\",\"deviceClass\":\"s,l\",\"placement\":\"header\",\"reason\":\"tts toast disabled\"},{\"url\":\"\\u002Fsite\\u002Fmisc\\u002Fshop-confidently\\u002Fpcmcat1584713369767.c?id=pcmcat1584713369767\",\"deviceClass\":\"s,l\",\"placement\":\"header\",\"reason\":\"tts toast disabled\"},{\"url\":\"\\u002Fsite\\u002Fmisc\\u002Fholiday-bundle-save\\u002Fpcmcat1602797275422.c?id=pcmcat1602797275422\",\"deviceClass\":\"s,l\",\"placement\":\"header\",\"reason\":\"tts toast disabled\"},{\"url\":\"\\u002Fsite\\u002Felectronics\\u002Fgift-ideas\\u002Fabcat0010000.c?id=abcat0010000\",\"deviceClass\":\"s,l\",\"placement\":\"header\",\"reason\":\"tts toast disabled\"},{\"url\":\"\\u002Fsite\\u002Fiphone\\u002Fshop-iphone-12-models\\u002Fpcmcat1602613536916.c?id=pcmcat1602613536916\",\"deviceClass\":\"s,l\",\"placement\":\"header\",\"reason\":\"tts toast disabled\"}]},\"batchDuration\":1000,\"priorities\":{\"email-modal-notification\":1600,\"price-change-notification\":1500,\"sign-in-toast-notification\":1050,\"last-item-viewed-toast-notification\":1000}}}}", "en-US");
# 		</script>
# 		</div></div></header><div class="sr-only" id="headerskip" tabindex="-1">Main Content</div></div></div>
# 			<script>
# 			if ('noModule' in HTMLScriptElement.prototype) {
# 				(function(document){
#
# 						var scriptEl = document.createElement('script');
# 						scriptEl.src = '/~assets/bby/_com/shop/header/dist/client/client-2f2fa62bcf73b1addc7657e14cf3e01c.mjs';
# 						scriptEl.type = 'module';
# 						if (window.navigator.userAgent.indexOf("Edge") === -1) {
# 							scriptEl.async = false;
# 						}
# 						document.getElementById('shop-header-8919cfdd-6d7e-4b7d-9088-6310979fbb32').appendChild(scriptEl);
#
# 				})(document);
# 			} else {
# 				(function(document){
#
# 						var scriptEl = document.createElement('script');
# 						scriptEl.src = '/~assets/bby/_com/shop/header/dist/client/client-4cf54ecc61aa52b403e5ff7ea219c337.js';
# 						scriptEl.noModule = true;
# 						scriptEl.defer = true;
# 						if (window.navigator.userAgent.indexOf("Edge") === -1) {
# 							scriptEl.async = false;
# 						}
# 						document.getElementById('shop-header-8919cfdd-6d7e-4b7d-9088-6310979fbb32').appendChild(scriptEl);
#
# 				})(document);
# 			}
# 		</script>
# 			<script>
# 			initializer.initializeComponent({"creatorNamespace":"shop","componentId":"header","contractVersion":"v1","componentVersion":"3.6.14"}, "shop-header-8919cfdd-6d7e-4b7d-9088-6310979fbb32", "{\"app\":{\"deviceClass\":\"l\",\"piscesUrl\":\"https:\\u002F\\u002Fpisces.bbystatic.com\",\"instanceId\":\"shop-header-8919cfdd-6d7e-4b7d-9088-6310979fbb32\",\"deltaMeasureSampleSize\":1,\"headerData\":{\"globalNavigation\":[{\"childNodes\":[],\"displayName\":\"Products\",\"styleId\":\"productsMenu\",\"_meta\":{},\"bold\":true,\"isFlyMenu\":true},{\"childNodes\":[],\"displayName\":\"Brands\",\"styleId\":\"shopByBrand\",\"_meta\":{},\"bold\":true,\"isFlyMenu\":true},{\"childNodes\":[],\"displayName\":\"Deals\",\"styleId\":\"dealsMenu\",\"_meta\":{},\"bold\":true,\"isFlyMenu\":true},{\"childNodes\":[],\"displayName\":\"Services\",\"styleId\":\"servicesMenu\",\"_meta\":{},\"bold\":true,\"isFlyMenu\":true},{\"childNodes\":[],\"_meta\":{\"omitFromLarge\":false,\"omitFromMedium\":false,\"omitFromNative\":false},\"link\":{\"url\":\"\\u002Fsite\\u002Fcustomer\\u002Fmyaccount\",\"lid\":\"account_home\"},\"displayName\":\"Account\",\"bold\":true},{\"childNodes\":[],\"_meta\":{\"omitFromLarge\":false,\"omitFromMedium\":false,\"omitFromNative\":false},\"styleId\":\"separator\"},{\"childNodes\":[],\"displayName\":\"Credit Cards\",\"_meta\":{\"omitFromLarge\":false,\"omitFromMedium\":false,\"omitFromNative\":false},\"link\":{\"url\":\"\\u002Fsite\\u002Fmisc\\u002Ffinancing-rewards\\u002Fpcmcat102500050032.c?id=pcmcat102500050032\",\"lid\":\"hdr_crd\"},\"styleId\":\"topNavSingleColumn\"},{\"childNodes\":[],\"displayName\":\"Order Status\",\"_meta\":{\"omitFromLarge\":false,\"omitFromMedium\":false,\"omitFromNative\":false},\"link\":{\"url\":\"\\u002Fprofile\\u002Fss\\u002Forderlookup\",\"lid\":\"hdr_ost\"}},{\"childNodes\":[],\"displayName\":\"Recently Viewed\",\"_meta\":{\"omitFromLarge\":false,\"omitFromMedium\":false,\"omitFromNative\":false},\"link\":{\"url\":\"\\u002Fsite\\u002Fcustomer\\u002Flists\\u002Fmanage\\u002Frecently-viewed\",\"lid\":\"hdr_shistory\"}},{\"childNodes\":[],\"displayName\":\"Saved Items\",\"_meta\":{\"omitFromLarge\":false,\"omitFromMedium\":false,\"omitFromNative\":false},\"link\":{\"url\":\"\\u002Fsite\\u002Fcustomer\\u002Flists\\u002Fmanage\\u002Fsaveditems\",\"lid\":\"hdr_saved\"}},{\"childNodes\":[],\"_meta\":{\"omitFromLarge\":false,\"omitFromMedium\":false,\"omitFromNative\":false},\"styleId\":\"separator\"},{\"displayName\":\"Top Deals\",\"link\":{\"url\":\"\\u002Fsite\\u002Felectronics\\u002Ftop-deals\\u002Fpcmcat1563299784494.c?id=pcmcat1563299784494\",\"lid\":\"hdr_td_topdeals\",\"nodeId\":\"pcmcat1563299784494\"},\"_meta\":{},\"styleId\":\"topNavSingleColumn\",\"childNodes\":[]},{\"childNodes\":[],\"displayName\":\"Deal of the Day\",\"_meta\":{\"omitFromSmall\":false},\"link\":{\"url\":\"\\u002Fsite\\u002Fmisc\\u002Fdeal-of-the-day\\u002Fpcmcat248000050016.c?id=pcmcat248000050016\",\"nodeId\":\"pcmcat248000050016\",\"lid\":\"hdr_dotd\"},\"styleId\":\"topNavSingleColumn\"},{\"childNodes\":[],\"displayName\":\"Gift Cards\",\"_meta\":{\"omitFromSmall\":false},\"link\":{\"url\":\"\\u002Fsite\\u002Felectronics\\u002Fgift-cards\\u002Fcat09000.c?id=cat09000\",\"nodeId\":\"cat09000\",\"lid\":\"hdr_gft_crd\"},\"styleId\":\"topNavSingleColumn\"},{\"displayName\":\"Health & Wellness\",\"link\":{\"url\":\"\\u002Fsite\\u002Fhealth-fitness-sports\\u002Fhealth-wellness\\u002Fpcmcat1603917798858.c?id=pcmcat1603917798858\",\"nodeId\":\"pcmcat1603917798858\",\"lid\":\"hdr_health\"},\"_meta\":{\"omitFromSmall\":false},\"styleId\":\"topNavSingleColumn\",\"childNodes\":[]},{\"childNodes\":[],\"displayName\":\"For Your Business\",\"_meta\":{\"omitFromLarge\":false,\"omitFromMedium\":false,\"omitFromSmall\":false,\"omitFromNative\":false},\"link\":{\"url\":\"\\u002Fsite\\u002Felectronics\\u002Fbestbuy-business\\u002Fpcmcat230900050001.c?id=pcmcat230900050001\",\"nodeId\":\"pcmcat230900050001\",\"lid\":\"hdr_bbfb\"},\"styleId\":\"topNavS ...
# 		</script>
# 		</div><div class="v-border v-border-top v-border-light v-p-vertical-xs" data-version="0.0.46" id="shop-display-ad-c7991cc3-662f-44ac-a587-2b90924469aa">
# 			<link href="https://assets.bbystatic.com/shop/display-ad/dist/client/client-cec474eb5dbbcc305ef23823d40324cf.css" rel="stylesheet"/>
# 			<div class="shop-display-ad"><div class="pencil-border pencil-banner" data-reactroot=""><div class="app-container outer-container none"><div class="inner-container"></div></div></div></div>
# 			<script>
# 			if ('noModule' in HTMLScriptElement.prototype) {
# 				(function(document){
#
# 						var scriptEl = document.createElement('script');
# 						scriptEl.src = 'https://assets.bbystatic.com/shop/display-ad/dist/client/client-0caff12e4b9ac461137b1323caa87d99.mjs';
# 						scriptEl.type = 'module';
# 						scriptEl.async = false;
# 						document.getElementById('shop-display-ad-c7991cc3-662f-44ac-a587-2b90924469aa').appendChild(scriptEl);
#
# 				})(document);
# 			} else {
# 				(function(document){
#
# 						var scriptEl = document.createElement('script');
# 						scriptEl.src = 'https://assets.bbystatic.com/shop/display-ad/dist/client/client-df6c9c1ea3b744aa8a0c4e971ff924e8.js';
# 						scriptEl.noModule = true;
# 						scriptEl.defer = true;
# 						scriptEl.async = false;
# 						document.getElementById('shop-display-ad-c7991cc3-662f-44ac-a587-2b90924469aa').appendChild(scriptEl);
#
# 				})(document);
# 			}
# 		</script>
# 			<script>
# 			initializer.initializeComponent({"creatorNamespace":"shop","componentId":"display-ad","contractVersion":"v1","componentVersion":"0.0.46"}, 'shop-display-ad-c7991cc3-662f-44ac-a587-2b90924469aa', "{\"app\":{\"position\":\"\",\"deviceClass\":\"l\",\"instanceId\":\"shop-display-ad-c7991cc3-662f-44ac-a587-2b90924469aa\",\"size\":\"pencilDimensions\",\"showBottomBorder\":true,\"textPosition\":\"none\",\"height\":\"\",\"width\":\"\",\"enableEnsighten\":false,\"disableDisplayAd\":false},\"metaLayer\":{\"env_assets\":\"https:\\u002F\\u002Fassets.bbystatic.com\",\"env_piscesUrl\":\"https:\\u002F\\u002Fpisces.bbystatic.com\",\"env_appServer\":\"https:\\u002F\\u002Fwww.bestbuy.com\"}}", 'en-US');
# 		</script>
# 		</div>
#
# 				<div class="pl-page-content">
# 					<div aria-hidden="true" class="pl-svg-def" style="display: none;"></div>
# 					<main>
# <div data-optimizely-experiment-key="SEARCHAPI"></div>
# <div data-optimizely-experiment-key="searchTest1"></div>
# <div data-optimizely-experiment-key="searchTest2"></div>
# <div data-optimizely-experiment-key="searchTest3"></div>
# <div data-optimizely-experiment-key="searchTest4"></div>
# <div data-optimizely-experiment-key="searchTest5"></div>
# <div data-optimizely-experiment-key="searchTest6"></div>
# <div data-optimizely-experiment-key="searchTest7"></div>
# <div data-optimizely-experiment-key="searchTest8"></div>
# <div class="container-v2">
# <div class="row">
# <div class="col-xs-12">
# <div class="None" data-version="20.16.16" id="shop-holiday-search-container-17d364ff-221c-44a1-b790-fd28c000da82">
# 			<link href="/~assets/bby/_com/shop/holiday-search-container/dist/client/client-222221d643fee1a1bfdedc8dfc68f413.css" rel="stylesheet"/>
# 			<div class="shop-holiday-search-container"><div class="row facets-scrolling" data-reactroot=""><div class="col-xs-12"><div><div class="None" data-version="20.16.17" id="search-header-1">
# 			<link href="/~assets/bby/_com/shop/search-header/dist/client/client-6e0c52a984013ce296b97e024219b340.css" rel="stylesheet"/>
# 			<div class="shop-search-header"><div class="app-container lv breadcrumb-and-title"><div><div id="skiptocontent"><a class="skip-link" href="#main-results">skip to results</a><a class="skip-link" href="#main-filters">skip to filters</a></div><nav aria-label="Breadcrumb" class="search-header-breadcrumb-list"><ol><li class="crumb-list-item"><a class="crumb" href="https://www.bestbuy.com/">Best Buy</a><span class="crumb-divider"></span></li><li class="crumb-list-item"><a class="crumb" href="https://www.bestbuy.com/site/electronics/video-games/abcat0700000.c?id=abcat0700000">Video Games</a><span class="crumb-divider"></span></li><li class="crumb-list-item"><a class="crumb" href="https://www.bestbuy.com/site/video-games/playstation-5/pcmcat1572034351415.c?id=pcmcat1572034351415">PlayStation 5</a></li></ol></nav></div><span><h1 class="browse-title title">PS5 Games</h1></span></div></div>
# 			<script defer="" src="/~assets/bby/_com/shop/search-header/dist/client/client-9949b2a78a64a70a2ed6d8b524435947.js"></script>
# 			<script>
# 			initializer.initializeComponent({"creatorNamespace":"shop","componentId":"search-header","contractVersion":"v1","componentVersion":"20.16.17"}, 'search-header-1', "{\"app\":{\"deviceClass\":\"l\",\"instanceId\":\"search-header-1\",\"categoryId\":\"pcmcat1587395108347\",\"numFound\":64},\"metaLayer\":{\"env_assets\":\"\\u002F~assets\\u002Fbby\\u002F_com\",\"env_piscesUrl\":\"https:\\u002F\\u002Fpisces.bbystatic.com\",\"env_appServer\":\"https:\\u002F\\u002Fwww.bestbuy.com\"},\"searchOptions\":{\"queries\":\"categoryid$pcmcat1587395108347\",\"sortBy\":\"Best-Selling\",\"facets\":[],\"pageNumber\":1,\"enableAutoFacet\":true,\"isLegacy\":true,\"facetDisplayMap\":{\"storepickupstores_facet\":\"Store\",\"category_facet\":{},\"deliverydays_facet\":\"Delivery\",\"installdays_facet\":\"Delivery + Installation\",\"heightwithhingerange_facet\":\"Height Range\",\"widthrange_facet\":\"Width Range\",\"currentprice_facet\":\"Price\",\"platform_facet\":\"Compatible Platform\",\"currentoffers_facet\":\"Current Deals\",\"releasesrange_facet\":\"New Releases\",\"brand_facet\":\"Brand\",\"colorcat_facet\":\"Color\",\"genre_facet\":\"Genre\",\"percentdiscount_facet\":\"Discount\",\"esrbrating_facet\":\"ESRB Rating\",\"customerreviews_facet\":\"Customer Rating\",\"collection_facet\":\"Collection\",\"giftcenter_facet\":\"Gift Ideas\",\"productcategories_facet\":\"Product Categories\"},\"overrideQueries\":\"categoryid$pcmcat1587395108347\",\"browsedCategory\":\"pcmcat1587395108347\",\"searchBrowsedCategory\":\"pcmcat1587395108347\",\"numberOfResults\":24,\"shouldCollapseSkuList\":true,\"debounceInterval\":2000,\"disableNestedFacet\":false,\"enableImplicitAll\":false,\"enableCollapsedListingOnFacet\":true,\"debounceEnabled\":false,\"useNewPlpUrls\":false,\"storePickup\":{\"enable\":true,\"multiStore\":{\"enable\":true},\"nearbyWarehouse\":{\"enable\":true}},\"enableNewFalcorRoutes\":{\"enable\":true},\"enableSponsoredListing\":false,\"requiresFacetDisplayMap\":true,\"searchVariant\":\"\",\"destinationZipCode\":\"\",\"storeId\":\"\",\"nearbyStoreIdList\":[],\"experimentMap\":{},\"searchEnhancedFilteringQueryList\":[],\"enableDeliveryFacet\":false,\"deviceClass\":\"l\",\"defaultSort\":\"Best-Selling\",\"defaultFacetList\":[],\"previousDestinationZipCode\":\"\",\"previousStoreId\":\"\",\"previousEnableDeliveryFacet\":false},\"primaryLineage\":[{\"id\":\"cat00000\",\"name\":\"Best Buy\",\"seoUrl\":\"https:\\u002F\\u002Fwww.bestbuy.com\\u002F\",\"sequence\":2},{\"id\":\"abcat0700000\",\"name\":\"Video Games\",\"seoUrl\":\"https:\\u002F\\u002Fwww.bestbuy.com\\u002Fsite\\u002Felectronics\\u002Fvideo-games\\u002Fabcat0700000.c?id=abcat0700000\",\"sequence\":1},{\"id\":\"pcmcat1572034351415\",\"name\":\"PlayStation 5\",\"seoUrl\":\"https:\\u002F\\u002Fwww.bestbuy.com\\u002Fsite\\u002Fvideo-games\\u002Fplaystation-5\\u002Fpcmcat1572034351415.c?id=pcmcat1572034351415\",\"sequence\":0}],\"title\":{\"name\":\"PS5 Games\",\"seoUrl\":\"https:\\u002F\\u002Fwww.bestbuy.com\\u002Fsite\\u002Fplaystation-5\\u002Fps5-games\\u002Fpcmcat1587395108347.c?id=pcmcat1587395108347\"}}", 'en-US');
# 		</script>
# 		</div></div><div class="row"><div class="col-xs-3 facets-column"><div class="sticky-container"><div><div class="None" data-version="20.16.32" id="facets-1">
# 			<link href="/~assets/bby/_com/shop/facets/dist/client/client-0f05a4c2bde35f8c6504730ec62d6754.css" rel="stylesheet"/>
# 			<div class="shop-facets"><div class="app-container lv"><div class="facet-list-container" id="main-filters"><div aria-level="2" class="sr-only" role="heading">Categories &amp; Filters</div><div class="get-it-fast-together"><div class="get-it-fast facet-section"><div class="facet-no-border-bottom"><div><h3 class="facet-title">Get it fast</h3></div></div></div><div class="facet-section"><div class="lv facet-no-delivery-facet-shown-padding pick-up-today-facet"><fieldset class="pick-up-today"><legend class="get-it-fast-subheading"><strong>Store Pickup</strong><span class="pick-up-at"> <!-- -->at<!-- --> </span></legend><div class="c-facet"><div class="c-checkbox v-medium disabled"><label for="store-pickup-pick-up-today"><div class="c-checkbox-brand"><div class="c-checkbox-custom-input"><input data-cy="store-pickup-pick-up-today" disabled="" id="store-pickup-pick-up-today" type="checkbox"/><div class="c-checkbox-focus-ring"></div><svg aria-hidden="true" class="c-checkbox-icon c-checkbox-icon-hidden" role="img" viewBox="0 0 100 100" width="1em"><use href="/~assets/bby/_img/int/plsvgdef-frontend/svg/checkbox-checkmark.svg#checkbox-checkmark" xlink:href="/~assets/bby/_img/int/plsvgdef-frontend/svg/checkbox-checkmark.svg#checkbox-checkmark"></use></svg></div></div><span class="c-facet-text">Pick up today</span></label></div></div></fieldset></div></div></div><div class="bordered-section"><div class="facet-section"></div><div class="facet-section"><section class="lv facet"><fieldset name="Price"><legend class="facet-legend"><h3 class="facet-title default"><span class="c-section-title-text">Price</span></h3></legend><div class="range"><div class="range-inputs"><input aria-label="Minimum Price" autocomplete="off" class="range-control form-control" id="min-currentprice_facet-input" maxlength="12" placeholder="min." type="text" value=""/><span class="range-to">to</span><input aria-label="Maximum Price" autocomplete="off" class="range-control form-control" id="max-currentprice_facet-input" maxlength="12" placeholder="max." type="text" value=""/></div><button aria-label="Apply Price Range" class="btn btn-link btn-sm btn-ficon c-button-icon c-button-icon-center range-submit" disabled="" href="" type="button"><svg aria-hidden="true" class="svg-size-s" role="img" viewBox="0 0 100 100"><use href="/~assets/bby/_img/int/plsvgdef-frontend/svg/Caret_Right_Line_Sm.svg#Caret_Right_Line_Sm" xlink:href="/~assets/bby/_img/int/plsvgdef-frontend/svg/Caret_Right_Line_Sm.svg#Caret_Right_Line_Sm"></use></svg></button></div><ul class="facet-option-list"><li class="facet-option-list-item"><div class="facet-option-container"><div class="c-facet"><div class="c-checkbox v-medium"><label for="currentprice_facet-$25-$49.99-0"><div class="c-checkbox-brand"><div class="c-checkbox-custom-input"><input id="currentprice_facet-$25-$49.99-0" type="checkbox"/><div class="c-checkbox-focus-ring"></div><svg aria-hidden="true" class="c-checkbox-icon c-checkbox-icon-hidden" role="img" viewBox="0 0 100 100" width="1em"><use href="/~assets/bby/_img/int/plsvgdef-frontend/svg/checkbox-checkmark.svg#checkbox-checkmark" xlink:href="/~assets/bby/_img/int/plsvgdef-frontend/svg/checkbox-checkmark.svg#checkbox-checkmark"></use></svg></div></div><span class="c-facet-text"><span class="sr-only">$25 - $49.99</span><a aria-hidden="true" class="facet-seo-link" href="https://www.bestbuy.com/site/searchpage.jsp?_dyncharset=UTF-8&amp;browsedCategory=pcmcat1587395108347&amp;id=pcat17071&amp;iht=n&amp;ks=960&amp;list=y&amp;qp=currentprice_facet%3DPrice~%2425%20-%20%2449.99&amp;sc=Global&amp;st=categoryid%24pcmcat1587395108347&amp;type=page&amp;usc=All%20Categories" tabindex="-1"><span class="facet-option-label-text">$25 - $49.99</span></a></span></label></div></div></div></li><li class="facet-option-list-item"><div class="facet-option-container"><div class="c-facet"><div class="c-checkbox v-medium"><label for="currentprice_facet-$50-$74.99-1"><div class="c-checkbox-brand"><div class="c-checkbox-cu ...
# 			<script defer="" src="/~assets/bby/_com/shop/facets/dist/client/client-185e10a62e4a2a4f27527d52db91a81f.js"></script>
# 			<script>
# ...
# 		</script>
# 		</div><div class="v-m-bottom-xxl" data-version="0.0.46" id="shop-display-ad-23ee8c53-c9c8-4550-97ae-cf5a9ec12c13">
#
# 			<div class="shop-display-ad"><div class="leaderboard-footer" data-reactroot=""><div class="app-container outer-container left"><span class="vertical-text ad-text uppercase">advertisement</span><div class="inner-container"></div></div></div></div>
# 			<script>
# 			if ('noModule' in HTMLScriptElement.prototype) {
# 				(function(document){
#
# 						var scriptEl = document.createElement('script');
# 						scriptEl.src = 'https://assets.bbystatic.com/shop/display-ad/dist/client/client-0caff12e4b9ac461137b1323caa87d99.mjs';
# 						scriptEl.type = 'module';
# 						scriptEl.async = false;
# 						document.getElementById('shop-display-ad-23ee8c53-c9c8-4550-97ae-cf5a9ec12c13').appendChild(scriptEl);
#
# 				})(document);
# 			} else {
# 				(function(document){
#
# 						var scriptEl = document.createElement('script');
# 						scriptEl.src = 'https://assets.bbystatic.com/shop/display-ad/dist/client/client-df6c9c1ea3b744aa8a0c4e971ff924e8.js';
# 						scriptEl.noModule = true;
# 						scriptEl.defer = true;
# 						scriptEl.async = false;
# 						document.getElementById('shop-display-ad-23ee8c53-c9c8-4550-97ae-cf5a9ec12c13').appendChild(scriptEl);
#
# 				})(document);
# 			}
# 		</script>
# 			<script>
# 			initializer.initializeComponent({"creatorNamespace":"shop","componentId":"display-ad","contractVersion":"v1","componentVersion":"0.0.46"}, 'shop-display-ad-23ee8c53-c9c8-4550-97ae-cf5a9ec12c13', "{\"app\":{\"position\":\"\",\"deviceClass\":\"l\",\"instanceId\":\"shop-display-ad-23ee8c53-c9c8-4550-97ae-cf5a9ec12c13\",\"size\":\"leaderboardFooter\",\"showBottomBorder\":false,\"textPosition\":\"left\",\"height\":\"\",\"width\":\"\",\"enableEnsighten\":false,\"disableDisplayAd\":false},\"metaLayer\":{\"env_assets\":\"https:\\u002F\\u002Fassets.bbystatic.com\",\"env_piscesUrl\":\"https:\\u002F\\u002Fpisces.bbystatic.com\",\"env_appServer\":\"https:\\u002F\\u002Fwww.bestbuy.com\"}}", 'en-US');
# 		</script>
# 		</div></div></div></div>
# <div class="None" data-version="2.1.19" id="shop-log-handler-7c49d4d9-efba-43b7-a722-8fbf9da9e3c8"><div class="shop-log-handler"></div><script defer="" src="/~assets/bby/_com/shop/log-handler/dist/client/client-2c79930a86135c750edb9f2b5288fe1c.js"></script><script>initializer.initializeComponent({"creatorNamespace":"shop","componentId":"log-handler","contractVersion":"v1","componentVersion":"2.1.19"}, "shop-log-handler-7c49d4d9-efba-43b7-a722-8fbf9da9e3c8", "{}", "en-US");</script></div><div class="None" data-version="2.0.57" id="shop-location-persistence-e0ffa793-cfc9-4552-9703-39505cd6c9e1">
#
# 			<div class="shop-location-persistence"></div>
# 			<script>
# 			if ('noModule' in HTMLScriptElement.prototype) {
# 				(function(document){
#
# 						var scriptEl = document.createElement('script');
# 						scriptEl.src = '/~assets/bby/_com/shop/location-persistence/dist/client/client-e2a10c1ab87a3eb304241dff537958cd.mjs';
# 						scriptEl.type = 'module';
# 						if (window.navigator.userAgent.indexOf("Edge") === -1) {
# 							scriptEl.async = false;
# 						}
# 						document.getElementById('shop-location-persistence-e0ffa793-cfc9-4552-9703-39505cd6c9e1').appendChild(scriptEl);
#
# 				})(document);
# 			} else {
# 				(function(document){
#
# 						var scriptEl = document.createElement('script');
# 						scriptEl.src = '/~assets/bby/_com/shop/location-persistence/dist/client/client-377876d8c0416cc5ee72fa863c397acb.js';
# 						scriptEl.noModule = true;
# 						scriptEl.defer = true;
# 						if (window.navigator.userAgent.indexOf("Edge") === -1) {
# 							scriptEl.async = false;
# 						}
# 						document.getElementById('shop-location-persistence-e0ffa793-cfc9-4552-9703-39505cd6c9e1').appendChild(scriptEl);
#
# 				})(document);
# 			}
# 		</script>
# 			<script>
# 			initializer.initializeComponent({"creatorNamespace":"shop","componentId":"location-persistence","contractVersion":"v1","componentVersion":"2.0.57"}, 'shop-location-persistence-e0ffa793-cfc9-4552-9703-39505cd6c9e1', "{\"liveConfig\":{\"updateOldCookie\":true,\"useExtStoreIdValue\":true,\"writeExtStoreIdToProfile\":true,\"restrictLocDestZipUpdate\":true,\"getShippingAddress\":true}}", 'en-US');
# 		</script>
# 		</div></main>
# 				</div>
#
#
# <div class="None" data-version="1.2.20" id="shop-footer-f45e1172-70e2-4c83-a57c-dbab9e489716">
# 			<link href="/~assets/bby/_com/shop/footer/dist/client/client-1496cb80b993d2c527e3ecbca266bd4d.css" rel="stylesheet"/>
# 			<div class="shop-footer"><footer class="appContainer lv" data-reactroot="" id="large-footer"><div id="footer-email-block"><div class="footer-email-wrap"><div class="footer-email-container"><div class="col-xs-8"><form aria-invalid="false" class="email-block-wrap" id="footer-email-form" novalidate=""><div class="headline" for="footerEmailField">Get the latest deals and more.</div><div id="input-wrapper"><span class="c-overlay-wrapper"><span class="overlayTrigger"><div class="footer-email-input-group form-group v-medium"><input aria-describedby="footer-email-field-error" aria-invalid="false" aria-label="Email Address" class="c-input" id="footerEmailField" name="footerEmailField" placeholder="Enter email address" required="" type="text" value=""/><button aria-describedby="footer-email-field-error" class="btn btn-primary v-medium" data-lid="ft_signup" id="footerEmailSignUpBtn" type="submit">Sign Up</button><span aria-live="polite" class="c-input-error-message" id="error-id"></span></div></span><span></span></span><span id="footer-email-field-error"></span></div></form></div><div class="divider-block col-xs-1"><div class="divider"></div></div><div class="col-xs-3"><div class="bby-app-block"><svg alt="device icon" aria-hidden="true" class="device-icon" fill="#e0e6ef" viewBox="0 0 100 100"><use href="/~assets/bby/_img/int/plsvgdef-frontend/svg/MobileApp_Line_Sm.svg#MobileApp_Line_Sm" xlink:href="/~assets/bby/_img/int/plsvgdef-frontend/svg/MobileApp_Line_Sm.svg#MobileApp_Line_Sm"></use></svg><a class="app-entry" data-lid="ft_bby_apps" href="/site/misc/mobile-app/pcmcat208500050016.c?id=pcmcat208500050016"><span class="app-entry-label">Best Buy app</span><span class="app-entry-action">Learn more ›</span></a></div></div></div></div></div><div class="primary-navigation"><div class="col-xs-3"><div class="primary-navigation-block"><h3 class="title"><a class="heading-6" data-lid="ft_mby" href="/site/clp/my-best-buy/pcmcat309300050007.c?id=pcmcat309300050007">My Best Buy<!-- --> ›</a></h3><ul aria-label="My Best Buy" class="links"><li class="link"><a data-lid="ft_pts" href="https://www.bestbuy.com/profile/c/rwz/overview">View Points &amp; Certificates</a></li><li class="link"><a data-lid="ft_mby_mem" href="/loyalty/catalog">Member Offers</a></li><li class="link"><a data-lid="ft_act" href="https://www.bestbuy.com/identity/global/signin">Sign in or Create Account</a></li></ul></div><div class="primary-navigation-block"><h3 class="title"><a class="heading-6" data-lid="ft_ccd" href="/site/misc/financing-rewards/pcmcat102500050032.c?id=pcmcat102500050032">Credit Cards<!-- --> ›</a></h3><ul aria-label="Credit Cards" class="links"><li class="link"><a data-lid="ft_mpy" href="https://www.bestbuy.com/identity/sso/signin?contextId=sso-visa&amp;processIndicator=dashboard&amp;source=fT4TCYlhM%2FBHt4GYEIyTpUXh8eOIYXDjvQ8brdIq%2BgjFKp0ZC2Aq%2BH81O%2Futk9NoztIKhuI3FqmuRt1rZid1%2Bw%3D%3D">Make a Payment at Citibank</a></li><li class="link"><a data-lid="ft_ccbal" href="https://www.bestbuy.com/identity/sso/signin?contextId=sso-visa&amp;processIndicator=dashboard&amp;source=fT4TCYlhM%2FBHt4GYEIyTpUXh8eOIYXDjvQ8brdIq%2BgjFKp0ZC2Aq%2BH81O%2Futk9NoztIKhuI3FqmuRt1rZid1%2Bw%3D%3D">Check Balance at Citibank</a></li><li class="link"><a data-lid="ft_cco" href="/site/misc/financing-rewards/pcmcat102500050032.c?id=pcmcat102500050032">Credit Card Offers</a></li><li class="link"><a data-lid="ft_ano" href="/site/misc/financing-rewards/pcmcat102500050032.c?id=pcmcat102500050032">Apply Now</a></li></ul></div></div><div class="col-xs-3"><div class="primary-navigation-block"><h3 class="title"><a class="heading-6" data-lid="ft_oar" href="/site/help-topics/orders-returns-exchanges-policy/pcmcat316000050002.c?id=pcmcat316000050002">Orders &amp; Returns<!-- --> ›</a></h3><ul aria-label="Orders &amp; Returns" class="links"><li class="link"><a data-lid="ft_os" href="/profile/ss/orderlookup">Order Status</a></li><li class="link"><a data-lid="ft_sds" href="/site/help-topics/shipping- ...
# 			<script>
# 			if ('noModule' in HTMLScriptElement.prototype) {
# 				(function(document){
#
# 						var scriptEl = document.createElement('script');
# 						scriptEl.src = '/~assets/bby/_com/shop/footer/dist/client/client-1c8e956beb5691f070397bf1ce4fbce6.mjs';
# 						scriptEl.type = 'module';
# 						if (window.navigator.userAgent.indexOf("Edge") === -1) {
# 							scriptEl.async = false;
# 						}
# 						document.getElementById('shop-footer-f45e1172-70e2-4c83-a57c-dbab9e489716').appendChild(scriptEl);
#
# 				})(document);
# 			} else {
# 				(function(document){
#
# 						var scriptEl = document.createElement('script');
# 						scriptEl.src = '/~assets/bby/_com/shop/footer/dist/client/client-a8a52101a19e2bbb1eb7086ccb2902f5.js';
# 						scriptEl.noModule = true;
# 						scriptEl.defer = true;
# 						if (window.navigator.userAgent.indexOf("Edge") === -1) {
# 							scriptEl.async = false;
# 						}
# 						document.getElementById('shop-footer-f45e1172-70e2-4c83-a57c-dbab9e489716').appendChild(scriptEl);
#
# 				})(document);
# 			}
# 		</script>
# 			<script>
# 			initializer.initializeComponent({"creatorNamespace":"shop","componentId":"footer","contractVersion":"v1","componentVersion":"1.2.20"}, "shop-footer-f45e1172-70e2-4c83-a57c-dbab9e489716", "{\"deviceClass\":\"l\",\"displayLiveChat\":false,\"disableFooterSTIPS\":true}", "en-US");
# 		</script>
# 		</div>
#
#
# <script type="text/javascript">
# var trackData = {
# profileId : "",
# recognized : "Anonymous",
# persistentCart : false,
# guestUser : "true",
# stnum : "960",
# rzTier : "None",
# rzId : "",
# sysDate : "01/04/2021",
# timestamp : "01/04/2021 11:22:12 PM"
#
# };
# </script>
#
# <script src="/~assets/bby/_com/optimizely/optimizely.min-0cf8c2d616509221aa049c8557a54b4f.js" type="text/javascript"></script><script type="text/javascript">
# window.__optimizelyData = {
# data: {"version":"4","rollouts":[],"typedAudiences":[],"anonymizeIP":false,"projectId":"8389272731","variables":[],"featureFlags":[{"experimentIds":[],"rolloutId":"","variables":[{"defaultValue":"150","type":"string","id":"1","key":"BAR_LENGTH"}],"id":"9841960106","key":"STICKY_SEARCH_BAR"}],"experiments":[],"audiences":[{"conditions":"[\"or\", {\"match\": \"exact\", \"name\": \"$opt_dummy_attribute\", \"type\": \"custom_attribute\", \"value\": \"$opt_dummy_value\"}]","id":"$opt_dummy_audience","name":"Optimizely-Generated Audience for Backwards Compatibility"}],"groups":[],"attributes":[{"id":"8385791998","key":"rzTier"},{"id":"8467486998","key":"postalCode"},{"id":"8498013367","key":"username"},{"id":"8568851411","key":"deviceClass"},{"id":"8629020721","key":"uuid"},{"id":"9015255042","key":"loggedIn"},{"id":"10446690792","key":"device-size"},{"id":"10448650355","key":"visitor-type"},{"id":"11045341972","key":"ptRecognized"},{"id":"11072702291","key":"vtRecognized"},{"id":"13723330407","key":"oid"}],"botFiltering":false,"accountId":"8140550914","events":[{"experimentIds":[],"id":"8562290693","key":"ATC - overall"},{"experimentIds":[],"id":"8781834467","key":"Purchase Conversion"},{"experimentIds":[],"id":"14146420270","key":"Dummy Conversion"}],"revision":"2096"},
# attrs: {"deviceClass":"l","loggedIn":"false","ptRecognized":"false","oid":"2107281356"},
# disableOptimizelyShopWebActivation: false
# };
# ;(function () {
# var data = window.__optimizelyData.data;
# var attrs = window.__optimizelyData.attrs;
# var id = (document.cookie.match('(^|; )oid=([^;]*)')||0)[2];
# var experimentAttr = 'data-optimizely-experiment-key';
# var isLoggingActive = /optimizelyLogging=true/i.test(window.location.search);
# var evarAttr = 'data-optimizely-evar';
# var activeTests = document.querySelectorAll('[' + experimentAttr + ']');
# var activatedTests = [];
# var config1 = window.liveConfig ? (window.liveConfig && window.liveConfig.gvp && window.liveConfig.gvp.services ? window.liveConfig.gvp.services.optimizely : {}) : {};
# var config2 = window.configService ? window.configService.getServiceConfig('optimizely') : {};
# var placebos = (config2 && config2.get && config2.get('placebos') ? config2.get('placebos') : config1.placebos) || [];
# var client,variation;
# window.track = window.track || {};
# var logLevelMatches = window.location.search.match(/optimizelyLoggingLevel=({d})/i);
# var logLevel = logLevelMatches ? logLevelMatches[1] : 2;
# var logger = {
# log: function (message) {
# if (isLoggingActive) {
# console.log(message);
# }
# }
# };
# if (data && attrs && id) {
# client = window.optimizelyClient.createInstance({
# datafile: data,
# skipJSONValidation: true,
# logger: logger,
# logLevel: logLevel
# });
# if (activeTests.length) {
# for (var i = 0; i < activeTests.length; i++) {
# activate(activeTests[i].getAttribute(experimentAttr), activeTests[i].getAttribute(evarAttr))
# }
# }
# if (placebos.length) {
# for (var i = 0; i < placebos.length; i++) {
# var placebo = placebos[i];
# try {
# var pageType = window._do_not_use_me ? window._do_not_use_me.pageType : (window.track || {}).pageType;
# if (placebo.locationHrefRegex && new RegExp(placebo.locationHrefRegex).test(window.location.href)) {
# activatePlacebo(placebo)
# } else if (placebo.pageTypeRegex && new RegExp(placebo.pageTypeRegex).test(pageType)) {
# activatePlacebo(placebo)
# }
# } catch (err) {
# console.log('failed to initialize placebo: ', placebo);
# }
# }
# }
# }
# function activate(experimentKey, evar) {
# if (activatedTests.indexOf(experimentKey) > -1) return;
# var variation = client.activate(experimentKey, id, attrs);
# if (evar && variation) {
# window.track[evar] = experimentKey + '_Recipe_' + variation;
# }
# activatedTests.push(experimentKey);
# return variation;
# }
# function activatePlacebo(placebo) {
# var evar = placebo.evar;
# var experimentKey = placebo.experimentKey;
# if (experimentKey) {
# if (activate(experimentKey, evar) && isLoggingActive) {
# console.log('activated placebo');
# }
# }
# }
# var optimizelyListener = {
# type: "addListener",
# filter: {
# type: "analytics",
# name: "trackEvent"
# },
# handler: function(event) {
# var metrics = event.data && event.data.metrics ? event.data.metrics : {};
# var tags = event.data && event.data.tags ? event.data.tags : {};
# var metricsTags = Object.assign({}, metrics, tags);
# var eventName = event.data && event.data.name ? event.data.name.replace(/\(|\)|\s+\//g, '') : '';
# if (event.data.type === 'pageview') {
# eventName = 'Visit Page - ' + eventName;
# }
# client.track(eventName, id, attrs, metricsTags);
# }
# }
# window.optimizely = window.optimizely || [];
# window.optimizely.push(optimizelyListener);
# })();
# </script>
#
#
# 				<script>
# 					;(function () {
# 							if (!document.querySelector('script[src="/~assets/bby/_js/ext/optmzly/8143030612.js"]')) {
# 								var script = document.createElement('script');
# 								script.src = '/~assets/bby/_js/ext/optmzly/8143030612.js';
# 								document.getElementsByTagName('head')[0].appendChild(script);
# 							}
# 					}());
# 				</script>
# 		<script>window.dioFramework = true;</script>
# 		<script async="" src="/~assets/bby/_com/analytics-dotcom/analyticsInit-8f9661a1685be65cc2851749e5596689.js"></script>
# 		<script async="" src="/~assets/bby/_com/@ds/unified-chat/dist/javascript/unified-chat-init-0da34486.js"></script>
# 		<script async="" src="/~assets/bby/_com/timeline-web/loader-1.0.648.js"></script>
#
#
#
#
# 				<script async="" defer="" src="//img.bbystatic.com/BestBuy_US/js/tracking/brightTag-min.js"></script>
# 			<script type="text/javascript">var _cf = _cf || []; _cf.push(['_setFsp', true]);  _cf.push(['_setBm', true]);  _cf.push(['_setAu', '/content/6b54142f6crn22099deb75f785c09980']); </script><script src="/content/6b54142f6crn22099deb75f785c09980" type="text/javascript"></script>
# 		</body></html>

# %%
items = soup.find(class_ = "sku-item-list")
items
# Out:
# <ol class="sku-item-list"><li class="embedded-sponsored-listing"><div><div class="None" data-version="1.0.71" id="shop-sponsored-listing-5a692e66-6fc6-4dfc-a80b-72703a25ca59">
# 			<link href="https://assets.bbystatic.com/shop/sponsored-listing/dist/client/client-5c6b73b32227ac79a8af2883387ddacf.css" rel="stylesheet"/>
# 			<div class="shop-sponsored-listing"><div class="appContainer sku-item" data-reactroot=""><div data-click-beacon="//cat.criteo.com/beacon?fid=100&amp;hl_qs=Qvl5fzLGBDdFpPiGp4UhOrXO%2b8IkUg%2bZa5GGaNg91XXl6k28FQ00nwUK%2bKc6ef4%2b%2fTxIfPVhY5kF9p%2bz43vhrpgfVDdNoG0avk3fHLId3h85MKnLQTG9Bkc51R4%2fznsv%2fMX27YFO2aY09lj7YfNasXc2w8HH1Tmy0AaQL5eoQxOyNkVsdOfnj2atTy4lpyAzVdDGMuvZxmEXvWEhXBdBbIZ%2ba8seo9zUfJwY6bujf%2b4MWDeDNEpHpKtiUeTp9dYQteo1zN7qfB3yO3TBhlQiifNtXpEp4G6hCANqOUN4hJnDryUu%2fH36yBdDuN80X0Oh0y9b1zdv8Ark64eTFJD0msVm9Pjn7GyrpLwJDeCHI4CnNHI%2fk2YHV%2f5ZYH5Fb3OGvkX%2fqne4Ec0TnlEk1Wx1Z4uAxK9Grxi2d8dU%2bX%2fT6xALrHFPBtMkPBOoYjzCaRAQuRYmEOvqjDA%2fuct67MQDdTgHr7SNV0tajCb7SRrIzhxeNOQAtKF1e57eBu%2fSppqYGpc2LkdFr0s7zG8My9HkZ9gC0Vi9LvnJHAjZ78vPLeNTM%2fG7jvaUAaNLXVsy8TM63axVJEw0R%2f48U73mdvjRM1EMygjPW6%2fFC2pyJnW3HJeJHqlX4985ZMTDlc6Q4xU53HarJKi1jrcdY23oaiSqPsTxbNfgK%2fxuJsBw6GezoNDUcOqnZrqdNLVZbDPlB%2f4kvVMKbOP2eBWaF5g91Dk2Abs6gPxsEEfwkVeDUIhecfW7wmDn9AIT0T9rT0%2bDMntT%2bS668hpvfJO3dSi11glJIiNZW3TMurxi4wfXPXcQ9cMnlfU%2bfuWMD4WuUAdNuKEq2vmaeI2m%2fE51a4G%2bAg8ACf4eeSRkhkXI6KrySJb%2fY0FSBr6IwuA%2bxi5xW8kEUsRwnrcmW4XTCmrH1DZKcU231tw2%2fXbpNoshbsHtTAdSxWnmDiRcZWeQEFCRQCU7018GfoUPe2KqayFtgFQPXiudT1MKbII0%2buU6IrKtIOh1udZcyuBd8cMhizOzwRWAC2zFnKfRMKY6z8b4hgsqtBJD9I7TPkOI%2fGNAbEfudlPJ3DyqXOMaZeV58HnFUIVJZfCEqbLKtr0QEyr4gD3J4TfZvCLvjLqN%2fmUU0MU4OEGs1PKpv7Mz8o4XIDkFOcNsYOz6FxtBW5%2f%2fuqaHOj5BXnpIWg%3d%3d&amp;ev=2&amp;action=click&amp;rn=586061695&amp;puserid=[PUSERID]&amp;pid=[CLICKPID]&amp;impressionpid=[IMPPID]&amp;pageguid=[PAGEGUID]" data-load-beacon="//b.va.us.criteo.com/beacon?fid=100&amp;hl_qs=Qvl5fzLGBDdFpPiGp4UhOrXO%2b8IkUg%2bZa5GGaNg91XXzsBBXhQUSnd28LuITB0WF8oBnfkWJ5s%2b9RYT5Qbp4pepA%2bA3DIUOZgF6Wv9UdOa3eUpvxQy%2bztJXtBSNfICDEMi843m5LjjSzPKiuN7gxAjjBRZrr8b3%2fsr8%2b9aMrP%2f4PQ%2fhibwW5%2f2m1qVT0zrrVBWh3w1HuBXMRG6ANN%2bSH%2fWLTz4X8Me7WeUrO8upjemvlT1f0LB%2bacPMI1erby2%2fEIx28x8AnI2vQwI8ed7XzP8n7rdLvNy5x9AcvW9WSbkArlPXq9LTrBrSY0yIMZACq0caHteD9ibyVXrairZ7FgSGnkKGeVDV5aGC7Y%2bDnX9%2frxFRql2fAoDrG8YDT7fKb4Cjq1aE9Wp%2fh2%2fGBTmtw5M4iqZOjJ0gQJig8Fb3JfCM2GSrnOxXb7EJJU2neesoBLUMy4k3%2bVO%2fajpzRMwSs%2bLaTMg4CwhONfvvJ4CzKHlPNwR6vWYXloODezObKIeatrH6iDzgu3bqu240ZnN%2bJMaenXo83CE5%2bBgjveJGD%2fotOLXzGZz%2fo5D3rIIlnrxLCeSTHmS%2bf5Gi6hW%2bJ9B%2fjrLdF3ouhulfe6Dx69PylCvIkHLqBYI39C80WH2nIIaAxEv7%2b3GZk%2ficU6WDxVr3EBjASKIgp6aET%2fWoCVtMnnAI2NDU%2fElSlMv9f66UD7orG48dcB2VP6rKirAd8MPHkN9WIl36L11pSCHewm7ELmSNHvMBorYpW4is8oVLFsdh5%2bxKTwO%2fdzjlQbMZ0occ2w8npH52WbZohoyAeqrfQolSigHv70VrHbpuwmvBmlLNT3XxSEzuRst2s7a9f4yMObJCw9nAhjYVc1IPqdVT1X5lXajtde8YbepdFQERVCH2NCMlS%2f9vC5%2bLZ3F1Rdh9YY8ZyeiSKD%2fd2%2f4vZKLOtzMn1GbjFdx7i93TArnat22Xs&amp;ev=2&amp;action=page&amp;origc=A&amp;rn=1710750397&amp;puserid=[PUSERID]&amp;pid=[PAGEGUID]" data-sponsored-variant="B" data-view-beacon="//b.va.us.criteo.com/beacon?fid=100&amp;hl_qs=Qvl5fzLGBDdFpPiGp4UhOrXO%2b8IkUg%2bZa5GGaNg91XXl6k28FQ00nwUK%2bKc6ef4%2b%2fTxIfPVhY5kF9p%2bz43vhrpgfVDdNoG0avk3fHLId3h85MKnLQTG9Bkc51R4%2fznsv%2fMX27YFO2aY09lj7YfNasXc2w8HH1Tmy0AaQL5eoQxOyNkVsdOfnj2atTy4lpyAzVdDGMuvZxmEXvWEhXBdBbIZ%2ba8seo9zUfJwY6bujf%2b4MWDeDNEpHpKtiUeTp9dYQteo1zN7qfB3yO3TBhlQiifNtXpEp4G6hCANqOUN4hJkIK2jZWGtzwePYcCxiwWdGIikksNYHI4rZXTlJZio4FJh9jQ0ZAey336TnhbBQzxIHx1sVTw5lJPNEv3KyGq%2bKW6NwtBtisIsiMLsLYhDf6066RnE%2bXquYdebDBTjtotEaU1brzQgRTqC1fGLW%2fuvkhnHSWgHePXg%2bIvzEUu5x850exKRhtYFaxc%2b9F6c3KRNt5kSDg%2fKjHZN4VHLozLvCP6X7vEVHEdN8mQ9BOxHQa27w5Z7yXmIp1%2b9qRvUj3lOLK3lJHZhzX9Uz0YWNR0sUCY84ckar12aHpXK2fK0yq%2bumy8a7hVc%2fnTllnwIe6PlE%2f67l43JPLQSC%2fAguAdKU61NBixL07HKJJTHC%2bVaBZFZRHY9fv5NRtSMxrByg2mDI8%2fWat3Kdd2RFvtfB5RHWTPntPdu8Sv7barzmoGCGWtpeRZV0N8EZZ5xNGp420GhKacZLPQpbY42Duei0zWLre8vprBpBE6TkIwY1NIf1LBtzo33KM1UqvPu0uUgx%2fsh7GbY5Vyk18JdYs%2buNHiQ%2fI4G8DDm%2fuKZRaQQ4AbCaA5DlZPDPO%2bOXrTB2TNCdsc8hR4ebu4IcHA%2bY1p2zb847YNOeMY%2bZ9lpaJbT9RVtapUCSA%2f3jW4Zy4g%2bk80VuMW5z7ZZ6MZ4GFknyWWqIfFP6GPuXJehWEx7g5U%2b04%2bBwXgVhvma7%2bIC55OhURaZVBwerRz%2bIzEnVs7UG1JueRhq%2bIP%2bTV3VCpsdI%2fpNVNIvnwtqUMNU5ot8QnqVVy4XLkpTe9jpGj%2fiHPAldO8Fx ...
# 			<link href="/~assets/bby/_com/shop/sku-list-item/dist/client/client-7ff3a8f671724a3da9f40a24734a4b73.css" rel="stylesheet"/>
# 			<div class="shop-sku-list-item"><div class="list-item lv" data-sku-id="6414078"><div class="image-column"><a class="image-link" href="/site/nba-2k21-mamba-forever-edition-playstation-5/6414078.p?skuId=6414078"><img alt="NBA 2K21 Mamba Forever Edition - PlayStation 5 - Alt_View_Standard_11" class="product-image" src="https://pisces.bbystatic.com/image2/BestBuy_US/images/products/6414/6414078cv11a.jpg;maxHeight=200;maxWidth=300" srcset="https://pisces.bbystatic.com/image2/BestBuy_US/images/products/6414/6414078cv11a.jpg;maxHeight=300;maxWidth=450 1.5x"/><div class="detail-display-text"><span data-track="See More Options">See More Options</span></div></a></div><div class="right-column"><div class="information"><div class="is-sponsored">Sponsored</div><div class="embedded-badge"><div><div></div></div></div><div><div class="sku-title"><h4 class="sku-header"><a href="/site/nba-2k21-mamba-forever-edition-playstation-5/6414078.p?skuId=6414078">NBA 2K21 Mamba Forever Edition - PlayStation 5</a></h4></div></div><div class="variation-info"><div class="sku-model"><div class="sku-attribute-title"><span class="attribute-title">Publisher:</span> <span class="sku-value">2K</span></div> <div class="sku-attribute-title"><span class="attribute-title">SKU:</span> <span class="sku-value">6414078</span></div> <div class="sku-attribute-title"><span class="attribute-title">Release Date:</span> <span class="sku-value">11/12/2020</span></div> <div class="sku-attribute-title"><span class="attribute-title">ESRB Rating<!-- -->:</span> <a href="https://www.esrb.org/ratings/ratings_guide.aspx" rel="noopener noreferrer" target="_blank">E (Everyone)</a></div> </div><div class="ratings-reviews"><div><div class="None" data-version="2.2.19" id="sponsored-listing-ugc-stats-v2">
# 			<link href="https://www.bestbuy.com/~assets/bby/_com/user-generated-content/ugc-stats/dist/client/client-1110f4ac7db3aefa02090b32d5e42780.css" rel="stylesheet"/>
# 			<div class="user-generated-content-ugc-stats"><div class="appContainer size-l" data-reactroot=""><ul class="reviews-stats-list"><li class="ugc-stat customer-review-stats"><a data-track="stats: customerReviews" href="/site/nba-2k21-mamba-forever-edition-playstation-5/6414078.p?skuId=6414078#tabbed-customerreviews"><div class="ugc-ratings-reviews c-ratings-reviews-v4 c-ratings-reviews-v4-size-small"><p class="sr-only">User rating, 4.7 out of 5 stars with 334 reviews.</p><i aria-hidden="true" class="c-stars-wrapper c-stars-wrapper-size-small"><span class="c-stars-container"><svg aria-hidden="true" fill="#C5CBD5" preserveAspectRatio="xMinYMin slice" role="img" viewBox="0 0 87 16"><use href="/~assets/bby/_img/int/plsvgdef-frontend/svg/star-rating-empty.svg#star-rating-empty" xlink:href="/~assets/bby/_img/int/plsvgdef-frontend/svg/star-rating-empty.svg#star-rating-empty"></use></svg></span><span class="c-stars-container" style="width:82.78px;overflow:hidden"><svg aria-hidden="true" fill="#C28400" preserveAspectRatio="xMinYMin slice" role="img" viewBox="0 0 87 16"><use href="/~assets/bby/_img/int/plsvgdef-frontend/svg/star-rating-border.svg#star-rating-border" xlink:href="/~assets/bby/_img/int/plsvgdef-frontend/svg/star-rating-border.svg#star-rating-border"></use></svg></span><span class="c-stars-container" style="width:81.78px;overflow:hidden"><svg aria-hidden="true" fill="#FFE000" preserveAspectRatio="xMinYMin slice" role="img" viewBox="0 0 87 16"><use href="/~assets/bby/_img/int/plsvgdef-frontend/svg/star-rating.svg#star-rating" xlink:href="/~assets/bby/_img/int/plsvgdef-frontend/svg/star-rating.svg#star-rating"></use></svg></span></i><span aria-hidden="true" class="c-reviews-v4">(334)</span></div></a></li></ul></div></div>
# 			<script>
# 			if ('noModule' in HTMLScriptElement.prototype) {
# 				(function(document){
#
# 						var scriptEl = document.createElement('script');
# 						scriptEl.src = 'https://www.bestbuy.com/~assets/bby/_com/user-generated-content/ugc-stats/dist/client/client-1ea693a74909895ff02b232f7026229c.mjs';
# 						scriptEl.type = 'module';
# 						if (window.navigator.userAgent.indexOf("Edge") === -1) {
# 							scriptEl.async = false;
# 						}
# 						document.getElementById('sponsored-listing-ugc-stats-v2').appendChild(scriptEl);
#
# 				})(document);
# 			} else {
# 				(function(document){
#
# 						var scriptEl = document.createElement('script');
# 						scriptEl.src = 'https://www.bestbuy.com/~assets/bby/_com/user-generated-content/ugc-stats/dist/client/client-9e97ddb6f42e381fd8b7551170463ea7.js';
# 						scriptEl.noModule = true;
# 						scriptEl.defer = true;
# 						if (window.navigator.userAgent.indexOf("Edge") === -1) {
# 							scriptEl.async = false;
# 						}
# 						document.getElementById('sponsored-listing-ugc-stats-v2').appendChild(scriptEl);
#
# 				})(document);
# 			}
# 		</script>
# 			<script>
# 			initializer.initializeComponent({"creatorNamespace":"user-generated-content","componentId":"ugc-stats","contractVersion":"v2","componentVersion":"2.2.19"}, 'sponsored-listing-ugc-stats-v2', "{\"app\":{\"device\":{\"isLarge\":true,\"isSmall\":false},\"instanceId\":\"sponsored-listing-ugc-stats-v2\",\"renderStyle\":\"smallStandard\",\"sku\":\"6414078\"},\"exp\":{\"expertStats\":{}},\"metaLayer\":{\"env_assets\":\"https:\\u002F\\u002Fwww.bestbuy.com\\u002F~assets\\u002Fbby\\u002F_com\",\"env_piscesUrl\":\"https:\\u002F\\u002Fpisces.bbystatic.com\",\"env_appServer\":\"https:\\u002F\\u002Fwww.bestbuy.com\"},\"qna\":{\"qnaStats\":{}},\"rnr\":{\"hideEmptyStars\":false,\"histogramsEnabled\":true,\"popoverEnabled\":true,\"reviewsLinkAction\":\"pdp\",\"reviewStats\":{\"sku\":\"6414078\",\"averageOverallRating\":{\"actual\":4.706586826347305,\"rounded\":4.7},\"topRated\":true,\"totalReviewCount\":334,\"verifiedPurchaseCount\":333,\"recommendedCount\":319,\"recommendedPercent\":96,\"distributions\":[{\"distributionCode\":\"RATING\",\"items\":[{\"value\":1,\"count\":4,\"roundedPercent\":1,\"actualPercent\":1.1976047904191616},{\"value\":2,\"count\":5,\"roundedPercent\":2,\"actualPercent\":1.4970059880239521},{\"value\":3,\"count\":8,\"roundedPercent\":2,\"actualPercent\":2.395209580838323},{\"value\":4,\"count\":51,\"roundedPercent\":15,\"actualPercent\":15.269461077844312},{\"value\":5,\"count\":266,\"roundedPercent\":80,\"actualPercent\":79.64071856287426}]}],\"isReviewable\":true,\"rnrStandalonePage\":\"\\u002Fsite\\u002Freviews\\u002Fnba-2k21-mamba-forever-edition-playstation-5\\u002F6414078\",\"writeAReview\":\"\\u002Fsite\\u002Freviews\\u002Fsubmission\\u002F6414078?campaignId=PDP_&return=\",\"rnrAccordion\":\"\\u002Fsite\\u002Fnba-2k21-mamba-forever-edition-playstation-5\\u002F6414078.p?skuId=6414078#tabbed-customerreviews\"},\"variant\":\"\"}}", 'en-US');
# 		</script>
# 		</div></div></div></div><div><div class="fulfillment-container"><div><!-- Route fulfillment.fulfillment-summary.v1 unResolvedParams --></div></div></div><div><div class="sku-list-item-compare-checkbox"><div class="sku-list-item-compare-and-save-container"><div class="sku-list-item-compare-container"><div><div class="None" data-version="1.0.26" id="sponsored-listing-compare-checkbox-v1">
# 			<link href="https://www.bestbuy.com/~assets/bby/_com/shop/compare-checkbox/dist/client/client-8998ea0bcccb5d17bb276950fcc6acad.css" rel="stylesheet"/>
# 			<div class="shop-compare-checkbox"><div class="appContainer" data-reactroot=""><div class="c-checkbox v-medium"><label for="6414078-compare-checkbox"><div class="c-checkbox-brand"><div class="c-checkbox-custom-input"><input id="6414078-compare-checkbox" type="checkbox" value="6414078"/><div class="c-checkbox-focus-ring"></div><svg aria-hidden="true" class="c-checkbox-icon c-checkbox-icon-hidden" role="img" viewBox="0 0 100 100" width="1em"><use href="/~assets/bby/_img/int/plsvgdef-frontend/svg/checkbox-checkmark.svg#checkbox-checkmark" xlink:href="/~assets/bby/_img/int/plsvgdef-frontend/svg/checkbox-checkmark.svg#checkbox-checkmark"></use></svg></div></div>Compare</label></div></div></div>
# 			<script async="" defer="" src="https://www.bestbuy.com/~assets/bby/_com/shop/compare-checkbox/dist/client/client-63d214e52f65f3a5fb79d111bfa22d84.js"></script>
# 			<script>
# 			initializer.initializeComponent({"creatorNamespace":"shop","componentId":"compare-checkbox","contractVersion":"v1","componentVersion":"1.0.26"}, 'sponsored-listing-compare-checkbox-v1', "{\"app\":{\"instanceId\":\"sponsored-listing-compare-checkbox-v1\",\"skuId\":\"6414078\",\"size\":\"medium\",\"plCompareCheckbox\":false,\"isBundled\":false,\"isValidSku\":true},\"disableCompareTray\":false,\"metaLayer\":{\"env_assets\":\"https:\\u002F\\u002Fwww.bestbuy.com\\u002F~assets\\u002Fbby\\u002F_com\",\"env_piscesUrl\":\"https:\\u002F\\u002Fpisces.bbystatic.com\",\"env_appServer\":\"https:\\u002F\\u002Fwww.bestbuy.com\"}}", 'en-US');
# 		</script>
# 		</div></div></div><div class="sku-list-item-save-container"><div><div class="None" data-version="1.2.6" id="sponsored-listing-save-for-later-v1">
# 			<link href="https://assets.bbystatic.com/node-cusoweb/shop/save-for-later/dist/client/client-c8db2c33d5fd81b02ff16cb8c659e496.css" rel="stylesheet"/>
# 			<div class="shop-save-for-later"><div class="appContainer" data-reactroot=""><div class="save-for-later"><button class="save-for-later-save"><img alt="" src="https://assets.bbystatic.com/node-cusoweb/shop/save-for-later/dist/client/images/bc3fd7b891476cb5c74e82497352c6c9.svg"/>Save</button></div></div></div>
# 			<script>
# 			if ('noModule' in document.createElement('script')) {
# 				(function(document){
#
# 						var scriptEl = document.createElement('script');
# 						scriptEl.src = 'https://assets.bbystatic.com/node-cusoweb/shop/save-for-later/dist/client/client-e062236836a6d807d09a1bf4b38465c8.mjs';
# 						scriptEl.type = 'module';
# 						document.getElementById('sponsored-listing-save-for-later-v1').appendChild(scriptEl);
#
# 				})(document);
# 			} else {
# 				(function(document){
#
# 						var scriptEl = document.createElement('script');
# 						scriptEl.src = 'https://assets.bbystatic.com/node-cusoweb/shop/save-for-later/dist/client/client-f612b5949b777abe067f381d0539aaf5.js';
# 						scriptEl.noModule = true;
# 						scriptEl.defer = true;
# 						document.getElementById('sponsored-listing-save-for-later-v1').appendChild(scriptEl);
#
# 				})(document);
# 			}
# 		</script>
# 			<script>
# 			initializer.initializeComponent({"creatorNamespace":"shop","componentId":"save-for-later","contractVersion":"v1","componentVersion":"1.2.6"}, 'sponsored-listing-save-for-later-v1', "{\"app\":{\"instanceId\":\"sponsored-listing-save-for-later-v1\",\"skuId\":\"6414078\",\"entityId\":\"6414078\",\"entityType\":\"SKU\",\"isCombo\":false,\"isSkuInList\":false,\"enableCustomLists\":false,\"tooltipPosition\":\"bottom\"},\"disableSaveForLater\":false,\"metaLayer\":{\"env_assets\":\"https:\\u002F\\u002Fassets.bbystatic.com\\u002Fnode-cusoweb\",\"env_piscesUrl\":\"https:\\u002F\\u002Fpisces.bbystatic.com\",\"env_appServer\":\"https:\\u002F\\u002Fwww.bestbuy.com\"}}", 'en-US');
# 		</script>
# 		</div></div></div></div></div></div></div><div class="price-block"><div class="sku-list-item-price"><div><div class="None" data-version="1.2043.12" id="pricing-price-40241508">
# 			<link href="https://assets.bbystatic.com/pricing/price/dist/client/client-f0a53019ddb5a579f7cdec2dda786b6f.css" rel="stylesheet"/>
# 			<div class="pricing-price"><div class="pricing-price" data-csi-destinationzipcode="None" data-csi-tiercode="None" data-reactroot=""><div class="pricing-lib-price-8-2043-12 price-view-pb priceView-layout-medium" data-bold="false" data-bundledversion="8.2043.12" data-buyingoptionsonly="false" data-context="PLP-PriceBlock" data-disablebuyingoptions="true" data-disabledynamicgvppricing="false" data-disableensureassets="true" data-disablegiftwithpurchase="false" data-disablepricematchguarantee="false" data-disableupdateoncart="false" data-disableusepricewithcart="false" data-easyreplenishprice="false" data-enablealignright="false" data-enablemmtpricing="false" data-enablereference="false" data-fixedheight="false" data-ispricefetching="false" data-layout="medium" data-openboxcondition="" data-openboxfacet="false" data-pricewithbundle="false" data-randomgenerateduniqueid="8376098704109587" data-serverrendering="true" data-showgwp="false" data-skuid="6414078" data-suppressmemberbadges="false" data-suppressrestrictedprice="false" data-unlockedretailoption="false" data-version="8.2043.12" data-viewtype="price"><div class="pricing-price pricing-lib-price-8-2043-12 priceView-price" data-version="8.2043.12"><div class="priceView-price-match-guarantee"><span class="c-overlay-wrapper"><span class="overlayTrigger"><button aria-controls="price-match-guarantee-overlay-id-8376098704109587" aria-expanded="false" class="btn btn-link-unstyled v-medium price-match-guarantee-badge" type="button"> Price Match Guarantee</button></span></span></div><div class=""><div><div><div class="priceView-hero-price priceView-customer-price"><span aria-hidden="true">$99.99</span><span class="sr-only">Your price for this item is $<!-- -->99.99</span></div></div></div></div></div></div></div></div>
# 			<script defer="" src="https://assets.bbystatic.com/pricing/price/dist/client/client-346a9b1de999e1fc1cbb48cd4999858a.js"></script>
# 			<script>
# 			initializer.initializeComponent({"creatorNamespace":"pricing","componentId":"price","contractVersion":"v1","componentVersion":"1.2043.12"}, "pricing-price-40241508", "{\"app\":{\"instanceId\":\"pricing-price-40241508\",\"skuId\":\"6414078\",\"layout\":\"medium\",\"context\":\"PLP-PriceBlock\",\"openBoxCondition\":\"\",\"enableAlignRight\":false,\"enableReference\":false,\"enableMMTPricing\":false,\"openBoxFacet\":\"false\",\"priceDomain\":{\"skuId\":\"6414078\",\"regularPrice\":99.99,\"currentPrice\":99.99,\"priceEventType\":\"regular\",\"totalSavings\":0,\"totalSavingsPercent\":0,\"customerPrice\":99.99,\"isMAP\":false,\"isPriceMatchGuarantee\":true,\"offerQualifiers\":[{\"offerId\":\"395044\",\"offerName\":\"Get free PS5 steelbook with purchase of NBA 2K21 Mamba\",\"offerVersion\":415547,\"offerDiscountType\":\"Free\",\"id\":395044002,\"comOfferType\":\"FREEITEM\",\"comRuleType\":\"10\",\"instanceId\":1,\"offerRevocableOnReturns\":true,\"excludeFromBundleBreakage\":false}],\"giftSkus\":[{\"skuId\":\"6420096\",\"quantity\":1,\"offerId\":\"395044\",\"savings\":0,\"isRequiredWithOffer\":false}],\"totalGiftSavings\":0,\"gspUnitPrice\":99.99,\"dotComDisplayStatus\":\"active\",\"locationId\":\"960\",\"currentAsOfDate\":\"2021-01-05T05:09:05 GMT\"},\"bundlePriceGVPServer\":{},\"mmtItemPriceServerData\":{},\"isPriceFetching\":false,\"priceWithBundle\":false,\"cookies\":{},\"disableDynamicGVPPricing\":false,\"configuration\":{\"allAccessModalNodeId\":\"all-access-modal-content\",\"gifts-with-purchase\":{\"enableInstanceIdInjection\":true,\"disableOfferLinkService\":false,\"features\":{\"clientSideRenderingOnly\":true,\"showNewGWPModalContent\":false}},\"bundle-and-save\":{\"features\":{\"showNewModalContent\":false,\"showNewExperience\":true}},\"customer-account-based-offer\":{\"features\":{\"showNewCABOModalContent\":false}},\"rnPriceBlock\":{\"showRegularGwp\":true,\"showComplexGwp\":true},\"mmtPricing\":true,\"regularPriceThreshold\":0.99,\"features\":{\"caboWhenNotUsePriceWithCart\":true},\"enableComplexGwp\":false,\"gwpEmbedClientSideOnly\":true,\"returnsMessagingState\":\"on\",\"returnsMessagingAB\":[\"CMT\",22,\"8-f\"],\"useDynamicSMPSpacing\":true,\"enablePriceShimmer\":false,\"dynamicPricingContextBlacklist\":[],\"dynamicPricingHrefBlacklist\":[]},\"returnsMessagingProps\":null},\"metaLayer\":{\"env_assets\":\"https:\\u002F\\u002Fassets.bbystatic.com\",\"env_piscesUrl\":\"https:\\u002F\\u002Fpisces.bbystatic.com\"}}", "en-US");
# 		</script>
# 		</div></div></div><div><div></div></div><div class="sku-list-item-button"><div><div><div class="None" data-version="21.0.128" id="sponsored-listing-add-to-cart-button-v1">
#
# 			<div class="fulfillment-add-to-cart-button"><div><div style="position:relative"><button class="btn btn-secondary btn-sm btn-block add-to-cart-button" data-sku-id="6414078" style="padding:0 8px" type="button">Check Stores</button><span id="wait-overlay-6414078"></span><span class="c-overlay-wrapper"><span class="overlayTrigger"><div aria-controls="wait-overlay-6414078" aria-describedby="wait-overlay-6414078" aria-expanded="false" style="width:0;height:0"></div></span></span></div></div></div>
# 			<script defer="" src="https://assets.bbystatic.com/fulfillment/add-to-cart-button/dist/client/client-9942b99c380491d427e87fbf10d35fb4.js"></script>
# 			<script>
# 			initializer.initializeComponent({"creatorNamespace":"fulfillment","componentId":"add-to-cart-button","contractVersion":"v1","componentVersion":"21.0.128"}, "sponsored-listing-add-to-cart-button-v1", "{\"app\":{\"attachModal\":{\"isShowing\":false,\"instanceNumber\":0},\"tests\":{\"sold-out-openbox\":{\"scaled\":true,\"ignore\":false},\"combo-availability-plp\":{\"scaled\":true,\"ignore\":false}},\"storeId\":\"\",\"context\":\"plp\",\"xboxAllAccess\":false,\"instanceId\":\"sponsored-listing-add-to-cart-button-v1\",\"destinationZipCode\":\"\",\"blockLevel\":true,\"size\":\"small\",\"disabled\":false,\"chatForServiceUrl\":\"\\u002Fusw\\u002Fcovertops\",\"learnMoreUrl\":\"\\u002Fsite\\u002Fhome-security-solutions\\u002Fsmart-home\\u002Fpcmcat748302047019.c?id=pcmcat748302047019\",\"attachModalEnabled\":true,\"buttonStateSourceRouteEnabled\":true,\"inHomeConsultationUrl\":\"https:\\u002F\\u002Fwww.bestbuy.com\\u002Fservices\\u002Fin-home-advisor\\u002Fhome\",\"maxComboSkusExceeded\":false,\"soldOutDispatchDisabled\":true,\"reportingVariables\":{},\"pickupTodayStores\":[],\"disasterFallBackLists\":{},\"xboxAllAccessModal\":{\"isShowing\":false,\"instanceNumber\":0},\"skuPdpUrl\":\"\\u002Fsite\\u002Fnba-2k21-mamba-forever-edition-playstation-5\\u002F6414078.p?skuId=6414078\"},\"items\":[{\"skuId\":\"6414078\",\"condition\":null,\"tags\":[\"tag\\u002Fprimary\"]}],\"buttonState\":{\"$__path\":[\"shop\",\"buttonstate\",\"v5\",\"item\",\"optional\",\"skus\",\"6414078\",\"conditions\",\"NONE\",\"destinationZipCode\",\"%20\",\"storeId\",\"%20\",\"storeZipCode\",\"%20\",\"context\",\"plp\",\"addAll\",\"false\",\"consolidated\",\"false\",\"source\",\"buttonView\",\"xboxAllAccess\",\"false\",\"buttonStateResponseInfos\",0],\"buttonState\":\"CHECK_STORES\",\"displayText\":\"Check Stores\"},\"metaLayer\":{\"env_assets\":\"https:\\u002F\\u002Fassets.bbystatic.com\",\"env_piscesUrl\":\"https:\\u002F\\u002Fpisces.bbystatic.com\",\"env_appServer\":\"https:\\u002F\\u002Fwww.bestbuy.com\"}}", "en-US");
# 		</script>
# 		</div></div></div></div><div><!-- Route shop.notify-me.v1 unResolvedParams --></div><div class="buying-options-only"><div><div class="" data-version="1.2043.12" id="pricing-price-87465139">
#
# 			<div class="pricing-price"><div class="pricing-price" data-csi-destinationzipcode="None" data-csi-tiercode="None" data-reactroot=""><div class="pricing-lib-price-8-2043-12 price-view-pb priceView-layout-medium" data-bold="false" data-bundledversion="8.2043.12" data-buyingoptionsonly="true" data-context="PLP-PriceBlock" data-disablebuyingoptions="true" data-disabledynamicgvppricing="false" data-disableensureassets="true" data-disablegiftwithpurchase="false" data-disablepricematchguarantee="false" data-disableupdateoncart="false" data-disableusepricewithcart="false" data-easyreplenishprice="false" data-enablealignright="false" data-enablemmtpricing="false" data-enablereference="false" data-fixedheight="false" data-ispricefetching="false" data-layout="medium" data-openboxcondition="" data-openboxfacet="false" data-pricewithbundle="false" data-randomgenerateduniqueid="7680868086272692" data-serverrendering="true" data-showgwp="false" data-skuid="6414078" data-suppressmemberbadges="false" data-suppressrestrictedprice="false" data-unlockedretailoption="false" data-version="8.2043.12" data-viewtype="price"></div></div></div>
#
# 			<script>
# 			initializer.initializeComponent({"creatorNamespace":"pricing","componentId":"price","contractVersion":"v1","componentVersion":"1.2043.12"}, "pricing-price-87465139", "{\"app\":{\"instanceId\":\"pricing-price-87465139\",\"skuId\":\"6414078\",\"layout\":\"medium\",\"context\":\"PLP-PriceBlock\",\"openBoxCondition\":\"\",\"buyingOptionsOnly\":\"true\",\"enableAlignRight\":false,\"enableReference\":false,\"enableMMTPricing\":false,\"openBoxFacet\":\"false\",\"priceDomain\":{\"skuId\":\"6414078\",\"regularPrice\":99.99,\"currentPrice\":99.99,\"priceEventType\":\"regular\",\"totalSavings\":0,\"totalSavingsPercent\":0,\"customerPrice\":99.99,\"isMAP\":false,\"isPriceMatchGuarantee\":true,\"offerQualifiers\":[{\"offerId\":\"395044\",\"offerName\":\"Get free PS5 steelbook with purchase of NBA 2K21 Mamba\",\"offerVersion\":415547,\"offerDiscountType\":\"Free\",\"id\":395044002,\"comOfferType\":\"FREEITEM\",\"comRuleType\":\"10\",\"instanceId\":1,\"offerRevocableOnReturns\":true,\"excludeFromBundleBreakage\":false}],\"giftSkus\":[{\"skuId\":\"6420096\",\"quantity\":1,\"offerId\":\"395044\",\"savings\":0,\"isRequiredWithOffer\":false}],\"totalGiftSavings\":0,\"gspUnitPrice\":99.99,\"dotComDisplayStatus\":\"active\",\"locationId\":\"960\",\"currentAsOfDate\":\"2021-01-05T05:09:05 GMT\"},\"bundlePriceGVPServer\":{},\"mmtItemPriceServerData\":{},\"isPriceFetching\":false,\"priceWithBundle\":false,\"cookies\":{},\"disableDynamicGVPPricing\":false,\"configuration\":{\"allAccessModalNodeId\":\"all-access-modal-content\",\"gifts-with-purchase\":{\"enableInstanceIdInjection\":true,\"disableOfferLinkService\":false,\"features\":{\"clientSideRenderingOnly\":true,\"showNewGWPModalContent\":false}},\"bundle-and-save\":{\"features\":{\"showNewModalContent\":false,\"showNewExperience\":true}},\"customer-account-based-offer\":{\"features\":{\"showNewCABOModalContent\":false}},\"rnPriceBlock\":{\"showRegularGwp\":true,\"showComplexGwp\":true},\"mmtPricing\":true,\"regularPriceThreshold\":0.99,\"features\":{\"caboWhenNotUsePriceWithCart\":true},\"enableComplexGwp\":false,\"gwpEmbedClientSideOnly\":true,\"returnsMessagingState\":\"on\",\"returnsMessagingAB\":[\"CMT\",22,\"8-f\"],\"useDynamicSMPSpacing\":true,\"enablePriceShimmer\":false,\"dynamicPricingContextBlacklist\":[],\"dynamicPricingHrefBlacklist\":[]},\"returnsMessagingProps\":null},\"metaLayer\":{\"env_assets\":\"https:\\u002F\\u002Fassets.bbystatic.com\",\"env_piscesUrl\":\"https:\\u002F\\u002Fpisces.bbystatic.com\"}}", "en-US");
# 		</script>
# 		</div></div></div></div></div></div></div>
# 			<script defer="" src="/~assets/bby/_com/shop/sku-list-item/dist/client/client-8998434e06e7b5c16367885b06144669.js"></script>
# 			<script>
# 			initializer.initializeComponent({"creatorNamespace":"shop","componentId":"sku-list-item","contractVersion":"v2","componentVersion":"20.16.17"}, "shop-sku-list-item-96a7b744-07c4-41e3-818e-55508563748a", "{\"app\":{\"skuId\":\"6414078\",\"deviceClass\":\"l\",\"instanceId\":\"shop-sku-list-item-96a7b744-07c4-41e3-818e-55508563748a\",\"inViewport\":true,\"isSponsored\":true,\"highlightedVariationSkuId\":\"6414078\",\"lazyLoadOffset\":-400,\"disableFulfillmentForVariation\":false},\"metaLayer\":{\"env_piscesUrl\":\"https:\\u002F\\u002Fpisces.bbystatic.com\",\"env_appServer\":\"https:\\u002F\\u002Fwww.bestbuy.com\"},\"searchDerived\":{\"isOpenBoxFacetSelected\":false},\"sku\":{\"customerRatings\":4.7,\"image\":{\"alt\":\"NBA 2K21 Mamba Forever Edition - PlayStation 5 - Alt_View_Standard_11\",\"src\":\"image2\\u002FBestBuy_US\\u002Fimages\\u002Fproducts\\u002F6414\\u002F6414078cv11a.jpg\"},\"link\":\"\\u002Fsite\\u002Fnba-2k21-mamba-forever-edition-playstation-5\\u002F6414078.p?skuId=6414078\",\"numberOfReviews\":334,\"name\":\"NBA 2K21 Mamba Forever Edition - PlayStation 5\",\"skuId\":\"6414078\",\"publisher\":\"2K\",\"esrbRating\":\"E (Everyone)\",\"releaseDate\":{\"notYetAnnounced\":false,\"date\":\"11\\u002F12\\u002F2020\"},\"isOpenBoxAvailable\":false,\"isNew\":false,\"isOpenBoxOnly\":false,\"detailDisplayText\":\"SEE_MORE_OPTIONS\"}}", "en-US");
# 		</script>
# 		</div></div></div></div></div>
# 			<script>
# 			if ('noModule' in HTMLScriptElement.prototype) {
# 				(function(document){
#
# 						var scriptEl = document.createElement('script');
# 						scriptEl.src = 'https://assets.bbystatic.com/shop/sponsored-listing/dist/client/client-25932b765e4941ba66044b30335d42ef.mjs';
# 						scriptEl.type = 'module';
# 						scriptEl.async = false;
# 						document.getElementById('shop-sponsored-listing-5a692e66-6fc6-4dfc-a80b-72703a25ca59').appendChild(scriptEl);
#
# 				})(document);
# 			} else {
# 				(function(document){
#
# 						var scriptEl = document.createElement('script');
# 						scriptEl.src = 'https://assets.bbystatic.com/shop/sponsored-listing/dist/client/client-75e292fff0cda375c7571254c153c03d.js';
# 						scriptEl.noModule = true;
# 						scriptEl.defer = true;
# 						scriptEl.async = false;
# 						document.getElementById('shop-sponsored-listing-5a692e66-6fc6-4dfc-a80b-72703a25ca59').appendChild(scriptEl);
#
# 				})(document);
# 			}
# 		</script>
# 			<script>
# 			initializer.initializeComponent({"creatorNamespace":"shop","componentId":"sponsored-listing","contractVersion":"v1","componentVersion":"1.0.71"}, 'shop-sponsored-listing-5a692e66-6fc6-4dfc-a80b-72703a25ca59', "{\"app\":{\"instanceId\":\"shop-sponsored-listing-5a692e66-6fc6-4dfc-a80b-72703a25ca59\",\"browsedCategory\":\"pcmcat1587395108347\",\"isSponsored\":\"true\",\"deviceClass\":\"l\",\"rows\":\"24\",\"pageNumber\":\"1\",\"searchTest1\":\" \",\"searchTest2\":\" \",\"searchTest3\":\" \",\"searchTest4\":\" \",\"searchTest5\":\" \",\"searchTest6\":\" \",\"searchTest7\":\" \",\"searchTest8\":\" \",\"sortBy\":\"Best-Selling\",\"tierCode\":\"\",\"skuId\":\"6414078\",\"uuid\":\"32eced241c85828924946d998335007c\",\"loadBeaconURL\":\"\\u002F\\u002Fb.va.us.criteo.com\\u002Fbeacon?fid=100&hl_qs=Qvl5fzLGBDdFpPiGp4UhOrXO%2b8IkUg%2bZa5GGaNg91XXzsBBXhQUSnd28LuITB0WF8oBnfkWJ5s%2b9RYT5Qbp4pepA%2bA3DIUOZgF6Wv9UdOa3eUpvxQy%2bztJXtBSNfICDEMi843m5LjjSzPKiuN7gxAjjBRZrr8b3%2fsr8%2b9aMrP%2f4PQ%2fhibwW5%2f2m1qVT0zrrVBWh3w1HuBXMRG6ANN%2bSH%2fWLTz4X8Me7WeUrO8upjemvlT1f0LB%2bacPMI1erby2%2fEIx28x8AnI2vQwI8ed7XzP8n7rdLvNy5x9AcvW9WSbkArlPXq9LTrBrSY0yIMZACq0caHteD9ibyVXrairZ7FgSGnkKGeVDV5aGC7Y%2bDnX9%2frxFRql2fAoDrG8YDT7fKb4Cjq1aE9Wp%2fh2%2fGBTmtw5M4iqZOjJ0gQJig8Fb3JfCM2GSrnOxXb7EJJU2neesoBLUMy4k3%2bVO%2fajpzRMwSs%2bLaTMg4CwhONfvvJ4CzKHlPNwR6vWYXloODezObKIeatrH6iDzgu3bqu240ZnN%2bJMaenXo83CE5%2bBgjveJGD%2fotOLXzGZz%2fo5D3rIIlnrxLCeSTHmS%2bf5Gi6hW%2bJ9B%2fjrLdF3ouhulfe6Dx69PylCvIkHLqBYI39C80WH2nIIaAxEv7%2b3GZk%2ficU6WDxVr3EBjASKIgp6aET%2fWoCVtMnnAI2NDU%2fElSlMv9f66UD7orG48dcB2VP6rKirAd8MPHkN9WIl36L11pSCHewm7ELmSNHvMBorYpW4is8oVLFsdh5%2bxKTwO%2fdzjlQbMZ0occ2w8npH52WbZohoyAeqrfQolSigHv70VrHbpuwmvBmlLNT3XxSEzuRst2s7a9f4yMObJCw9nAhjYVc1IPqdVT1X5lXajtde8YbepdFQERVCH2NCMlS%2f9vC5%2bLZ3F1Rdh9YY8ZyeiSKD%2fd2%2f4vZKLOtzMn1GbjFdx7i93TArnat22Xs&ev=2&action=page&origc=A&rn=1710750397&puserid=[PUSERID]&pid=[PAGEGUID]\",\"viewBeaconURL\":\"\\u002F\\u002Fb.va.us.criteo.com\\u002Fbeacon?fid=100&hl_qs=Qvl5fzLGBDdFpPiGp4UhOrXO%2b8IkUg%2bZa5GGaNg91XXl6k28FQ00nwUK%2bKc6ef4%2b%2fTxIfPVhY5kF9p%2bz43vhrpgfVDdNoG0avk3fHLId3h85MKnLQTG9Bkc51R4%2fznsv%2fMX27YFO2aY09lj7YfNasXc2w8HH1Tmy0AaQL5eoQxOyNkVsdOfnj2atTy4lpyAzVdDGMuvZxmEXvWEhXBdBbIZ%2ba8seo9zUfJwY6bujf%2b4MWDeDNEpHpKtiUeTp9dYQteo1zN7qfB3yO3TBhlQiifNtXpEp4G6hCANqOUN4hJkIK2jZWGtzwePYcCxiwWdGIikksNYHI4rZXTlJZio4FJh9jQ0ZAey336TnhbBQzxIHx1sVTw5lJPNEv3KyGq%2bKW6NwtBtisIsiMLsLYhDf6066RnE%2bXquYdebDBTjtotEaU1brzQgRTqC1fGLW%2fuvkhnHSWgHePXg%2bIvzEUu5x850exKRhtYFaxc%2b9F6c3KRNt5kSDg%2fKjHZN4VHLozLvCP6X7vEVHEdN8mQ9BOxHQa27w5Z7yXmIp1%2b9qRvUj3lOLK3lJHZhzX9Uz0YWNR0sUCY84ckar12aHpXK2fK0yq%2bumy8a7hVc%2fnTllnwIe6PlE%2f67l43JPLQSC%2fAguAdKU61NBixL07HKJJTHC%2bVaBZFZRHY9fv5NRtSMxrByg2mDI8%2fWat3Kdd2RFvtfB5RHWTPntPdu8Sv7barzmoGCGWtpeRZV0N8EZZ5xNGp420GhKacZLPQpbY42Duei0zWLre8vprBpBE6TkIwY1NIf1LBtzo33KM1UqvPu0uUgx%2fsh7GbY5Vyk18JdYs%2buNHiQ%2fI4G8DDm%2fuKZRaQQ4AbCaA5DlZPDPO%2bOXrTB2TNCdsc8hR4ebu4IcHA%2bY1p2zb847YNOeMY%2bZ9lpaJbT9RVtapUCSA%2f3jW4Zy4g%2bk80VuMW5z7ZZ6MZ4GFknyWWqIfFP6GPuXJehWEx7g5U%2b04%2bBwXgVhvma7%2bIC55OhURaZVBwerRz%2bIzEnVs7UG1JueRhq%2bIP%2bTV3VCpsdI%2fpNVNIvnwtqUMNU5ot8QnqVVy4XLkpTe9jpGj%2fiHPAldO8FxH8ttybBsEwUev5mrDpi9nBmQJJJXFUVuSfvTeAuQOE7xO%2falxqm36y%2fAGD3Mg%2bamAvnJVpCGYgcHMnpqTURmZNfS8I0W9N6QORLtO8Yx%2fneJ0mvo7Wgb7LEqkIzuRO4g%2botEKBfEl8L%2fYukSvJFTPI5kowQiJNzRAxUO4hOcny7OT2U01ackAd9q0u7g3WCiUsb5oPuNqR8eJ%2b1euCcxV4LUVvbBrYp6yBDXxF9sTxEBxVjJlk%2bFPgT31wdsH2lWmy7J&ev=2&action=imp&rn=559303693&puserid=[PUSERID]&pid=[IMPPID]&pageguid=[PAGEGUID]\",\"clickBeaconURL\":\"\\u002F\\u002Fcat.criteo.com\\u002Fbeacon?fid=100&hl_qs=Qvl5fzLGBDdFpPiGp4UhOrXO%2b8IkUg%2bZa5GGaNg91XXl6k28FQ00nwUK%2bKc6ef4%2b%2fTxIfPVhY5kF9p%2bz43vhrpgfVDdNoG0avk3fHLId3h85MKnLQTG9Bkc51R4%2fznsv%2fMX27YFO2aY09lj7YfNasXc2w8HH1Tmy0AaQL5eoQxOyNkVsdOfnj2atTy4lpyAzVdDGMuvZxmEXvWEhXBdBbIZ%2ba8seo9zUfJwY6bujf%2b4MWDeDNEpHpKtiUeTp9dYQteo1zN7qfB3yO3TBhlQiifNtXpEp4G6hCANqOUN4hJnDryUu%2fH36yBdDuN80X0Oh0y9b1zdv8Ark64eTFJD0msVm9Pjn7GyrpLwJDeCHI4CnNHI%2fk2YHV%2f5ZYH5Fb3O ...
# 		</script>
# 		</div></div></li><li class="sku-item" data-sku-id="6432588"><div class="" data-track="[context:listRank=1]"><div><div class="None" data-version="20.16.17" id="shop-sku-list-item-a158b446-4747-4a1f-be33-950ee98028ea">
#
# 			<div class="shop-sku-list-item"><div class="list-item lv" data-sku-id="6432588"><div class="image-column"><a class="image-link" href="/site/immortals-fenyx-rising-standard-edition-playstation-5/6432588.p?skuId=6432588"><img alt="Immortals Fenyx Rising Standard Edition - PlayStation 5 - Front_Zoom" class="product-image" src="https://pisces.bbystatic.com/image2/BestBuy_US/images/products/6432/6432588_sd.jpg;maxHeight=200;maxWidth=300" srcset="https://pisces.bbystatic.com/image2/BestBuy_US/images/products/6432/6432588_sd.jpg;maxHeight=300;maxWidth=450 1.5x"/><div class="detail-display-text"><span data-track="See More Options">See More Options</span></div></a></div><div class="right-column"><div class="information"><div class="embedded-badge"><div></div></div><div><div class="sku-title"><h4 class="sku-header"><a href="/site/immortals-fenyx-rising-standard-edition-playstation-5/6432588.p?skuId=6432588">Immortals Fenyx Rising Standard Edition - PlayStation 5</a></h4></div></div><div class="variation-info"><div class="sku-model"><div class="sku-attribute-title"><span class="attribute-title">Publisher:</span> <span class="sku-value">Ubisoft</span></div> <div class="sku-attribute-title"><span class="attribute-title">SKU:</span> <span class="sku-value">6432588</span></div> <div class="sku-attribute-title"><span class="attribute-title">Release Date:</span> <span class="sku-value">12/03/2020</span></div> <div class="sku-attribute-title"><span class="attribute-title">ESRB Rating<!-- -->:</span> <a href="https://www.esrb.org/ratings/ratings_guide.aspx" rel="noopener noreferrer" target="_blank">T (Teen 13+)</a></div> </div><div class="ratings-reviews"><div><div class="None" data-version="2.2.19" id="user-generated-content-ugc-stats-84671566">
#
# 			<div class="user-generated-content-ugc-stats"><div class="appContainer size-l" data-reactroot=""><ul class="reviews-stats-list"><li class="ugc-stat customer-review-stats"><a data-track="stats: customerReviews" href="/site/immortals-fenyx-rising-standard-edition-playstation-5/6432588.p?skuId=6432588#tabbed-customerreviews"><div class="ugc-ratings-reviews c-ratings-reviews-v4 c-ratings-reviews-v4-size-small"><p class="sr-only">User rating, 4.7 out of 5 stars with 147 reviews.</p><i aria-hidden="true" class="c-stars-wrapper c-stars-wrapper-size-small"><span class="c-stars-container"><svg aria-hidden="true" fill="#C5CBD5" preserveAspectRatio="xMinYMin slice" role="img" viewBox="0 0 87 16"><use href="/~assets/bby/_img/int/plsvgdef-frontend/svg/star-rating-empty.svg#star-rating-empty" xlink:href="/~assets/bby/_img/int/plsvgdef-frontend/svg/star-rating-empty.svg#star-rating-empty"></use></svg></span><span class="c-stars-container" style="width:82.78px;overflow:hidden"><svg aria-hidden="true" fill="#C28400" preserveAspectRatio="xMinYMin slice" role="img" viewBox="0 0 87 16"><use href="/~assets/bby/_img/int/plsvgdef-frontend/svg/star-rating-border.svg#star-rating-border" xlink:href="/~assets/bby/_img/int/plsvgdef-frontend/svg/star-rating-border.svg#star-rating-border"></use></svg></span><span class="c-stars-container" style="width:81.78px;overflow:hidden"><svg aria-hidden="true" fill="#FFE000" preserveAspectRatio="xMinYMin slice" role="img" viewBox="0 0 87 16"><use href="/~assets/bby/_img/int/plsvgdef-frontend/svg/star-rating.svg#star-rating" xlink:href="/~assets/bby/_img/int/plsvgdef-frontend/svg/star-rating.svg#star-rating"></use></svg></span></i><span aria-hidden="true" class="c-reviews-v4">(147)</span></div></a></li></ul></div></div>
# 			<script>
# 			if ('noModule' in HTMLScriptElement.prototype) {
# 				(function(document){
#
# 						var scriptEl = document.createElement('script');
# 						scriptEl.src = 'https://www.bestbuy.com/~assets/bby/_com/user-generated-content/ugc-stats/dist/client/client-1ea693a74909895ff02b232f7026229c.mjs';
# 						scriptEl.type = 'module';
# 						if (window.navigator.userAgent.indexOf("Edge") === -1) {
# 							scriptEl.async = false;
# 						}
# 						document.getElementById('user-generated-content-ugc-stats-84671566').appendChild(scriptEl);
#
# 				})(document);
# 			} else {
# 				(function(document){
#
# 						var scriptEl = document.createElement('script');
# 						scriptEl.src = 'https://www.bestbuy.com/~assets/bby/_com/user-generated-content/ugc-stats/dist/client/client-9e97ddb6f42e381fd8b7551170463ea7.js';
# 						scriptEl.noModule = true;
# 						scriptEl.defer = true;
# 						if (window.navigator.userAgent.indexOf("Edge") === -1) {
# 							scriptEl.async = false;
# 						}
# 						document.getElementById('user-generated-content-ugc-stats-84671566').appendChild(scriptEl);
#
# 				})(document);
# 			}
# 		</script>
# 			<script>
# 			initializer.initializeComponent({"creatorNamespace":"user-generated-content","componentId":"ugc-stats","contractVersion":"v2","componentVersion":"2.2.19"}, 'user-generated-content-ugc-stats-84671566', "{\"app\":{\"device\":{\"isLarge\":true,\"isSmall\":false},\"instanceId\":\"user-generated-content-ugc-stats-84671566\",\"renderStyle\":\"smallStandard\",\"sku\":\"6432588\"},\"exp\":{\"expertStats\":{}},\"metaLayer\":{\"env_assets\":\"https:\\u002F\\u002Fwww.bestbuy.com\\u002F~assets\\u002Fbby\\u002F_com\",\"env_piscesUrl\":\"https:\\u002F\\u002Fpisces.bbystatic.com\",\"env_appServer\":\"https:\\u002F\\u002Fwww.bestbuy.com\"},\"qna\":{\"qnaStats\":{}},\"rnr\":{\"hideEmptyStars\":false,\"histogramsEnabled\":true,\"popoverEnabled\":true,\"reviewsLinkAction\":\"pdp\",\"reviewStats\":{\"sku\":\"6432588\",\"averageOverallRating\":{\"actual\":4.673469387755102,\"rounded\":4.7},\"topRated\":true,\"totalReviewCount\":147,\"verifiedPurchaseCount\":145,\"recommendedCount\":143,\"recommendedPercent\":97,\"distributions\":[{\"distributionCode\":\"RATING\",\"items\":[{\"value\":1,\"count\":0,\"roundedPercent\":0,\"actualPercent\":0},{\"value\":2,\"count\":1,\"roundedPercent\":1,\"actualPercent\":0.6802721088435374},{\"value\":3,\"count\":6,\"roundedPercent\":4,\"actualPercent\":4.081632653061225},{\"value\":4,\"count\":33,\"roundedPercent\":22,\"actualPercent\":22.448979591836736},{\"value\":5,\"count\":107,\"roundedPercent\":73,\"actualPercent\":72.78911564625851}]}],\"isReviewable\":true,\"rnrStandalonePage\":\"\\u002Fsite\\u002Freviews\\u002Fimmortals-fenyx-rising-standard-edition-playstation-5\\u002F6432588\",\"writeAReview\":\"\\u002Fsite\\u002Freviews\\u002Fsubmission\\u002F6432588?campaignId=PDP_&return=\",\"rnrAccordion\":\"\\u002Fsite\\u002Fimmortals-fenyx-rising-standard-edition-playstation-5\\u002F6432588.p?skuId=6432588#tabbed-customerreviews\"},\"variant\":\"\"}}", 'en-US');
# 		</script>
# 		</div></div></div></div><div></div><div></div></div><div class="price-block"><div class="sku-list-item-price"><div><div class="None" data-version="1.2043.12" id="pricing-price-35701337">
#
# 			<div class="pricing-price"><div class="pricing-price" data-csi-destinationzipcode="None" data-csi-tiercode="None" data-reactroot=""><div class="pricing-lib-price-8-2043-12 price-view-pb priceView-layout-medium" data-bold="false" data-bundledversion="8.2043.12" data-buyingoptionsonly="false" data-context="PLP-PriceBlock" data-disablebuyingoptions="true" data-disabledynamicgvppricing="false" data-disableensureassets="true" data-disablegiftwithpurchase="false" data-disablepricematchguarantee="false" data-disableupdateoncart="false" data-disableusepricewithcart="false" data-easyreplenishprice="false" data-enablealignright="false" data-enablemmtpricing="false" data-enablereference="false" data-fixedheight="false" data-ispricefetching="false" data-layout="medium" data-openboxcondition="" data-openboxfacet="false" data-pricewithbundle="false" data-randomgenerateduniqueid="27340806865062084" data-serverrendering="true" data-showgwp="false" data-skuid="6432588" data-suppressmemberbadges="false" data-suppressrestrictedprice="false" data-unlockedretailoption="false" data-version="8.2043.12" data-viewtype="price"><div class="pricing-price pricing-lib-price-8-2043-12 priceView-price" data-version="8.2043.12"><div class="priceView-price-match-guarantee"><span class="c-overlay-wrapper"><span class="overlayTrigger"><button aria-controls="price-match-guarantee-overlay-id-27340806865062084" aria-expanded="false" class="btn btn-link-unstyled v-medium price-match-guarantee-badge" type="button"> Price Match Guarantee</button></span></span></div><div class=""><div><div><div class="priceView-hero-price priceView-customer-price"><span aria-hidden="true">$29.99</span><span class="sr-only">Your price for this item is $<!-- -->29.99</span></div></div><div class="pricing-price__savings-regular-price"><div class="pricing-price__savings">Save $30</div><span><div aria-hidden="true" class="pricing-price__regular-price">Was $59.99</div><div class="pricing-price__regular-price sr-only">The previous price was $59.99</div></span></div></div></div></div></div></div></div>
#
# 			<script>
# 			initializer.initializeComponent({"creatorNamespace":"pricing","componentId":"price","contractVersion":"v1","componentVersion":"1.2043.12"}, "pricing-price-35701337", "{\"app\":{\"instanceId\":\"pricing-price-35701337\",\"skuId\":\"6432588\",\"layout\":\"medium\",\"context\":\"PLP-PriceBlock\",\"openBoxCondition\":\"\",\"enableAlignRight\":false,\"enableReference\":false,\"enableMMTPricing\":false,\"openBoxFacet\":\"false\",\"priceDomain\":{\"skuId\":\"6432588\",\"regularPrice\":59.99,\"currentPrice\":29.99,\"priceEventType\":\"onSale\",\"regularPriceMessageType\":\"WAS\",\"instantSavings\":30,\"totalSavings\":30,\"totalSavingsPercent\":50,\"customerPrice\":29.99,\"isMAP\":false,\"isPriceMatchGuarantee\":true,\"gspUnitPrice\":29.99,\"dotComDisplayStatus\":\"active\",\"locationId\":\"960\",\"currentAsOfDate\":\"2021-01-05T05:12:19 GMT\"},\"bundlePriceGVPServer\":{},\"mmtItemPriceServerData\":{},\"isPriceFetching\":false,\"priceWithBundle\":false,\"cookies\":{},\"disableDynamicGVPPricing\":false,\"configuration\":{\"allAccessModalNodeId\":\"all-access-modal-content\",\"gifts-with-purchase\":{\"enableInstanceIdInjection\":true,\"disableOfferLinkService\":false,\"features\":{\"clientSideRenderingOnly\":true,\"showNewGWPModalContent\":false}},\"bundle-and-save\":{\"features\":{\"showNewModalContent\":false,\"showNewExperience\":true}},\"customer-account-based-offer\":{\"features\":{\"showNewCABOModalContent\":false}},\"rnPriceBlock\":{\"showRegularGwp\":true,\"showComplexGwp\":true},\"mmtPricing\":true,\"regularPriceThreshold\":0.99,\"features\":{\"caboWhenNotUsePriceWithCart\":true},\"enableComplexGwp\":false,\"gwpEmbedClientSideOnly\":true,\"returnsMessagingState\":\"on\",\"returnsMessagingAB\":[\"CMT\",22,\"8-f\"],\"useDynamicSMPSpacing\":true,\"enablePriceShimmer\":false,\"dynamicPricingContextBlacklist\":[],\"dynamicPricingHrefBlacklist\":[]},\"returnsMessagingProps\":null},\"metaLayer\":{\"env_assets\":\"https:\\u002F\\u002Fassets.bbystatic.com\",\"env_piscesUrl\":\"https:\\u002F\\u002Fpisces.bbystatic.com\"}}", "en-US");
# 		</script>
# 		</div></div></div><div></div><div class="sku-list-item-button"><div><div><div class="None" data-version="21.0.128" id="fulfillment-add-to-cart-button-807becc8-be57-4c3d-b291-2b95fd27e66a">
#
# 			<div class="fulfillment-add-to-cart-button"><div><div style="position:relative"><button class="btn btn-primary btn-sm btn-block btn-leading-ficon add-to-cart-button" data-sku-id="6432588" style="padding:0 8px" type="button"><svg aria-hidden="true" role="img" style="width:16px;height:16px;margin-bottom:-2px;margin-right:9px;fill:currentColor" viewBox="0 0 100 100"><use href="/~assets/bby/_img/int/plsvgdef-frontend/svg/cart.svg#cart" xlink:href="/~assets/bby/_img/int/plsvgdef-frontend/svg/cart.svg#cart"></use></svg>Add to Cart</button><span id="wait-overlay-6432588"></span><span class="c-overlay-wrapper"><span class="overlayTrigger"><div aria-controls="wait-overlay-6432588" aria-describedby="wait-overlay-6432588" aria-expanded="false" style="width:0;height:0"></div></span></span></div></div></div>
#
# 			<script>
# 			initializer.initializeComponent({"creatorNamespace":"fulfillment","componentId":"add-to-cart-button","contractVersion":"v1","componentVersion":"21.0.128"}, "fulfillment-add-to-cart-button-807becc8-be57-4c3d-b291-2b95fd27e66a", "{\"app\":{\"attachModal\":{\"isShowing\":false,\"instanceNumber\":0},\"tests\":{\"sold-out-openbox\":{\"scaled\":true,\"ignore\":false},\"combo-availability-plp\":{\"scaled\":true,\"ignore\":false}},\"context\":\"plp\",\"xboxAllAccess\":false,\"instanceId\":\"fulfillment-add-to-cart-button-807becc8-be57-4c3d-b291-2b95fd27e66a\",\"blockLevel\":true,\"size\":\"small\",\"disabled\":false,\"chatForServiceUrl\":\"\\u002Fusw\\u002Fcovertops\",\"learnMoreUrl\":\"\\u002Fsite\\u002Fhome-security-solutions\\u002Fsmart-home\\u002Fpcmcat748302047019.c?id=pcmcat748302047019\",\"attachModalEnabled\":true,\"buttonStateSourceRouteEnabled\":true,\"inHomeConsultationUrl\":\"https:\\u002F\\u002Fwww.bestbuy.com\\u002Fservices\\u002Fin-home-advisor\\u002Fhome\",\"maxComboSkusExceeded\":false,\"soldOutDispatchDisabled\":true,\"reportingVariables\":{},\"pickupTodayStores\":[],\"disasterFallBackLists\":{},\"xboxAllAccessModal\":{\"isShowing\":false,\"instanceNumber\":0},\"skuPdpUrl\":\"\\u002Fsite\\u002Fimmortals-fenyx-rising-standard-edition-playstation-5\\u002F6432588.p?skuId=6432588\"},\"items\":[{\"skuId\":\"6432588\",\"condition\":null,\"tags\":[\"tag\\u002Fprimary\"]}],\"buttonState\":{\"$__path\":[\"shop\",\"buttonstate\",\"v5\",\"item\",\"optional\",\"skus\",\"6432588\",\"conditions\",\"NONE\",\"destinationZipCode\",\"%20\",\"storeId\",\"%20\",\"storeZipCode\",\"%20\",\"context\",\"plp\",\"addAll\",\"false\",\"consolidated\",\"false\",\"source\",\"buttonView\",\"xboxAllAccess\",\"false\",\"buttonStateResponseInfos\",0],\"buttonState\":\"ADD_TO_CART\",\"displayText\":\"Add to Cart\"},\"metaLayer\":{\"env_assets\":\"https:\\u002F\\u002Fassets.bbystatic.com\",\"env_piscesUrl\":\"https:\\u002F\\u002Fpisces.bbystatic.com\",\"env_appServer\":\"https:\\u002F\\u002Fwww.bestbuy.com\"}}", "en-US");
# 		</script>
# 		</div></div></div></div><div></div><div class="buying-options-only"><div><div class="" data-version="1.2043.12" id="pricing-price-89833071">
#
# ...
# 			<script>
# 			if ('noModule' in HTMLScriptElement.prototype) {
# 				(function(document){
#
# 						var scriptEl = document.createElement('script');
# 						scriptEl.src = 'https://www.bestbuy.com/~assets/bby/_com/user-generated-content/ugc-stats/dist/client/client-1ea693a74909895ff02b232f7026229c.mjs';
# 						scriptEl.type = 'module';
# 						if (window.navigator.userAgent.indexOf("Edge") === -1) {
# 							scriptEl.async = false;
# 						}
# 						document.getElementById('user-generated-content-ugc-stats-80503912').appendChild(scriptEl);
#
# 				})(document);
# 			} else {
# 				(function(document){
#
# 						var scriptEl = document.createElement('script');
# 						scriptEl.src = 'https://www.bestbuy.com/~assets/bby/_com/user-generated-content/ugc-stats/dist/client/client-9e97ddb6f42e381fd8b7551170463ea7.js';
# 						scriptEl.noModule = true;
# 						scriptEl.defer = true;
# 						if (window.navigator.userAgent.indexOf("Edge") === -1) {
# 							scriptEl.async = false;
# 						}
# 						document.getElementById('user-generated-content-ugc-stats-80503912').appendChild(scriptEl);
#
# 				})(document);
# 			}
# 		</script>
# 			<script>
# 			initializer.initializeComponent({"creatorNamespace":"user-generated-content","componentId":"ugc-stats","contractVersion":"v2","componentVersion":"2.2.19"}, 'user-generated-content-ugc-stats-80503912', "{\"app\":{\"device\":{\"isLarge\":true,\"isSmall\":false},\"instanceId\":\"user-generated-content-ugc-stats-80503912\",\"renderStyle\":\"smallStandard\",\"sku\":\"6414016\"},\"exp\":{\"expertStats\":{}},\"metaLayer\":{\"env_assets\":\"https:\\u002F\\u002Fwww.bestbuy.com\\u002F~assets\\u002Fbby\\u002F_com\",\"env_piscesUrl\":\"https:\\u002F\\u002Fpisces.bbystatic.com\",\"env_appServer\":\"https:\\u002F\\u002Fwww.bestbuy.com\"},\"qna\":{\"qnaStats\":{}},\"rnr\":{\"hideEmptyStars\":false,\"histogramsEnabled\":true,\"popoverEnabled\":true,\"reviewsLinkAction\":\"pdp\",\"reviewStats\":{\"sku\":\"6414016\",\"averageOverallRating\":{\"actual\":4.81151832460733,\"rounded\":4.8},\"topRated\":true,\"totalReviewCount\":191,\"verifiedPurchaseCount\":190,\"recommendedCount\":187,\"recommendedPercent\":98,\"distributions\":[{\"distributionCode\":\"RATING\",\"items\":[{\"value\":1,\"count\":2,\"roundedPercent\":1,\"actualPercent\":1.0471204188481675},{\"value\":2,\"count\":2,\"roundedPercent\":1,\"actualPercent\":1.0471204188481675},{\"value\":3,\"count\":4,\"roundedPercent\":2,\"actualPercent\":2.094240837696335},{\"value\":4,\"count\":14,\"roundedPercent\":7,\"actualPercent\":7.329842931937173},{\"value\":5,\"count\":169,\"roundedPercent\":89,\"actualPercent\":88.48167539267016}]}],\"isReviewable\":true,\"rnrStandalonePage\":\"\\u002Fsite\\u002Freviews\\u002Fmortal-kombat-11-ultimate-edition-playstation-5\\u002F6414016\",\"writeAReview\":\"\\u002Fsite\\u002Freviews\\u002Fsubmission\\u002F6414016?campaignId=PDP_&return=\",\"rnrAccordion\":\"\\u002Fsite\\u002Fmortal-kombat-11-ultimate-edition-playstation-5\\u002F6414016.p?skuId=6414016#tabbed-customerreviews\"},\"variant\":\"\"}}", 'en-US');
# 		</script>
# 		</div></div></div></div><div></div><div></div></div><div class="price-block"><div class="sku-list-item-price"><div><div class="None" data-version="1.2043.12" id="pricing-price-77881252">
#
# 			<div class="pricing-price"><div class="pricing-price" data-csi-destinationzipcode="None" data-csi-tiercode="None" data-reactroot=""><div class="pricing-lib-price-8-2043-12 price-view-pb priceView-layout-medium" data-bold="false" data-bundledversion="8.2043.12" data-buyingoptionsonly="false" data-context="PLP-PriceBlock" data-disablebuyingoptions="true" data-disabledynamicgvppricing="false" data-disableensureassets="true" data-disablegiftwithpurchase="false" data-disablepricematchguarantee="false" data-disableupdateoncart="false" data-disableusepricewithcart="false" data-easyreplenishprice="false" data-enablealignright="false" data-enablemmtpricing="false" data-enablereference="false" data-fixedheight="false" data-ispricefetching="false" data-layout="medium" data-openboxcondition="" data-openboxfacet="false" data-pricewithbundle="false" data-randomgenerateduniqueid="6915088666926814" data-serverrendering="true" data-showgwp="false" data-skuid="6414016" data-suppressmemberbadges="false" data-suppressrestrictedprice="false" data-unlockedretailoption="false" data-version="8.2043.12" data-viewtype="price"><div class="pricing-price pricing-lib-price-8-2043-12 priceView-price" data-version="8.2043.12"><div class="priceView-price-match-guarantee"><span class="c-overlay-wrapper"><span class="overlayTrigger"><button aria-controls="price-match-guarantee-overlay-id-6915088666926814" aria-expanded="false" class="btn btn-link-unstyled v-medium price-match-guarantee-badge" type="button"> Price Match Guarantee</button></span></span></div><div class=""><div><div><div class="priceView-hero-price priceView-customer-price"><span aria-hidden="true">$59.99</span><span class="sr-only">Your price for this item is $<!-- -->59.99</span></div></div></div></div></div></div></div></div>
#
# 			<script>
# 			initializer.initializeComponent({"creatorNamespace":"pricing","componentId":"price","contractVersion":"v1","componentVersion":"1.2043.12"}, "pricing-price-77881252", "{\"app\":{\"instanceId\":\"pricing-price-77881252\",\"skuId\":\"6414016\",\"layout\":\"medium\",\"context\":\"PLP-PriceBlock\",\"openBoxCondition\":\"\",\"enableAlignRight\":false,\"enableReference\":false,\"enableMMTPricing\":false,\"openBoxFacet\":\"false\",\"priceDomain\":{\"skuId\":\"6414016\",\"regularPrice\":59.99,\"currentPrice\":59.99,\"priceEventType\":\"regular\",\"totalSavings\":0,\"totalSavingsPercent\":0,\"customerPrice\":59.99,\"isMAP\":false,\"isPriceMatchGuarantee\":true,\"gspUnitPrice\":59.99,\"dotComDisplayStatus\":\"active\",\"locationId\":\"960\",\"currentAsOfDate\":\"2021-01-05T05:11:26 GMT\"},\"bundlePriceGVPServer\":{},\"mmtItemPriceServerData\":{},\"isPriceFetching\":false,\"priceWithBundle\":false,\"cookies\":{},\"disableDynamicGVPPricing\":false,\"configuration\":{\"allAccessModalNodeId\":\"all-access-modal-content\",\"gifts-with-purchase\":{\"enableInstanceIdInjection\":true,\"disableOfferLinkService\":false,\"features\":{\"clientSideRenderingOnly\":true,\"showNewGWPModalContent\":false}},\"bundle-and-save\":{\"features\":{\"showNewModalContent\":false,\"showNewExperience\":true}},\"customer-account-based-offer\":{\"features\":{\"showNewCABOModalContent\":false}},\"rnPriceBlock\":{\"showRegularGwp\":true,\"showComplexGwp\":true},\"mmtPricing\":true,\"regularPriceThreshold\":0.99,\"features\":{\"caboWhenNotUsePriceWithCart\":true},\"enableComplexGwp\":false,\"gwpEmbedClientSideOnly\":true,\"returnsMessagingState\":\"on\",\"returnsMessagingAB\":[\"CMT\",22,\"8-f\"],\"useDynamicSMPSpacing\":true,\"enablePriceShimmer\":false,\"dynamicPricingContextBlacklist\":[],\"dynamicPricingHrefBlacklist\":[]},\"returnsMessagingProps\":null},\"metaLayer\":{\"env_assets\":\"https:\\u002F\\u002Fassets.bbystatic.com\",\"env_piscesUrl\":\"https:\\u002F\\u002Fpisces.bbystatic.com\"}}", "en-US");
# 		</script>
# 		</div></div></div><div></div><div class="sku-list-item-button"><div><div><div class="None" data-version="21.0.128" id="fulfillment-add-to-cart-button-53c65a08-43f1-4e55-a6ee-df8bc69684e4">
#
# 			<div class="fulfillment-add-to-cart-button"><div><div style="position:relative"><button class="btn btn-primary btn-sm btn-block btn-leading-ficon add-to-cart-button" data-sku-id="6414016" style="padding:0 8px" type="button"><svg aria-hidden="true" role="img" style="width:16px;height:16px;margin-bottom:-2px;margin-right:9px;fill:currentColor" viewBox="0 0 100 100"><use href="/~assets/bby/_img/int/plsvgdef-frontend/svg/cart.svg#cart" xlink:href="/~assets/bby/_img/int/plsvgdef-frontend/svg/cart.svg#cart"></use></svg>Add to Cart</button><span id="wait-overlay-6414016"></span><span class="c-overlay-wrapper"><span class="overlayTrigger"><div aria-controls="wait-overlay-6414016" aria-describedby="wait-overlay-6414016" aria-expanded="false" style="width:0;height:0"></div></span></span></div></div></div>
#
# 			<script>
# 			initializer.initializeComponent({"creatorNamespace":"fulfillment","componentId":"add-to-cart-button","contractVersion":"v1","componentVersion":"21.0.128"}, "fulfillment-add-to-cart-button-53c65a08-43f1-4e55-a6ee-df8bc69684e4", "{\"app\":{\"attachModal\":{\"isShowing\":false,\"instanceNumber\":0},\"tests\":{\"sold-out-openbox\":{\"scaled\":true,\"ignore\":false},\"combo-availability-plp\":{\"scaled\":true,\"ignore\":false}},\"context\":\"plp\",\"xboxAllAccess\":false,\"instanceId\":\"fulfillment-add-to-cart-button-53c65a08-43f1-4e55-a6ee-df8bc69684e4\",\"blockLevel\":true,\"size\":\"small\",\"disabled\":false,\"chatForServiceUrl\":\"\\u002Fusw\\u002Fcovertops\",\"learnMoreUrl\":\"\\u002Fsite\\u002Fhome-security-solutions\\u002Fsmart-home\\u002Fpcmcat748302047019.c?id=pcmcat748302047019\",\"attachModalEnabled\":true,\"buttonStateSourceRouteEnabled\":true,\"inHomeConsultationUrl\":\"https:\\u002F\\u002Fwww.bestbuy.com\\u002Fservices\\u002Fin-home-advisor\\u002Fhome\",\"maxComboSkusExceeded\":false,\"soldOutDispatchDisabled\":true,\"reportingVariables\":{},\"pickupTodayStores\":[],\"disasterFallBackLists\":{},\"xboxAllAccessModal\":{\"isShowing\":false,\"instanceNumber\":0},\"skuPdpUrl\":\"\\u002Fsite\\u002Fmortal-kombat-11-ultimate-edition-playstation-5\\u002F6414016.p?skuId=6414016\"},\"items\":[{\"skuId\":\"6414016\",\"condition\":null,\"tags\":[\"tag\\u002Fprimary\"]}],\"buttonState\":{\"$__path\":[\"shop\",\"buttonstate\",\"v5\",\"item\",\"optional\",\"skus\",\"6414016\",\"conditions\",\"NONE\",\"destinationZipCode\",\"%20\",\"storeId\",\"%20\",\"storeZipCode\",\"%20\",\"context\",\"plp\",\"addAll\",\"false\",\"consolidated\",\"false\",\"source\",\"buttonView\",\"xboxAllAccess\",\"false\",\"buttonStateResponseInfos\",0],\"buttonState\":\"ADD_TO_CART\",\"displayText\":\"Add to Cart\"},\"metaLayer\":{\"env_assets\":\"https:\\u002F\\u002Fassets.bbystatic.com\",\"env_piscesUrl\":\"https:\\u002F\\u002Fpisces.bbystatic.com\",\"env_appServer\":\"https:\\u002F\\u002Fwww.bestbuy.com\"}}", "en-US");
# 		</script>
# 		</div></div></div></div><div></div><div class="buying-options-only"><div><div class="" data-version="1.2043.12" id="pricing-price-2261336">
#
# 			<div class="pricing-price"><div class="pricing-price" data-csi-destinationzipcode="None" data-csi-tiercode="None" data-reactroot=""><div class="pricing-lib-price-8-2043-12 price-view-pb priceView-layout-medium" data-bold="false" data-bundledversion="8.2043.12" data-buyingoptionsonly="true" data-context="PLP-PriceBlock" data-disablebuyingoptions="true" data-disabledynamicgvppricing="false" data-disableensureassets="true" data-disablegiftwithpurchase="false" data-disablepricematchguarantee="false" data-disableupdateoncart="false" data-disableusepricewithcart="false" data-easyreplenishprice="false" data-enablealignright="false" data-enablemmtpricing="false" data-enablereference="false" data-fixedheight="false" data-ispricefetching="false" data-layout="medium" data-openboxcondition="" data-openboxfacet="false" data-pricewithbundle="false" data-randomgenerateduniqueid="8541438289898411" data-serverrendering="true" data-showgwp="false" data-skuid="6414016" data-suppressmemberbadges="false" data-suppressrestrictedprice="false" data-unlockedretailoption="false" data-version="8.2043.12" data-viewtype="price"></div></div></div>
#
# 			<script>
# 			initializer.initializeComponent({"creatorNamespace":"pricing","componentId":"price","contractVersion":"v1","componentVersion":"1.2043.12"}, "pricing-price-2261336", "{\"app\":{\"instanceId\":\"pricing-price-2261336\",\"skuId\":\"6414016\",\"layout\":\"medium\",\"context\":\"PLP-PriceBlock\",\"openBoxCondition\":\"\",\"buyingOptionsOnly\":\"true\",\"enableAlignRight\":false,\"enableReference\":false,\"enableMMTPricing\":false,\"openBoxFacet\":\"false\",\"priceDomain\":{\"skuId\":\"6414016\",\"regularPrice\":59.99,\"currentPrice\":59.99,\"priceEventType\":\"regular\",\"totalSavings\":0,\"totalSavingsPercent\":0,\"customerPrice\":59.99,\"isMAP\":false,\"isPriceMatchGuarantee\":true,\"gspUnitPrice\":59.99,\"dotComDisplayStatus\":\"active\",\"locationId\":\"960\",\"currentAsOfDate\":\"2021-01-05T05:11:26 GMT\"},\"bundlePriceGVPServer\":{},\"mmtItemPriceServerData\":{},\"isPriceFetching\":false,\"priceWithBundle\":false,\"cookies\":{},\"disableDynamicGVPPricing\":false,\"configuration\":{\"allAccessModalNodeId\":\"all-access-modal-content\",\"gifts-with-purchase\":{\"enableInstanceIdInjection\":true,\"disableOfferLinkService\":false,\"features\":{\"clientSideRenderingOnly\":true,\"showNewGWPModalContent\":false}},\"bundle-and-save\":{\"features\":{\"showNewModalContent\":false,\"showNewExperience\":true}},\"customer-account-based-offer\":{\"features\":{\"showNewCABOModalContent\":false}},\"rnPriceBlock\":{\"showRegularGwp\":true,\"showComplexGwp\":true},\"mmtPricing\":true,\"regularPriceThreshold\":0.99,\"features\":{\"caboWhenNotUsePriceWithCart\":true},\"enableComplexGwp\":false,\"gwpEmbedClientSideOnly\":true,\"returnsMessagingState\":\"on\",\"returnsMessagingAB\":[\"CMT\",22,\"8-f\"],\"useDynamicSMPSpacing\":true,\"enablePriceShimmer\":false,\"dynamicPricingContextBlacklist\":[],\"dynamicPricingHrefBlacklist\":[]},\"returnsMessagingProps\":null},\"metaLayer\":{\"env_assets\":\"https:\\u002F\\u002Fassets.bbystatic.com\",\"env_piscesUrl\":\"https:\\u002F\\u002Fpisces.bbystatic.com\"}}", "en-US");
# 		</script>
# 		</div></div></div></div></div></div></div>
#
# 			<script>
# 			initializer.initializeComponent({"creatorNamespace":"shop","componentId":"sku-list-item","contractVersion":"v2","componentVersion":"20.16.17"}, "shop-sku-list-item-183dd6dc-cb9f-4433-b3ce-63cd860a4e8c", "{\"app\":{\"skuId\":\"6414016\",\"deviceClass\":\"l\",\"instanceId\":\"shop-sku-list-item-183dd6dc-cb9f-4433-b3ce-63cd860a4e8c\",\"inViewport\":false,\"isSponsored\":false,\"variationId\":\"d13057a2-a346-41bd-8424-0c946c92c8c8\",\"highlightedVariationSkuId\":\"6414016\",\"lazyLoadOffset\":-400,\"disableFulfillmentForVariation\":false},\"metaLayer\":{\"env_piscesUrl\":\"https:\\u002F\\u002Fpisces.bbystatic.com\",\"env_appServer\":\"https:\\u002F\\u002Fwww.bestbuy.com\"},\"searchDerived\":{\"isOpenBoxFacetSelected\":false},\"sku\":{\"customerRatings\":4.8,\"image\":{\"alt\":\"Mortal Kombat 11: Ultimate Edition - PlayStation 5 - Front_Zoom\",\"src\":\"image2\\u002FBestBuy_US\\u002Fimages\\u002Fproducts\\u002F6414\\u002F6414016_sd.jpg\"},\"link\":\"\\u002Fsite\\u002Fmortal-kombat-11-ultimate-edition-playstation-5\\u002F6414016.p?skuId=6414016\",\"numberOfReviews\":191,\"name\":\"Mortal Kombat 11: Ultimate Edition - PlayStation 5\",\"skuId\":\"6414016\",\"publisher\":\"Warner Bros. Games\",\"esrbRating\":\"M (Mature 17+)\",\"releaseDate\":{\"notYetAnnounced\":false,\"date\":\"11\\u002F17\\u002F2020\"},\"isOpenBoxAvailable\":false,\"isNew\":false,\"isOpenBoxOnly\":false,\"productVariation\":{\"variationSkuList\":[{\"skuId\":\"6414016\",\"image\":null,\"link\":\"https:\\u002F\\u002Fwww.bestbuy.com\\u002Fsite\\u002Fmortal-kombat-11-ultimate-edition-playstation-5\\u002F6414016.p?skuId=6414016\",\"name\":\"Mortal Kombat 11: Ultimate Edition - PlayStation 5\",\"hoverName\":\"PlayStation 5\"},{\"skuId\":\"6414030\",\"image\":null,\"link\":\"https:\\u002F\\u002Fwww.bestbuy.com\\u002Fsite\\u002Fmortal-kombat-11-ultimate-edition-xbox-one-xbox-series-x\\u002F6414030.p?skuId=6414030\",\"name\":\"Mortal Kombat 11: Ultimate Edition - Xbox One, Xbox Series X\",\"hoverName\":\"Xbox One \\u002F Xbox Series X\"}],\"variationName\":\"Platform\"},\"detailDisplayText\":\"SEE_MORE_OPTIONS\"}}", "en-US");
# 		</script>
# 		</div></div></div></li></ol>

# %%
each_item = items.find_all(class_ = "sku-item")
each_item
# Out:
# [<div class="appContainer sku-item" data-reactroot=""><div data-click-beacon="//cat.criteo.com/beacon?fid=100&amp;hl_qs=Qvl5fzLGBDdFpPiGp4UhOrXO%2b8IkUg%2bZa5GGaNg91XXl6k28FQ00nwUK%2bKc6ef4%2b%2fTxIfPVhY5kF9p%2bz43vhrpgfVDdNoG0avk3fHLId3h85MKnLQTG9Bkc51R4%2fznsv%2fMX27YFO2aY09lj7YfNasXc2w8HH1Tmy0AaQL5eoQxOyNkVsdOfnj2atTy4lpyAzVdDGMuvZxmEXvWEhXBdBbIZ%2ba8seo9zUfJwY6bujf%2b4MWDeDNEpHpKtiUeTp9dYQteo1zN7qfB3yO3TBhlQiifNtXpEp4G6hCANqOUN4hJnDryUu%2fH36yBdDuN80X0Oh0y9b1zdv8Ark64eTFJD0msVm9Pjn7GyrpLwJDeCHI4CnNHI%2fk2YHV%2f5ZYH5Fb3OGvkX%2fqne4Ec0TnlEk1Wx1Z4uAxK9Grxi2d8dU%2bX%2fT6xALrHFPBtMkPBOoYjzCaRAQuRYmEOvqjDA%2fuct67MQDdTgHr7SNV0tajCb7SRrIzhxeNOQAtKF1e57eBu%2fSppqYGpc2LkdFr0s7zG8My9HkZ9gC0Vi9LvnJHAjZ78vPLeNTM%2fG7jvaUAaNLXVsy8TM63axVJEw0R%2f48U73mdvjRM1EMygjPW6%2fFC2pyJnW3HJeJHqlX4985ZMTDlc6Q4xU53HarJKi1jrcdY23oaiSqPsTxbNfgK%2fxuJsBw6GezoNDUcOqnZrqdNLVZbDPlB%2f4kvVMKbOP2eBWaF5g91Dk2Abs6gPxsEEfwkVeDUIhecfW7wmDn9AIT0T9rT0%2bDMntT%2bS668hpvfJO3dSi11glJIiNZW3TMurxi4wfXPXcQ9cMnlfU%2bfuWMD4WuUAdNuKEq2vmaeI2m%2fE51a4G%2bAg8ACf4eeSRkhkXI6KrySJb%2fY0FSBr6IwuA%2bxi5xW8kEUsRwnrcmW4XTCmrH1DZKcU231tw2%2fXbpNoshbsHtTAdSxWnmDiRcZWeQEFCRQCU7018GfoUPe2KqayFtgFQPXiudT1MKbII0%2buU6IrKtIOh1udZcyuBd8cMhizOzwRWAC2zFnKfRMKY6z8b4hgsqtBJD9I7TPkOI%2fGNAbEfudlPJ3DyqXOMaZeV58HnFUIVJZfCEqbLKtr0QEyr4gD3J4TfZvCLvjLqN%2fmUU0MU4OEGs1PKpv7Mz8o4XIDkFOcNsYOz6FxtBW5%2f%2fuqaHOj5BXnpIWg%3d%3d&amp;ev=2&amp;action=click&amp;rn=586061695&amp;puserid=[PUSERID]&amp;pid=[CLICKPID]&amp;impressionpid=[IMPPID]&amp;pageguid=[PAGEGUID]" data-load-beacon="//b.va.us.criteo.com/beacon?fid=100&amp;hl_qs=Qvl5fzLGBDdFpPiGp4UhOrXO%2b8IkUg%2bZa5GGaNg91XXzsBBXhQUSnd28LuITB0WF8oBnfkWJ5s%2b9RYT5Qbp4pepA%2bA3DIUOZgF6Wv9UdOa3eUpvxQy%2bztJXtBSNfICDEMi843m5LjjSzPKiuN7gxAjjBRZrr8b3%2fsr8%2b9aMrP%2f4PQ%2fhibwW5%2f2m1qVT0zrrVBWh3w1HuBXMRG6ANN%2bSH%2fWLTz4X8Me7WeUrO8upjemvlT1f0LB%2bacPMI1erby2%2fEIx28x8AnI2vQwI8ed7XzP8n7rdLvNy5x9AcvW9WSbkArlPXq9LTrBrSY0yIMZACq0caHteD9ibyVXrairZ7FgSGnkKGeVDV5aGC7Y%2bDnX9%2frxFRql2fAoDrG8YDT7fKb4Cjq1aE9Wp%2fh2%2fGBTmtw5M4iqZOjJ0gQJig8Fb3JfCM2GSrnOxXb7EJJU2neesoBLUMy4k3%2bVO%2fajpzRMwSs%2bLaTMg4CwhONfvvJ4CzKHlPNwR6vWYXloODezObKIeatrH6iDzgu3bqu240ZnN%2bJMaenXo83CE5%2bBgjveJGD%2fotOLXzGZz%2fo5D3rIIlnrxLCeSTHmS%2bf5Gi6hW%2bJ9B%2fjrLdF3ouhulfe6Dx69PylCvIkHLqBYI39C80WH2nIIaAxEv7%2b3GZk%2ficU6WDxVr3EBjASKIgp6aET%2fWoCVtMnnAI2NDU%2fElSlMv9f66UD7orG48dcB2VP6rKirAd8MPHkN9WIl36L11pSCHewm7ELmSNHvMBorYpW4is8oVLFsdh5%2bxKTwO%2fdzjlQbMZ0occ2w8npH52WbZohoyAeqrfQolSigHv70VrHbpuwmvBmlLNT3XxSEzuRst2s7a9f4yMObJCw9nAhjYVc1IPqdVT1X5lXajtde8YbepdFQERVCH2NCMlS%2f9vC5%2bLZ3F1Rdh9YY8ZyeiSKD%2fd2%2f4vZKLOtzMn1GbjFdx7i93TArnat22Xs&amp;ev=2&amp;action=page&amp;origc=A&amp;rn=1710750397&amp;puserid=[PUSERID]&amp;pid=[PAGEGUID]" data-sponsored-variant="B" data-view-beacon="//b.va.us.criteo.com/beacon?fid=100&amp;hl_qs=Qvl5fzLGBDdFpPiGp4UhOrXO%2b8IkUg%2bZa5GGaNg91XXl6k28FQ00nwUK%2bKc6ef4%2b%2fTxIfPVhY5kF9p%2bz43vhrpgfVDdNoG0avk3fHLId3h85MKnLQTG9Bkc51R4%2fznsv%2fMX27YFO2aY09lj7YfNasXc2w8HH1Tmy0AaQL5eoQxOyNkVsdOfnj2atTy4lpyAzVdDGMuvZxmEXvWEhXBdBbIZ%2ba8seo9zUfJwY6bujf%2b4MWDeDNEpHpKtiUeTp9dYQteo1zN7qfB3yO3TBhlQiifNtXpEp4G6hCANqOUN4hJkIK2jZWGtzwePYcCxiwWdGIikksNYHI4rZXTlJZio4FJh9jQ0ZAey336TnhbBQzxIHx1sVTw5lJPNEv3KyGq%2bKW6NwtBtisIsiMLsLYhDf6066RnE%2bXquYdebDBTjtotEaU1brzQgRTqC1fGLW%2fuvkhnHSWgHePXg%2bIvzEUu5x850exKRhtYFaxc%2b9F6c3KRNt5kSDg%2fKjHZN4VHLozLvCP6X7vEVHEdN8mQ9BOxHQa27w5Z7yXmIp1%2b9qRvUj3lOLK3lJHZhzX9Uz0YWNR0sUCY84ckar12aHpXK2fK0yq%2bumy8a7hVc%2fnTllnwIe6PlE%2f67l43JPLQSC%2fAguAdKU61NBixL07HKJJTHC%2bVaBZFZRHY9fv5NRtSMxrByg2mDI8%2fWat3Kdd2RFvtfB5RHWTPntPdu8Sv7barzmoGCGWtpeRZV0N8EZZ5xNGp420GhKacZLPQpbY42Duei0zWLre8vprBpBE6TkIwY1NIf1LBtzo33KM1UqvPu0uUgx%2fsh7GbY5Vyk18JdYs%2buNHiQ%2fI4G8DDm%2fuKZRaQQ4AbCaA5DlZPDPO%2bOXrTB2TNCdsc8hR4ebu4IcHA%2bY1p2zb847YNOeMY%2bZ9lpaJbT9RVtapUCSA%2f3jW4Zy4g%2bk80VuMW5z7ZZ6MZ4GFknyWWqIfFP6GPuXJehWEx7g5U%2b04%2bBwXgVhvma7%2bIC55OhURaZVBwerRz%2bIzEnVs7UG1JueRhq%2bIP%2bTV3VCpsdI%2fpNVNIvnwtqUMNU5ot8QnqVVy4XLkpTe9jpGj%2fiHPAldO8FxH8ttybBsEwUev5mrDpi9nBmQJJJXFUVuSfvTeA ...
#  			<link href="/~assets/bby/_com/shop/sku-list-item/dist/client/client-7ff3a8f671724a3da9f40a24734a4b73.css" rel="stylesheet"/>
#  			<div class="shop-sku-list-item"><div class="list-item lv" data-sku-id="6414078"><div class="image-column"><a class="image-link" href="/site/nba-2k21-mamba-forever-edition-playstation-5/6414078.p?skuId=6414078"><img alt="NBA 2K21 Mamba Forever Edition - PlayStation 5 - Alt_View_Standard_11" class="product-image" src="https://pisces.bbystatic.com/image2/BestBuy_US/images/products/6414/6414078cv11a.jpg;maxHeight=200;maxWidth=300" srcset="https://pisces.bbystatic.com/image2/BestBuy_US/images/products/6414/6414078cv11a.jpg;maxHeight=300;maxWidth=450 1.5x"/><div class="detail-display-text"><span data-track="See More Options">See More Options</span></div></a></div><div class="right-column"><div class="information"><div class="is-sponsored">Sponsored</div><div class="embedded-badge"><div><div></div></div></div><div><div class="sku-title"><h4 class="sku-header"><a href="/site/nba-2k21-mamba-forever-edition-playstation-5/6414078.p?skuId=6414078">NBA 2K21 Mamba Forever Edition - PlayStation 5</a></h4></div></div><div class="variation-info"><div class="sku-model"><div class="sku-attribute-title"><span class="attribute-title">Publisher:</span> <span class="sku-value">2K</span></div> <div class="sku-attribute-title"><span class="attribute-title">SKU:</span> <span class="sku-value">6414078</span></div> <div class="sku-attribute-title"><span class="attribute-title">Release Date:</span> <span class="sku-value">11/12/2020</span></div> <div class="sku-attribute-title"><span class="attribute-title">ESRB Rating<!-- -->:</span> <a href="https://www.esrb.org/ratings/ratings_guide.aspx" rel="noopener noreferrer" target="_blank">E (Everyone)</a></div> </div><div class="ratings-reviews"><div><div class="None" data-version="2.2.19" id="sponsored-listing-ugc-stats-v2">
#  			<link href="https://www.bestbuy.com/~assets/bby/_com/user-generated-content/ugc-stats/dist/client/client-1110f4ac7db3aefa02090b32d5e42780.css" rel="stylesheet"/>
#  			<div class="user-generated-content-ugc-stats"><div class="appContainer size-l" data-reactroot=""><ul class="reviews-stats-list"><li class="ugc-stat customer-review-stats"><a data-track="stats: customerReviews" href="/site/nba-2k21-mamba-forever-edition-playstation-5/6414078.p?skuId=6414078#tabbed-customerreviews"><div class="ugc-ratings-reviews c-ratings-reviews-v4 c-ratings-reviews-v4-size-small"><p class="sr-only">User rating, 4.7 out of 5 stars with 334 reviews.</p><i aria-hidden="true" class="c-stars-wrapper c-stars-wrapper-size-small"><span class="c-stars-container"><svg aria-hidden="true" fill="#C5CBD5" preserveAspectRatio="xMinYMin slice" role="img" viewBox="0 0 87 16"><use href="/~assets/bby/_img/int/plsvgdef-frontend/svg/star-rating-empty.svg#star-rating-empty" xlink:href="/~assets/bby/_img/int/plsvgdef-frontend/svg/star-rating-empty.svg#star-rating-empty"></use></svg></span><span class="c-stars-container" style="width:82.78px;overflow:hidden"><svg aria-hidden="true" fill="#C28400" preserveAspectRatio="xMinYMin slice" role="img" viewBox="0 0 87 16"><use href="/~assets/bby/_img/int/plsvgdef-frontend/svg/star-rating-border.svg#star-rating-border" xlink:href="/~assets/bby/_img/int/plsvgdef-frontend/svg/star-rating-border.svg#star-rating-border"></use></svg></span><span class="c-stars-container" style="width:81.78px;overflow:hidden"><svg aria-hidden="true" fill="#FFE000" preserveAspectRatio="xMinYMin slice" role="img" viewBox="0 0 87 16"><use href="/~assets/bby/_img/int/plsvgdef-frontend/svg/star-rating.svg#star-rating" xlink:href="/~assets/bby/_img/int/plsvgdef-frontend/svg/star-rating.svg#star-rating"></use></svg></span></i><span aria-hidden="true" class="c-reviews-v4">(334)</span></div></a></li></ul></div></div>
#  			<script>
#  			if ('noModule' in HTMLScriptElement.prototype) {
#  				(function(document){
#
#  						var scriptEl = document.createElement('script');
#  						scriptEl.src = 'https://www.bestbuy.com/~assets/bby/_com/user-generated-content/ugc-stats/dist/client/client-1ea693a74909895ff02b232f7026229c.mjs';
#  						scriptEl.type = 'module';
#  						if (window.navigator.userAgent.indexOf("Edge") === -1) {
#  							scriptEl.async = false;
#  						}
#  						document.getElementById('sponsored-listing-ugc-stats-v2').appendChild(scriptEl);
#
#  				})(document);
#  			} else {
#  				(function(document){
#
#  						var scriptEl = document.createElement('script');
#  						scriptEl.src = 'https://www.bestbuy.com/~assets/bby/_com/user-generated-content/ugc-stats/dist/client/client-9e97ddb6f42e381fd8b7551170463ea7.js';
#  						scriptEl.noModule = true;
#  						scriptEl.defer = true;
#  						if (window.navigator.userAgent.indexOf("Edge") === -1) {
#  							scriptEl.async = false;
#  						}
#  						document.getElementById('sponsored-listing-ugc-stats-v2').appendChild(scriptEl);
#
#  				})(document);
#  			}
#  		</script>
#  			<script>
#  			initializer.initializeComponent({"creatorNamespace":"user-generated-content","componentId":"ugc-stats","contractVersion":"v2","componentVersion":"2.2.19"}, 'sponsored-listing-ugc-stats-v2', "{\"app\":{\"device\":{\"isLarge\":true,\"isSmall\":false},\"instanceId\":\"sponsored-listing-ugc-stats-v2\",\"renderStyle\":\"smallStandard\",\"sku\":\"6414078\"},\"exp\":{\"expertStats\":{}},\"metaLayer\":{\"env_assets\":\"https:\\u002F\\u002Fwww.bestbuy.com\\u002F~assets\\u002Fbby\\u002F_com\",\"env_piscesUrl\":\"https:\\u002F\\u002Fpisces.bbystatic.com\",\"env_appServer\":\"https:\\u002F\\u002Fwww.bestbuy.com\"},\"qna\":{\"qnaStats\":{}},\"rnr\":{\"hideEmptyStars\":false,\"histogramsEnabled\":true,\"popoverEnabled\":true,\"reviewsLinkAction\":\"pdp\",\"reviewStats\":{\"sku\":\"6414078\",\"averageOverallRating\":{\"actual\":4.706586826347305,\"rounded\":4.7},\"topRated\":true,\"totalReviewCount\":334,\"verifiedPurchaseCount\":333,\"recommendedCount\":319,\"recommendedPercent\":96,\"distributions\":[{\"distributionCode\":\"RATING\",\"items\":[{\"value\":1,\"count\":4,\"roundedPercent\":1,\"actualPercent\":1.1976047904191616},{\"value\":2,\"count\":5,\"roundedPercent\":2,\"actualPercent\":1.4970059880239521},{\"value\":3,\"count\":8,\"roundedPercent\":2,\"actualPercent\":2.395209580838323},{\"value\":4,\"count\":51,\"roundedPercent\":15,\"actualPercent\":15.269461077844312},{\"value\":5,\"count\":266,\"roundedPercent\":80,\"actualPercent\":79.64071856287426}]}],\"isReviewable\":true,\"rnrStandalonePage\":\"\\u002Fsite\\u002Freviews\\u002Fnba-2k21-mamba-forever-edition-playstation-5\\u002F6414078\",\"writeAReview\":\"\\u002Fsite\\u002Freviews\\u002Fsubmission\\u002F6414078?campaignId=PDP_&return=\",\"rnrAccordion\":\"\\u002Fsite\\u002Fnba-2k21-mamba-forever-edition-playstation-5\\u002F6414078.p?skuId=6414078#tabbed-customerreviews\"},\"variant\":\"\"}}", 'en-US');
#  		</script>
#  		</div></div></div></div><div><div class="fulfillment-container"><div><!-- Route fulfillment.fulfillment-summary.v1 unResolvedParams --></div></div></div><div><div class="sku-list-item-compare-checkbox"><div class="sku-list-item-compare-and-save-container"><div class="sku-list-item-compare-container"><div><div class="None" data-version="1.0.26" id="sponsored-listing-compare-checkbox-v1">
#  			<link href="https://www.bestbuy.com/~assets/bby/_com/shop/compare-checkbox/dist/client/client-8998ea0bcccb5d17bb276950fcc6acad.css" rel="stylesheet"/>
#  			<div class="shop-compare-checkbox"><div class="appContainer" data-reactroot=""><div class="c-checkbox v-medium"><label for="6414078-compare-checkbox"><div class="c-checkbox-brand"><div class="c-checkbox-custom-input"><input id="6414078-compare-checkbox" type="checkbox" value="6414078"/><div class="c-checkbox-focus-ring"></div><svg aria-hidden="true" class="c-checkbox-icon c-checkbox-icon-hidden" role="img" viewBox="0 0 100 100" width="1em"><use href="/~assets/bby/_img/int/plsvgdef-frontend/svg/checkbox-checkmark.svg#checkbox-checkmark" xlink:href="/~assets/bby/_img/int/plsvgdef-frontend/svg/checkbox-checkmark.svg#checkbox-checkmark"></use></svg></div></div>Compare</label></div></div></div>
#  			<script async="" defer="" src="https://www.bestbuy.com/~assets/bby/_com/shop/compare-checkbox/dist/client/client-63d214e52f65f3a5fb79d111bfa22d84.js"></script>
#  			<script>
#  			initializer.initializeComponent({"creatorNamespace":"shop","componentId":"compare-checkbox","contractVersion":"v1","componentVersion":"1.0.26"}, 'sponsored-listing-compare-checkbox-v1', "{\"app\":{\"instanceId\":\"sponsored-listing-compare-checkbox-v1\",\"skuId\":\"6414078\",\"size\":\"medium\",\"plCompareCheckbox\":false,\"isBundled\":false,\"isValidSku\":true},\"disableCompareTray\":false,\"metaLayer\":{\"env_assets\":\"https:\\u002F\\u002Fwww.bestbuy.com\\u002F~assets\\u002Fbby\\u002F_com\",\"env_piscesUrl\":\"https:\\u002F\\u002Fpisces.bbystatic.com\",\"env_appServer\":\"https:\\u002F\\u002Fwww.bestbuy.com\"}}", 'en-US');
#  		</script>
#  		</div></div></div><div class="sku-list-item-save-container"><div><div class="None" data-version="1.2.6" id="sponsored-listing-save-for-later-v1">
#  			<link href="https://assets.bbystatic.com/node-cusoweb/shop/save-for-later/dist/client/client-c8db2c33d5fd81b02ff16cb8c659e496.css" rel="stylesheet"/>
#  			<div class="shop-save-for-later"><div class="appContainer" data-reactroot=""><div class="save-for-later"><button class="save-for-later-save"><img alt="" src="https://assets.bbystatic.com/node-cusoweb/shop/save-for-later/dist/client/images/bc3fd7b891476cb5c74e82497352c6c9.svg"/>Save</button></div></div></div>
#  			<script>
#  			if ('noModule' in document.createElement('script')) {
#  				(function(document){
#
#  						var scriptEl = document.createElement('script');
#  						scriptEl.src = 'https://assets.bbystatic.com/node-cusoweb/shop/save-for-later/dist/client/client-e062236836a6d807d09a1bf4b38465c8.mjs';
#  						scriptEl.type = 'module';
#  						document.getElementById('sponsored-listing-save-for-later-v1').appendChild(scriptEl);
#
#  				})(document);
#  			} else {
#  				(function(document){
#
#  						var scriptEl = document.createElement('script');
#  						scriptEl.src = 'https://assets.bbystatic.com/node-cusoweb/shop/save-for-later/dist/client/client-f612b5949b777abe067f381d0539aaf5.js';
#  						scriptEl.noModule = true;
#  						scriptEl.defer = true;
#  						document.getElementById('sponsored-listing-save-for-later-v1').appendChild(scriptEl);
#
#  				})(document);
#  			}
#  		</script>
#  			<script>
#  			initializer.initializeComponent({"creatorNamespace":"shop","componentId":"save-for-later","contractVersion":"v1","componentVersion":"1.2.6"}, 'sponsored-listing-save-for-later-v1', "{\"app\":{\"instanceId\":\"sponsored-listing-save-for-later-v1\",\"skuId\":\"6414078\",\"entityId\":\"6414078\",\"entityType\":\"SKU\",\"isCombo\":false,\"isSkuInList\":false,\"enableCustomLists\":false,\"tooltipPosition\":\"bottom\"},\"disableSaveForLater\":false,\"metaLayer\":{\"env_assets\":\"https:\\u002F\\u002Fassets.bbystatic.com\\u002Fnode-cusoweb\",\"env_piscesUrl\":\"https:\\u002F\\u002Fpisces.bbystatic.com\",\"env_appServer\":\"https:\\u002F\\u002Fwww.bestbuy.com\"}}", 'en-US');
#  		</script>
#  		</div></div></div></div></div></div></div><div class="price-block"><div class="sku-list-item-price"><div><div class="None" data-version="1.2043.12" id="pricing-price-40241508">
#  			<link href="https://assets.bbystatic.com/pricing/price/dist/client/client-f0a53019ddb5a579f7cdec2dda786b6f.css" rel="stylesheet"/>
#  			<div class="pricing-price"><div class="pricing-price" data-csi-destinationzipcode="None" data-csi-tiercode="None" data-reactroot=""><div class="pricing-lib-price-8-2043-12 price-view-pb priceView-layout-medium" data-bold="false" data-bundledversion="8.2043.12" data-buyingoptionsonly="false" data-context="PLP-PriceBlock" data-disablebuyingoptions="true" data-disabledynamicgvppricing="false" data-disableensureassets="true" data-disablegiftwithpurchase="false" data-disablepricematchguarantee="false" data-disableupdateoncart="false" data-disableusepricewithcart="false" data-easyreplenishprice="false" data-enablealignright="false" data-enablemmtpricing="false" data-enablereference="false" data-fixedheight="false" data-ispricefetching="false" data-layout="medium" data-openboxcondition="" data-openboxfacet="false" data-pricewithbundle="false" data-randomgenerateduniqueid="8376098704109587" data-serverrendering="true" data-showgwp="false" data-skuid="6414078" data-suppressmemberbadges="false" data-suppressrestrictedprice="false" data-unlockedretailoption="false" data-version="8.2043.12" data-viewtype="price"><div class="pricing-price pricing-lib-price-8-2043-12 priceView-price" data-version="8.2043.12"><div class="priceView-price-match-guarantee"><span class="c-overlay-wrapper"><span class="overlayTrigger"><button aria-controls="price-match-guarantee-overlay-id-8376098704109587" aria-expanded="false" class="btn btn-link-unstyled v-medium price-match-guarantee-badge" type="button"> Price Match Guarantee</button></span></span></div><div class=""><div><div><div class="priceView-hero-price priceView-customer-price"><span aria-hidden="true">$99.99</span><span class="sr-only">Your price for this item is $<!-- -->99.99</span></div></div></div></div></div></div></div></div>
#  			<script defer="" src="https://assets.bbystatic.com/pricing/price/dist/client/client-346a9b1de999e1fc1cbb48cd4999858a.js"></script>
#  			<script>
#  			initializer.initializeComponent({"creatorNamespace":"pricing","componentId":"price","contractVersion":"v1","componentVersion":"1.2043.12"}, "pricing-price-40241508", "{\"app\":{\"instanceId\":\"pricing-price-40241508\",\"skuId\":\"6414078\",\"layout\":\"medium\",\"context\":\"PLP-PriceBlock\",\"openBoxCondition\":\"\",\"enableAlignRight\":false,\"enableReference\":false,\"enableMMTPricing\":false,\"openBoxFacet\":\"false\",\"priceDomain\":{\"skuId\":\"6414078\",\"regularPrice\":99.99,\"currentPrice\":99.99,\"priceEventType\":\"regular\",\"totalSavings\":0,\"totalSavingsPercent\":0,\"customerPrice\":99.99,\"isMAP\":false,\"isPriceMatchGuarantee\":true,\"offerQualifiers\":[{\"offerId\":\"395044\",\"offerName\":\"Get free PS5 steelbook with purchase of NBA 2K21 Mamba\",\"offerVersion\":415547,\"offerDiscountType\":\"Free\",\"id\":395044002,\"comOfferType\":\"FREEITEM\",\"comRuleType\":\"10\",\"instanceId\":1,\"offerRevocableOnReturns\":true,\"excludeFromBundleBreakage\":false}],\"giftSkus\":[{\"skuId\":\"6420096\",\"quantity\":1,\"offerId\":\"395044\",\"savings\":0,\"isRequiredWithOffer\":false}],\"totalGiftSavings\":0,\"gspUnitPrice\":99.99,\"dotComDisplayStatus\":\"active\",\"locationId\":\"960\",\"currentAsOfDate\":\"2021-01-05T05:09:05 GMT\"},\"bundlePriceGVPServer\":{},\"mmtItemPriceServerData\":{},\"isPriceFetching\":false,\"priceWithBundle\":false,\"cookies\":{},\"disableDynamicGVPPricing\":false,\"configuration\":{\"allAccessModalNodeId\":\"all-access-modal-content\",\"gifts-with-purchase\":{\"enableInstanceIdInjection\":true,\"disableOfferLinkService\":false,\"features\":{\"clientSideRenderingOnly\":true,\"showNewGWPModalContent\":false}},\"bundle-and-save\":{\"features\":{\"showNewModalContent\":false,\"showNewExperience\":true}},\"customer-account-based-offer\":{\"features\":{\"showNewCABOModalContent\":false}},\"rnPriceBlock\":{\"showRegularGwp\":true,\"showComplexGwp\":true},\"mmtPricing\":true,\"regularPriceThreshold\":0.99,\"features\":{\"caboWhenNotUsePriceWithCart\":true},\"enableComplexGwp\":false,\"gwpEmbedClientSideOnly\":true,\"returnsMessagingState\":\"on\",\"returnsMessagingAB\":[\"CMT\",22,\"8-f\"],\"useDynamicSMPSpacing\":true,\"enablePriceShimmer\":false,\"dynamicPricingContextBlacklist\":[],\"dynamicPricingHrefBlacklist\":[]},\"returnsMessagingProps\":null},\"metaLayer\":{\"env_assets\":\"https:\\u002F\\u002Fassets.bbystatic.com\",\"env_piscesUrl\":\"https:\\u002F\\u002Fpisces.bbystatic.com\"}}", "en-US");
#  		</script>
#  		</div></div></div><div><div></div></div><div class="sku-list-item-button"><div><div><div class="None" data-version="21.0.128" id="sponsored-listing-add-to-cart-button-v1">
#
#  			<div class="fulfillment-add-to-cart-button"><div><div style="position:relative"><button class="btn btn-secondary btn-sm btn-block add-to-cart-button" data-sku-id="6414078" style="padding:0 8px" type="button">Check Stores</button><span id="wait-overlay-6414078"></span><span class="c-overlay-wrapper"><span class="overlayTrigger"><div aria-controls="wait-overlay-6414078" aria-describedby="wait-overlay-6414078" aria-expanded="false" style="width:0;height:0"></div></span></span></div></div></div>
#  			<script defer="" src="https://assets.bbystatic.com/fulfillment/add-to-cart-button/dist/client/client-9942b99c380491d427e87fbf10d35fb4.js"></script>
#  			<script>
#  			initializer.initializeComponent({"creatorNamespace":"fulfillment","componentId":"add-to-cart-button","contractVersion":"v1","componentVersion":"21.0.128"}, "sponsored-listing-add-to-cart-button-v1", "{\"app\":{\"attachModal\":{\"isShowing\":false,\"instanceNumber\":0},\"tests\":{\"sold-out-openbox\":{\"scaled\":true,\"ignore\":false},\"combo-availability-plp\":{\"scaled\":true,\"ignore\":false}},\"storeId\":\"\",\"context\":\"plp\",\"xboxAllAccess\":false,\"instanceId\":\"sponsored-listing-add-to-cart-button-v1\",\"destinationZipCode\":\"\",\"blockLevel\":true,\"size\":\"small\",\"disabled\":false,\"chatForServiceUrl\":\"\\u002Fusw\\u002Fcovertops\",\"learnMoreUrl\":\"\\u002Fsite\\u002Fhome-security-solutions\\u002Fsmart-home\\u002Fpcmcat748302047019.c?id=pcmcat748302047019\",\"attachModalEnabled\":true,\"buttonStateSourceRouteEnabled\":true,\"inHomeConsultationUrl\":\"https:\\u002F\\u002Fwww.bestbuy.com\\u002Fservices\\u002Fin-home-advisor\\u002Fhome\",\"maxComboSkusExceeded\":false,\"soldOutDispatchDisabled\":true,\"reportingVariables\":{},\"pickupTodayStores\":[],\"disasterFallBackLists\":{},\"xboxAllAccessModal\":{\"isShowing\":false,\"instanceNumber\":0},\"skuPdpUrl\":\"\\u002Fsite\\u002Fnba-2k21-mamba-forever-edition-playstation-5\\u002F6414078.p?skuId=6414078\"},\"items\":[{\"skuId\":\"6414078\",\"condition\":null,\"tags\":[\"tag\\u002Fprimary\"]}],\"buttonState\":{\"$__path\":[\"shop\",\"buttonstate\",\"v5\",\"item\",\"optional\",\"skus\",\"6414078\",\"conditions\",\"NONE\",\"destinationZipCode\",\"%20\",\"storeId\",\"%20\",\"storeZipCode\",\"%20\",\"context\",\"plp\",\"addAll\",\"false\",\"consolidated\",\"false\",\"source\",\"buttonView\",\"xboxAllAccess\",\"false\",\"buttonStateResponseInfos\",0],\"buttonState\":\"CHECK_STORES\",\"displayText\":\"Check Stores\"},\"metaLayer\":{\"env_assets\":\"https:\\u002F\\u002Fassets.bbystatic.com\",\"env_piscesUrl\":\"https:\\u002F\\u002Fpisces.bbystatic.com\",\"env_appServer\":\"https:\\u002F\\u002Fwww.bestbuy.com\"}}", "en-US");
#  		</script>
#  		</div></div></div></div><div><!-- Route shop.notify-me.v1 unResolvedParams --></div><div class="buying-options-only"><div><div class="" data-version="1.2043.12" id="pricing-price-87465139">
#
#  			<div class="pricing-price"><div class="pricing-price" data-csi-destinationzipcode="None" data-csi-tiercode="None" data-reactroot=""><div class="pricing-lib-price-8-2043-12 price-view-pb priceView-layout-medium" data-bold="false" data-bundledversion="8.2043.12" data-buyingoptionsonly="true" data-context="PLP-PriceBlock" data-disablebuyingoptions="true" data-disabledynamicgvppricing="false" data-disableensureassets="true" data-disablegiftwithpurchase="false" data-disablepricematchguarantee="false" data-disableupdateoncart="false" data-disableusepricewithcart="false" data-easyreplenishprice="false" data-enablealignright="false" data-enablemmtpricing="false" data-enablereference="false" data-fixedheight="false" data-ispricefetching="false" data-layout="medium" data-openboxcondition="" data-openboxfacet="false" data-pricewithbundle="false" data-randomgenerateduniqueid="7680868086272692" data-serverrendering="true" data-showgwp="false" data-skuid="6414078" data-suppressmemberbadges="false" data-suppressrestrictedprice="false" data-unlockedretailoption="false" data-version="8.2043.12" data-viewtype="price"></div></div></div>
#
#  			<script>
#  			initializer.initializeComponent({"creatorNamespace":"pricing","componentId":"price","contractVersion":"v1","componentVersion":"1.2043.12"}, "pricing-price-87465139", "{\"app\":{\"instanceId\":\"pricing-price-87465139\",\"skuId\":\"6414078\",\"layout\":\"medium\",\"context\":\"PLP-PriceBlock\",\"openBoxCondition\":\"\",\"buyingOptionsOnly\":\"true\",\"enableAlignRight\":false,\"enableReference\":false,\"enableMMTPricing\":false,\"openBoxFacet\":\"false\",\"priceDomain\":{\"skuId\":\"6414078\",\"regularPrice\":99.99,\"currentPrice\":99.99,\"priceEventType\":\"regular\",\"totalSavings\":0,\"totalSavingsPercent\":0,\"customerPrice\":99.99,\"isMAP\":false,\"isPriceMatchGuarantee\":true,\"offerQualifiers\":[{\"offerId\":\"395044\",\"offerName\":\"Get free PS5 steelbook with purchase of NBA 2K21 Mamba\",\"offerVersion\":415547,\"offerDiscountType\":\"Free\",\"id\":395044002,\"comOfferType\":\"FREEITEM\",\"comRuleType\":\"10\",\"instanceId\":1,\"offerRevocableOnReturns\":true,\"excludeFromBundleBreakage\":false}],\"giftSkus\":[{\"skuId\":\"6420096\",\"quantity\":1,\"offerId\":\"395044\",\"savings\":0,\"isRequiredWithOffer\":false}],\"totalGiftSavings\":0,\"gspUnitPrice\":99.99,\"dotComDisplayStatus\":\"active\",\"locationId\":\"960\",\"currentAsOfDate\":\"2021-01-05T05:09:05 GMT\"},\"bundlePriceGVPServer\":{},\"mmtItemPriceServerData\":{},\"isPriceFetching\":false,\"priceWithBundle\":false,\"cookies\":{},\"disableDynamicGVPPricing\":false,\"configuration\":{\"allAccessModalNodeId\":\"all-access-modal-content\",\"gifts-with-purchase\":{\"enableInstanceIdInjection\":true,\"disableOfferLinkService\":false,\"features\":{\"clientSideRenderingOnly\":true,\"showNewGWPModalContent\":false}},\"bundle-and-save\":{\"features\":{\"showNewModalContent\":false,\"showNewExperience\":true}},\"customer-account-based-offer\":{\"features\":{\"showNewCABOModalContent\":false}},\"rnPriceBlock\":{\"showRegularGwp\":true,\"showComplexGwp\":true},\"mmtPricing\":true,\"regularPriceThreshold\":0.99,\"features\":{\"caboWhenNotUsePriceWithCart\":true},\"enableComplexGwp\":false,\"gwpEmbedClientSideOnly\":true,\"returnsMessagingState\":\"on\",\"returnsMessagingAB\":[\"CMT\",22,\"8-f\"],\"useDynamicSMPSpacing\":true,\"enablePriceShimmer\":false,\"dynamicPricingContextBlacklist\":[],\"dynamicPricingHrefBlacklist\":[]},\"returnsMessagingProps\":null},\"metaLayer\":{\"env_assets\":\"https:\\u002F\\u002Fassets.bbystatic.com\",\"env_piscesUrl\":\"https:\\u002F\\u002Fpisces.bbystatic.com\"}}", "en-US");
#  		</script>
#  		</div></div></div></div></div></div></div>
#  			<script defer="" src="/~assets/bby/_com/shop/sku-list-item/dist/client/client-8998434e06e7b5c16367885b06144669.js"></script>
#  			<script>
#  			initializer.initializeComponent({"creatorNamespace":"shop","componentId":"sku-list-item","contractVersion":"v2","componentVersion":"20.16.17"}, "shop-sku-list-item-96a7b744-07c4-41e3-818e-55508563748a", "{\"app\":{\"skuId\":\"6414078\",\"deviceClass\":\"l\",\"instanceId\":\"shop-sku-list-item-96a7b744-07c4-41e3-818e-55508563748a\",\"inViewport\":true,\"isSponsored\":true,\"highlightedVariationSkuId\":\"6414078\",\"lazyLoadOffset\":-400,\"disableFulfillmentForVariation\":false},\"metaLayer\":{\"env_piscesUrl\":\"https:\\u002F\\u002Fpisces.bbystatic.com\",\"env_appServer\":\"https:\\u002F\\u002Fwww.bestbuy.com\"},\"searchDerived\":{\"isOpenBoxFacetSelected\":false},\"sku\":{\"customerRatings\":4.7,\"image\":{\"alt\":\"NBA 2K21 Mamba Forever Edition - PlayStation 5 - Alt_View_Standard_11\",\"src\":\"image2\\u002FBestBuy_US\\u002Fimages\\u002Fproducts\\u002F6414\\u002F6414078cv11a.jpg\"},\"link\":\"\\u002Fsite\\u002Fnba-2k21-mamba-forever-edition-playstation-5\\u002F6414078.p?skuId=6414078\",\"numberOfReviews\":334,\"name\":\"NBA 2K21 Mamba Forever Edition - PlayStation 5\",\"skuId\":\"6414078\",\"publisher\":\"2K\",\"esrbRating\":\"E (Everyone)\",\"releaseDate\":{\"notYetAnnounced\":false,\"date\":\"11\\u002F12\\u002F2020\"},\"isOpenBoxAvailable\":false,\"isNew\":false,\"isOpenBoxOnly\":false,\"detailDisplayText\":\"SEE_MORE_OPTIONS\"}}", "en-US");
#  		</script>
#  		</div></div></div></div>,
#  <li class="sku-item" data-sku-id="6432588"><div class="" data-track="[context:listRank=1]"><div><div class="None" data-version="20.16.17" id="shop-sku-list-item-a158b446-4747-4a1f-be33-950ee98028ea">
#
#  			<div class="shop-sku-list-item"><div class="list-item lv" data-sku-id="6432588"><div class="image-column"><a class="image-link" href="/site/immortals-fenyx-rising-standard-edition-playstation-5/6432588.p?skuId=6432588"><img alt="Immortals Fenyx Rising Standard Edition - PlayStation 5 - Front_Zoom" class="product-image" src="https://pisces.bbystatic.com/image2/BestBuy_US/images/products/6432/6432588_sd.jpg;maxHeight=200;maxWidth=300" srcset="https://pisces.bbystatic.com/image2/BestBuy_US/images/products/6432/6432588_sd.jpg;maxHeight=300;maxWidth=450 1.5x"/><div class="detail-display-text"><span data-track="See More Options">See More Options</span></div></a></div><div class="right-column"><div class="information"><div class="embedded-badge"><div></div></div><div><div class="sku-title"><h4 class="sku-header"><a href="/site/immortals-fenyx-rising-standard-edition-playstation-5/6432588.p?skuId=6432588">Immortals Fenyx Rising Standard Edition - PlayStation 5</a></h4></div></div><div class="variation-info"><div class="sku-model"><div class="sku-attribute-title"><span class="attribute-title">Publisher:</span> <span class="sku-value">Ubisoft</span></div> <div class="sku-attribute-title"><span class="attribute-title">SKU:</span> <span class="sku-value">6432588</span></div> <div class="sku-attribute-title"><span class="attribute-title">Release Date:</span> <span class="sku-value">12/03/2020</span></div> <div class="sku-attribute-title"><span class="attribute-title">ESRB Rating<!-- -->:</span> <a href="https://www.esrb.org/ratings/ratings_guide.aspx" rel="noopener noreferrer" target="_blank">T (Teen 13+)</a></div> </div><div class="ratings-reviews"><div><div class="None" data-version="2.2.19" id="user-generated-content-ugc-stats-84671566">
#
#  			<div class="user-generated-content-ugc-stats"><div class="appContainer size-l" data-reactroot=""><ul class="reviews-stats-list"><li class="ugc-stat customer-review-stats"><a data-track="stats: customerReviews" href="/site/immortals-fenyx-rising-standard-edition-playstation-5/6432588.p?skuId=6432588#tabbed-customerreviews"><div class="ugc-ratings-reviews c-ratings-reviews-v4 c-ratings-reviews-v4-size-small"><p class="sr-only">User rating, 4.7 out of 5 stars with 147 reviews.</p><i aria-hidden="true" class="c-stars-wrapper c-stars-wrapper-size-small"><span class="c-stars-container"><svg aria-hidden="true" fill="#C5CBD5" preserveAspectRatio="xMinYMin slice" role="img" viewBox="0 0 87 16"><use href="/~assets/bby/_img/int/plsvgdef-frontend/svg/star-rating-empty.svg#star-rating-empty" xlink:href="/~assets/bby/_img/int/plsvgdef-frontend/svg/star-rating-empty.svg#star-rating-empty"></use></svg></span><span class="c-stars-container" style="width:82.78px;overflow:hidden"><svg aria-hidden="true" fill="#C28400" preserveAspectRatio="xMinYMin slice" role="img" viewBox="0 0 87 16"><use href="/~assets/bby/_img/int/plsvgdef-frontend/svg/star-rating-border.svg#star-rating-border" xlink:href="/~assets/bby/_img/int/plsvgdef-frontend/svg/star-rating-border.svg#star-rating-border"></use></svg></span><span class="c-stars-container" style="width:81.78px;overflow:hidden"><svg aria-hidden="true" fill="#FFE000" preserveAspectRatio="xMinYMin slice" role="img" viewBox="0 0 87 16"><use href="/~assets/bby/_img/int/plsvgdef-frontend/svg/star-rating.svg#star-rating" xlink:href="/~assets/bby/_img/int/plsvgdef-frontend/svg/star-rating.svg#star-rating"></use></svg></span></i><span aria-hidden="true" class="c-reviews-v4">(147)</span></div></a></li></ul></div></div>
#  			<script>
#  			if ('noModule' in HTMLScriptElement.prototype) {
#  				(function(document){
#
#  						var scriptEl = document.createElement('script');
#  						scriptEl.src = 'https://www.bestbuy.com/~assets/bby/_com/user-generated-content/ugc-stats/dist/client/client-1ea693a74909895ff02b232f7026229c.mjs';
#  						scriptEl.type = 'module';
#  						if (window.navigator.userAgent.indexOf("Edge") === -1) {
#  							scriptEl.async = false;
#  						}
#  						document.getElementById('user-generated-content-ugc-stats-84671566').appendChild(scriptEl);
#
#  				})(document);
#  			} else {
#  				(function(document){
#
#  						var scriptEl = document.createElement('script');
#  						scriptEl.src = 'https://www.bestbuy.com/~assets/bby/_com/user-generated-content/ugc-stats/dist/client/client-9e97ddb6f42e381fd8b7551170463ea7.js';
#  						scriptEl.noModule = true;
#  						scriptEl.defer = true;
#  						if (window.navigator.userAgent.indexOf("Edge") === -1) {
#  							scriptEl.async = false;
#  						}
#  						document.getElementById('user-generated-content-ugc-stats-84671566').appendChild(scriptEl);
#
#  				})(document);
#  			}
#  		</script>
#  			<script>
#  			initializer.initializeComponent({"creatorNamespace":"user-generated-content","componentId":"ugc-stats","contractVersion":"v2","componentVersion":"2.2.19"}, 'user-generated-content-ugc-stats-84671566', "{\"app\":{\"device\":{\"isLarge\":true,\"isSmall\":false},\"instanceId\":\"user-generated-content-ugc-stats-84671566\",\"renderStyle\":\"smallStandard\",\"sku\":\"6432588\"},\"exp\":{\"expertStats\":{}},\"metaLayer\":{\"env_assets\":\"https:\\u002F\\u002Fwww.bestbuy.com\\u002F~assets\\u002Fbby\\u002F_com\",\"env_piscesUrl\":\"https:\\u002F\\u002Fpisces.bbystatic.com\",\"env_appServer\":\"https:\\u002F\\u002Fwww.bestbuy.com\"},\"qna\":{\"qnaStats\":{}},\"rnr\":{\"hideEmptyStars\":false,\"histogramsEnabled\":true,\"popoverEnabled\":true,\"reviewsLinkAction\":\"pdp\",\"reviewStats\":{\"sku\":\"6432588\",\"averageOverallRating\":{\"actual\":4.673469387755102,\"rounded\":4.7},\"topRated\":true,\"totalReviewCount\":147,\"verifiedPurchaseCount\":145,\"recommendedCount\":143,\"recommendedPercent\":97,\"distributions\":[{\"distributionCode\":\"RATING\",\"items\":[{\"value\":1,\"count\":0,\"roundedPercent\":0,\"actualPercent\":0},{\"value\":2,\"count\":1,\"roundedPercent\":1,\"actualPercent\":0.6802721088435374},{\"value\":3,\"count\":6,\"roundedPercent\":4,\"actualPercent\":4.081632653061225},{\"value\":4,\"count\":33,\"roundedPercent\":22,\"actualPercent\":22.448979591836736},{\"value\":5,\"count\":107,\"roundedPercent\":73,\"actualPercent\":72.78911564625851}]}],\"isReviewable\":true,\"rnrStandalonePage\":\"\\u002Fsite\\u002Freviews\\u002Fimmortals-fenyx-rising-standard-edition-playstation-5\\u002F6432588\",\"writeAReview\":\"\\u002Fsite\\u002Freviews\\u002Fsubmission\\u002F6432588?campaignId=PDP_&return=\",\"rnrAccordion\":\"\\u002Fsite\\u002Fimmortals-fenyx-rising-standard-edition-playstation-5\\u002F6432588.p?skuId=6432588#tabbed-customerreviews\"},\"variant\":\"\"}}", 'en-US');
#  		</script>
#  		</div></div></div></div><div></div><div></div></div><div class="price-block"><div class="sku-list-item-price"><div><div class="None" data-version="1.2043.12" id="pricing-price-35701337">
#
#  			<div class="pricing-price"><div class="pricing-price" data-csi-destinationzipcode="None" data-csi-tiercode="None" data-reactroot=""><div class="pricing-lib-price-8-2043-12 price-view-pb priceView-layout-medium" data-bold="false" data-bundledversion="8.2043.12" data-buyingoptionsonly="false" data-context="PLP-PriceBlock" data-disablebuyingoptions="true" data-disabledynamicgvppricing="false" data-disableensureassets="true" data-disablegiftwithpurchase="false" data-disablepricematchguarantee="false" data-disableupdateoncart="false" data-disableusepricewithcart="false" data-easyreplenishprice="false" data-enablealignright="false" data-enablemmtpricing="false" data-enablereference="false" data-fixedheight="false" data-ispricefetching="false" data-layout="medium" data-openboxcondition="" data-openboxfacet="false" data-pricewithbundle="false" data-randomgenerateduniqueid="27340806865062084" data-serverrendering="true" data-showgwp="false" data-skuid="6432588" data-suppressmemberbadges="false" data-suppressrestrictedprice="false" data-unlockedretailoption="false" data-version="8.2043.12" data-viewtype="price"><div class="pricing-price pricing-lib-price-8-2043-12 priceView-price" data-version="8.2043.12"><div class="priceView-price-match-guarantee"><span class="c-overlay-wrapper"><span class="overlayTrigger"><button aria-controls="price-match-guarantee-overlay-id-27340806865062084" aria-expanded="false" class="btn btn-link-unstyled v-medium price-match-guarantee-badge" type="button"> Price Match Guarantee</button></span></span></div><div class=""><div><div><div class="priceView-hero-price priceView-customer-price"><span aria-hidden="true">$29.99</span><span class="sr-only">Your price for this item is $<!-- -->29.99</span></div></div><div class="pricing-price__savings-regular-price"><div class="pricing-price__savings">Save $30</div><span><div aria-hidden="true" class="pricing-price__regular-price">Was $59.99</div><div class="pricing-price__regular-price sr-only">The previous price was $59.99</div></span></div></div></div></div></div></div></div>
#
#  			<script>
#  			initializer.initializeComponent({"creatorNamespace":"pricing","componentId":"price","contractVersion":"v1","componentVersion":"1.2043.12"}, "pricing-price-35701337", "{\"app\":{\"instanceId\":\"pricing-price-35701337\",\"skuId\":\"6432588\",\"layout\":\"medium\",\"context\":\"PLP-PriceBlock\",\"openBoxCondition\":\"\",\"enableAlignRight\":false,\"enableReference\":false,\"enableMMTPricing\":false,\"openBoxFacet\":\"false\",\"priceDomain\":{\"skuId\":\"6432588\",\"regularPrice\":59.99,\"currentPrice\":29.99,\"priceEventType\":\"onSale\",\"regularPriceMessageType\":\"WAS\",\"instantSavings\":30,\"totalSavings\":30,\"totalSavingsPercent\":50,\"customerPrice\":29.99,\"isMAP\":false,\"isPriceMatchGuarantee\":true,\"gspUnitPrice\":29.99,\"dotComDisplayStatus\":\"active\",\"locationId\":\"960\",\"currentAsOfDate\":\"2021-01-05T05:12:19 GMT\"},\"bundlePriceGVPServer\":{},\"mmtItemPriceServerData\":{},\"isPriceFetching\":false,\"priceWithBundle\":false,\"cookies\":{},\"disableDynamicGVPPricing\":false,\"configuration\":{\"allAccessModalNodeId\":\"all-access-modal-content\",\"gifts-with-purchase\":{\"enableInstanceIdInjection\":true,\"disableOfferLinkService\":false,\"features\":{\"clientSideRenderingOnly\":true,\"showNewGWPModalContent\":false}},\"bundle-and-save\":{\"features\":{\"showNewModalContent\":false,\"showNewExperience\":true}},\"customer-account-based-offer\":{\"features\":{\"showNewCABOModalContent\":false}},\"rnPriceBlock\":{\"showRegularGwp\":true,\"showComplexGwp\":true},\"mmtPricing\":true,\"regularPriceThreshold\":0.99,\"features\":{\"caboWhenNotUsePriceWithCart\":true},\"enableComplexGwp\":false,\"gwpEmbedClientSideOnly\":true,\"returnsMessagingState\":\"on\",\"returnsMessagingAB\":[\"CMT\",22,\"8-f\"],\"useDynamicSMPSpacing\":true,\"enablePriceShimmer\":false,\"dynamicPricingContextBlacklist\":[],\"dynamicPricingHrefBlacklist\":[]},\"returnsMessagingProps\":null},\"metaLayer\":{\"env_assets\":\"https:\\u002F\\u002Fassets.bbystatic.com\",\"env_piscesUrl\":\"https:\\u002F\\u002Fpisces.bbystatic.com\"}}", "en-US");
#  		</script>
#  		</div></div></div><div></div><div class="sku-list-item-button"><div><div><div class="None" data-version="21.0.128" id="fulfillment-add-to-cart-button-807becc8-be57-4c3d-b291-2b95fd27e66a">
#
#  			<div class="fulfillment-add-to-cart-button"><div><div style="position:relative"><button class="btn btn-primary btn-sm btn-block btn-leading-ficon add-to-cart-button" data-sku-id="6432588" style="padding:0 8px" type="button"><svg aria-hidden="true" role="img" style="width:16px;height:16px;margin-bottom:-2px;margin-right:9px;fill:currentColor" viewBox="0 0 100 100"><use href="/~assets/bby/_img/int/plsvgdef-frontend/svg/cart.svg#cart" xlink:href="/~assets/bby/_img/int/plsvgdef-frontend/svg/cart.svg#cart"></use></svg>Add to Cart</button><span id="wait-overlay-6432588"></span><span class="c-overlay-wrapper"><span class="overlayTrigger"><div aria-controls="wait-overlay-6432588" aria-describedby="wait-overlay-6432588" aria-expanded="false" style="width:0;height:0"></div></span></span></div></div></div>
#
#  			<script>
#  			initializer.initializeComponent({"creatorNamespace":"fulfillment","componentId":"add-to-cart-button","contractVersion":"v1","componentVersion":"21.0.128"}, "fulfillment-add-to-cart-button-807becc8-be57-4c3d-b291-2b95fd27e66a", "{\"app\":{\"attachModal\":{\"isShowing\":false,\"instanceNumber\":0},\"tests\":{\"sold-out-openbox\":{\"scaled\":true,\"ignore\":false},\"combo-availability-plp\":{\"scaled\":true,\"ignore\":false}},\"context\":\"plp\",\"xboxAllAccess\":false,\"instanceId\":\"fulfillment-add-to-cart-button-807becc8-be57-4c3d-b291-2b95fd27e66a\",\"blockLevel\":true,\"size\":\"small\",\"disabled\":false,\"chatForServiceUrl\":\"\\u002Fusw\\u002Fcovertops\",\"learnMoreUrl\":\"\\u002Fsite\\u002Fhome-security-solutions\\u002Fsmart-home\\u002Fpcmcat748302047019.c?id=pcmcat748302047019\",\"attachModalEnabled\":true,\"buttonStateSourceRouteEnabled\":true,\"inHomeConsultationUrl\":\"https:\\u002F\\u002Fwww.bestbuy.com\\u002Fservices\\u002Fin-home-advisor\\u002Fhome\",\"maxComboSkusExceeded\":false,\"soldOutDispatchDisabled\":true,\"reportingVariables\":{},\"pickupTodayStores\":[],\"disasterFallBackLists\":{},\"xboxAllAccessModal\":{\"isShowing\":false,\"instanceNumber\":0},\"skuPdpUrl\":\"\\u002Fsite\\u002Fimmortals-fenyx-rising-standard-edition-playstation-5\\u002F6432588.p?skuId=6432588\"},\"items\":[{\"skuId\":\"6432588\",\"condition\":null,\"tags\":[\"tag\\u002Fprimary\"]}],\"buttonState\":{\"$__path\":[\"shop\",\"buttonstate\",\"v5\",\"item\",\"optional\",\"skus\",\"6432588\",\"conditions\",\"NONE\",\"destinationZipCode\",\"%20\",\"storeId\",\"%20\",\"storeZipCode\",\"%20\",\"context\",\"plp\",\"addAll\",\"false\",\"consolidated\",\"false\",\"source\",\"buttonView\",\"xboxAllAccess\",\"false\",\"buttonStateResponseInfos\",0],\"buttonState\":\"ADD_TO_CART\",\"displayText\":\"Add to Cart\"},\"metaLayer\":{\"env_assets\":\"https:\\u002F\\u002Fassets.bbystatic.com\",\"env_piscesUrl\":\"https:\\u002F\\u002Fpisces.bbystatic.com\",\"env_appServer\":\"https:\\u002F\\u002Fwww.bestbuy.com\"}}", "en-US");
#  		</script>
#  		</div></div></div></div><div></div><div class="buying-options-only"><div><div class="" data-version="1.2043.12" id="pricing-price-89833071">
#
#  			<div class="pricing-price"><div class="pricing-price" data-csi-destinationzipcode="None" data-csi-tiercode="None" data-reactroot=""><div class="pricing-lib-price-8-2043-12 price-view-pb priceView-layout-medium" data-bold="false" data-bundledversion="8.2043.12" data-buyingoptionsonly="true" data-context="PLP-PriceBlock" data-disablebuyingoptions="true" data-disabledynamicgvppricing="false" data-disableensureassets="true" data-disablegiftwithpurchase="false" data-disablepricematchguarantee="false" data-disableupdateoncart="false" data-disableusepricewithcart="false" data-easyreplenishprice="false" data-enablealignright="false" data-enablemmtpricing="false" data-enablereference="false" data-fixedheight="false" data-ispricefetching="false" data-layout="medium" data-openboxcondition="" data-openboxfacet="false" data-pricewithbundle="false" data-randomgenerateduniqueid="632745295858824" data-serverrendering="true" data-showgwp="false" data-skuid="6432588" data-suppressmemberbadges="false" data-suppressrestrictedprice="false" data-unlockedretailoption="false" data-version="8.2043.12" data-viewtype="price"></div></div></div>
#
#  			<script>
#  			initializer.initializeComponent({"creatorNamespace":"pricing","componentId":"price","contractVersion":"v1","componentVersion":"1.2043.12"}, "pricing-price-89833071", "{\"app\":{\"instanceId\":\"pricing-price-89833071\",\"skuId\":\"6432588\",\"layout\":\"medium\",\"context\":\"PLP-PriceBlock\",\"openBoxCondition\":\"\",\"buyingOptionsOnly\":\"true\",\"enableAlignRight\":false,\"enableReference\":false,\"enableMMTPricing\":false,\"openBoxFacet\":\"false\",\"priceDomain\":{\"skuId\":\"6432588\",\"regularPrice\":59.99,\"currentPrice\":29.99,\"priceEventType\":\"onSale\",\"regularPriceMessageType\":\"WAS\",\"instantSavings\":30,\"totalSavings\":30,\"totalSavingsPercent\":50,\"customerPrice\":29.99,\"isMAP\":false,\"isPriceMatchGuarantee\":true,\"gspUnitPrice\":29.99,\"dotComDisplayStatus\":\"active\",\"locationId\":\"960\",\"currentAsOfDate\":\"2021-01-05T05:12:19 GMT\"},\"bundlePriceGVPServer\":{},\"mmtItemPriceServerData\":{},\"isPriceFetching\":false,\"priceWithBundle\":false,\"cookies\":{},\"disableDynamicGVPPricing\":false,\"configuration\":{\"allAccessModalNodeId\":\"all-access-modal-content\",\"gifts-with-purchase\":{\"enableInstanceIdInjection\":true,\"disableOfferLinkService\":false,\"features\":{\"clientSideRenderingOnly\":true,\"showNewGWPModalContent\":false}},\"bundle-and-save\":{\"features\":{\"showNewModalContent\":false,\"showNewExperience\":true}},\"customer-account-based-offer\":{\"features\":{\"showNewCABOModalContent\":false}},\"rnPriceBlock\":{\"showRegularGwp\":true,\"showComplexGwp\":true},\"mmtPricing\":true,\"regularPriceThreshold\":0.99,\"features\":{\"caboWhenNotUsePriceWithCart\":true},\"enableComplexGwp\":false,\"gwpEmbedClientSideOnly\":true,\"returnsMessagingState\":\"on\",\"returnsMessagingAB\":[\"CMT\",22,\"8-f\"],\"useDynamicSMPSpacing\":true,\"enablePriceShimmer\":false,\"dynamicPricingContextBlacklist\":[],\"dynamicPricingHrefBlacklist\":[]},\"returnsMessagingProps\":null},\"metaLayer\":{\"env_assets\":\"https:\\u002F\\u002Fassets.bbystatic.com\",\"env_piscesUrl\":\"https:\\u002F\\u002Fpisces.bbystatic.com\"}}", "en-US");
#  		</script>
#  		</div></div></div></div></div></div></div>
#
#  			<script>
#  			initializer.initializeComponent({"creatorNamespace":"shop","componentId":"sku-list-item","contractVersion":"v2","componentVersion":"20.16.17"}, "shop-sku-list-item-a158b446-4747-4a1f-be33-950ee98028ea", "{\"app\":{\"skuId\":\"6432588\",\"deviceClass\":\"l\",\"instanceId\":\"shop-sku-list-item-a158b446-4747-4a1f-be33-950ee98028ea\",\"inViewport\":false,\"isSponsored\":false,\"highlightedVariationSkuId\":\"6432588\",\"lazyLoadOffset\":-400,\"disableFulfillmentForVariation\":false},\"metaLayer\":{\"env_piscesUrl\":\"https:\\u002F\\u002Fpisces.bbystatic.com\",\"env_appServer\":\"https:\\u002F\\u002Fwww.bestbuy.com\"},\"searchDerived\":{\"isOpenBoxFacetSelected\":false},\"sku\":{\"customerRatings\":4.7,\"image\":{\"alt\":\"Immortals Fenyx Rising Standard Edition - PlayStation 5 - Front_Zoom\",\"src\":\"image2\\u002FBestBuy_US\\u002Fimages\\u002Fproducts\\u002F6432\\u002F6432588_sd.jpg\"},\"link\":\"\\u002Fsite\\u002Fimmortals-fenyx-rising-standard-edition-playstation-5\\u002F6432588.p?skuId=6432588\",\"numberOfReviews\":147,\"name\":\"Immortals Fenyx Rising Standard Edition - PlayStation 5\",\"skuId\":\"6432588\",\"publisher\":\"Ubisoft\",\"esrbRating\":\"T (Teen 13+)\",\"releaseDate\":{\"notYetAnnounced\":false,\"date\":\"12\\u002F03\\u002F2020\"},\"isOpenBoxAvailable\":false,\"isNew\":false,\"isOpenBoxOnly\":false,\"detailDisplayText\":\"SEE_MORE_OPTIONS\"}}", "en-US");
#  		</script>
#  		</div></div></div></li>,
#  <li class="sku-item" data-sku-id="6430146"><div class="" data-track="[context:listRank=2]"><div><div class="" data-version="20.16.17" id="shop-sku-list-item-cad6b90b-0441-4c54-9885-3ea58b936a38">
#
# ...
#  			<script>
#  			if ('noModule' in HTMLScriptElement.prototype) {
#  				(function(document){
#
#  						var scriptEl = document.createElement('script');
#  						scriptEl.src = 'https://www.bestbuy.com/~assets/bby/_com/user-generated-content/ugc-stats/dist/client/client-1ea693a74909895ff02b232f7026229c.mjs';
#  						scriptEl.type = 'module';
#  						if (window.navigator.userAgent.indexOf("Edge") === -1) {
#  							scriptEl.async = false;
#  						}
#  						document.getElementById('user-generated-content-ugc-stats-80503912').appendChild(scriptEl);
#
#  				})(document);
#  			} else {
#  				(function(document){
#
#  						var scriptEl = document.createElement('script');
#  						scriptEl.src = 'https://www.bestbuy.com/~assets/bby/_com/user-generated-content/ugc-stats/dist/client/client-9e97ddb6f42e381fd8b7551170463ea7.js';
#  						scriptEl.noModule = true;
#  						scriptEl.defer = true;
#  						if (window.navigator.userAgent.indexOf("Edge") === -1) {
#  							scriptEl.async = false;
#  						}
#  						document.getElementById('user-generated-content-ugc-stats-80503912').appendChild(scriptEl);
#
#  				})(document);
#  			}
#  		</script>
#  			<script>
#  			initializer.initializeComponent({"creatorNamespace":"user-generated-content","componentId":"ugc-stats","contractVersion":"v2","componentVersion":"2.2.19"}, 'user-generated-content-ugc-stats-80503912', "{\"app\":{\"device\":{\"isLarge\":true,\"isSmall\":false},\"instanceId\":\"user-generated-content-ugc-stats-80503912\",\"renderStyle\":\"smallStandard\",\"sku\":\"6414016\"},\"exp\":{\"expertStats\":{}},\"metaLayer\":{\"env_assets\":\"https:\\u002F\\u002Fwww.bestbuy.com\\u002F~assets\\u002Fbby\\u002F_com\",\"env_piscesUrl\":\"https:\\u002F\\u002Fpisces.bbystatic.com\",\"env_appServer\":\"https:\\u002F\\u002Fwww.bestbuy.com\"},\"qna\":{\"qnaStats\":{}},\"rnr\":{\"hideEmptyStars\":false,\"histogramsEnabled\":true,\"popoverEnabled\":true,\"reviewsLinkAction\":\"pdp\",\"reviewStats\":{\"sku\":\"6414016\",\"averageOverallRating\":{\"actual\":4.81151832460733,\"rounded\":4.8},\"topRated\":true,\"totalReviewCount\":191,\"verifiedPurchaseCount\":190,\"recommendedCount\":187,\"recommendedPercent\":98,\"distributions\":[{\"distributionCode\":\"RATING\",\"items\":[{\"value\":1,\"count\":2,\"roundedPercent\":1,\"actualPercent\":1.0471204188481675},{\"value\":2,\"count\":2,\"roundedPercent\":1,\"actualPercent\":1.0471204188481675},{\"value\":3,\"count\":4,\"roundedPercent\":2,\"actualPercent\":2.094240837696335},{\"value\":4,\"count\":14,\"roundedPercent\":7,\"actualPercent\":7.329842931937173},{\"value\":5,\"count\":169,\"roundedPercent\":89,\"actualPercent\":88.48167539267016}]}],\"isReviewable\":true,\"rnrStandalonePage\":\"\\u002Fsite\\u002Freviews\\u002Fmortal-kombat-11-ultimate-edition-playstation-5\\u002F6414016\",\"writeAReview\":\"\\u002Fsite\\u002Freviews\\u002Fsubmission\\u002F6414016?campaignId=PDP_&return=\",\"rnrAccordion\":\"\\u002Fsite\\u002Fmortal-kombat-11-ultimate-edition-playstation-5\\u002F6414016.p?skuId=6414016#tabbed-customerreviews\"},\"variant\":\"\"}}", 'en-US');
#  		</script>
#  		</div></div></div></div><div></div><div></div></div><div class="price-block"><div class="sku-list-item-price"><div><div class="None" data-version="1.2043.12" id="pricing-price-77881252">
#
#  			<div class="pricing-price"><div class="pricing-price" data-csi-destinationzipcode="None" data-csi-tiercode="None" data-reactroot=""><div class="pricing-lib-price-8-2043-12 price-view-pb priceView-layout-medium" data-bold="false" data-bundledversion="8.2043.12" data-buyingoptionsonly="false" data-context="PLP-PriceBlock" data-disablebuyingoptions="true" data-disabledynamicgvppricing="false" data-disableensureassets="true" data-disablegiftwithpurchase="false" data-disablepricematchguarantee="false" data-disableupdateoncart="false" data-disableusepricewithcart="false" data-easyreplenishprice="false" data-enablealignright="false" data-enablemmtpricing="false" data-enablereference="false" data-fixedheight="false" data-ispricefetching="false" data-layout="medium" data-openboxcondition="" data-openboxfacet="false" data-pricewithbundle="false" data-randomgenerateduniqueid="6915088666926814" data-serverrendering="true" data-showgwp="false" data-skuid="6414016" data-suppressmemberbadges="false" data-suppressrestrictedprice="false" data-unlockedretailoption="false" data-version="8.2043.12" data-viewtype="price"><div class="pricing-price pricing-lib-price-8-2043-12 priceView-price" data-version="8.2043.12"><div class="priceView-price-match-guarantee"><span class="c-overlay-wrapper"><span class="overlayTrigger"><button aria-controls="price-match-guarantee-overlay-id-6915088666926814" aria-expanded="false" class="btn btn-link-unstyled v-medium price-match-guarantee-badge" type="button"> Price Match Guarantee</button></span></span></div><div class=""><div><div><div class="priceView-hero-price priceView-customer-price"><span aria-hidden="true">$59.99</span><span class="sr-only">Your price for this item is $<!-- -->59.99</span></div></div></div></div></div></div></div></div>
#
#  			<script>
#  			initializer.initializeComponent({"creatorNamespace":"pricing","componentId":"price","contractVersion":"v1","componentVersion":"1.2043.12"}, "pricing-price-77881252", "{\"app\":{\"instanceId\":\"pricing-price-77881252\",\"skuId\":\"6414016\",\"layout\":\"medium\",\"context\":\"PLP-PriceBlock\",\"openBoxCondition\":\"\",\"enableAlignRight\":false,\"enableReference\":false,\"enableMMTPricing\":false,\"openBoxFacet\":\"false\",\"priceDomain\":{\"skuId\":\"6414016\",\"regularPrice\":59.99,\"currentPrice\":59.99,\"priceEventType\":\"regular\",\"totalSavings\":0,\"totalSavingsPercent\":0,\"customerPrice\":59.99,\"isMAP\":false,\"isPriceMatchGuarantee\":true,\"gspUnitPrice\":59.99,\"dotComDisplayStatus\":\"active\",\"locationId\":\"960\",\"currentAsOfDate\":\"2021-01-05T05:11:26 GMT\"},\"bundlePriceGVPServer\":{},\"mmtItemPriceServerData\":{},\"isPriceFetching\":false,\"priceWithBundle\":false,\"cookies\":{},\"disableDynamicGVPPricing\":false,\"configuration\":{\"allAccessModalNodeId\":\"all-access-modal-content\",\"gifts-with-purchase\":{\"enableInstanceIdInjection\":true,\"disableOfferLinkService\":false,\"features\":{\"clientSideRenderingOnly\":true,\"showNewGWPModalContent\":false}},\"bundle-and-save\":{\"features\":{\"showNewModalContent\":false,\"showNewExperience\":true}},\"customer-account-based-offer\":{\"features\":{\"showNewCABOModalContent\":false}},\"rnPriceBlock\":{\"showRegularGwp\":true,\"showComplexGwp\":true},\"mmtPricing\":true,\"regularPriceThreshold\":0.99,\"features\":{\"caboWhenNotUsePriceWithCart\":true},\"enableComplexGwp\":false,\"gwpEmbedClientSideOnly\":true,\"returnsMessagingState\":\"on\",\"returnsMessagingAB\":[\"CMT\",22,\"8-f\"],\"useDynamicSMPSpacing\":true,\"enablePriceShimmer\":false,\"dynamicPricingContextBlacklist\":[],\"dynamicPricingHrefBlacklist\":[]},\"returnsMessagingProps\":null},\"metaLayer\":{\"env_assets\":\"https:\\u002F\\u002Fassets.bbystatic.com\",\"env_piscesUrl\":\"https:\\u002F\\u002Fpisces.bbystatic.com\"}}", "en-US");
#  		</script>
#  		</div></div></div><div></div><div class="sku-list-item-button"><div><div><div class="None" data-version="21.0.128" id="fulfillment-add-to-cart-button-53c65a08-43f1-4e55-a6ee-df8bc69684e4">
#
#  			<div class="fulfillment-add-to-cart-button"><div><div style="position:relative"><button class="btn btn-primary btn-sm btn-block btn-leading-ficon add-to-cart-button" data-sku-id="6414016" style="padding:0 8px" type="button"><svg aria-hidden="true" role="img" style="width:16px;height:16px;margin-bottom:-2px;margin-right:9px;fill:currentColor" viewBox="0 0 100 100"><use href="/~assets/bby/_img/int/plsvgdef-frontend/svg/cart.svg#cart" xlink:href="/~assets/bby/_img/int/plsvgdef-frontend/svg/cart.svg#cart"></use></svg>Add to Cart</button><span id="wait-overlay-6414016"></span><span class="c-overlay-wrapper"><span class="overlayTrigger"><div aria-controls="wait-overlay-6414016" aria-describedby="wait-overlay-6414016" aria-expanded="false" style="width:0;height:0"></div></span></span></div></div></div>
#
#  			<script>
#  			initializer.initializeComponent({"creatorNamespace":"fulfillment","componentId":"add-to-cart-button","contractVersion":"v1","componentVersion":"21.0.128"}, "fulfillment-add-to-cart-button-53c65a08-43f1-4e55-a6ee-df8bc69684e4", "{\"app\":{\"attachModal\":{\"isShowing\":false,\"instanceNumber\":0},\"tests\":{\"sold-out-openbox\":{\"scaled\":true,\"ignore\":false},\"combo-availability-plp\":{\"scaled\":true,\"ignore\":false}},\"context\":\"plp\",\"xboxAllAccess\":false,\"instanceId\":\"fulfillment-add-to-cart-button-53c65a08-43f1-4e55-a6ee-df8bc69684e4\",\"blockLevel\":true,\"size\":\"small\",\"disabled\":false,\"chatForServiceUrl\":\"\\u002Fusw\\u002Fcovertops\",\"learnMoreUrl\":\"\\u002Fsite\\u002Fhome-security-solutions\\u002Fsmart-home\\u002Fpcmcat748302047019.c?id=pcmcat748302047019\",\"attachModalEnabled\":true,\"buttonStateSourceRouteEnabled\":true,\"inHomeConsultationUrl\":\"https:\\u002F\\u002Fwww.bestbuy.com\\u002Fservices\\u002Fin-home-advisor\\u002Fhome\",\"maxComboSkusExceeded\":false,\"soldOutDispatchDisabled\":true,\"reportingVariables\":{},\"pickupTodayStores\":[],\"disasterFallBackLists\":{},\"xboxAllAccessModal\":{\"isShowing\":false,\"instanceNumber\":0},\"skuPdpUrl\":\"\\u002Fsite\\u002Fmortal-kombat-11-ultimate-edition-playstation-5\\u002F6414016.p?skuId=6414016\"},\"items\":[{\"skuId\":\"6414016\",\"condition\":null,\"tags\":[\"tag\\u002Fprimary\"]}],\"buttonState\":{\"$__path\":[\"shop\",\"buttonstate\",\"v5\",\"item\",\"optional\",\"skus\",\"6414016\",\"conditions\",\"NONE\",\"destinationZipCode\",\"%20\",\"storeId\",\"%20\",\"storeZipCode\",\"%20\",\"context\",\"plp\",\"addAll\",\"false\",\"consolidated\",\"false\",\"source\",\"buttonView\",\"xboxAllAccess\",\"false\",\"buttonStateResponseInfos\",0],\"buttonState\":\"ADD_TO_CART\",\"displayText\":\"Add to Cart\"},\"metaLayer\":{\"env_assets\":\"https:\\u002F\\u002Fassets.bbystatic.com\",\"env_piscesUrl\":\"https:\\u002F\\u002Fpisces.bbystatic.com\",\"env_appServer\":\"https:\\u002F\\u002Fwww.bestbuy.com\"}}", "en-US");
#  		</script>
#  		</div></div></div></div><div></div><div class="buying-options-only"><div><div class="" data-version="1.2043.12" id="pricing-price-2261336">
#
#  			<div class="pricing-price"><div class="pricing-price" data-csi-destinationzipcode="None" data-csi-tiercode="None" data-reactroot=""><div class="pricing-lib-price-8-2043-12 price-view-pb priceView-layout-medium" data-bold="false" data-bundledversion="8.2043.12" data-buyingoptionsonly="true" data-context="PLP-PriceBlock" data-disablebuyingoptions="true" data-disabledynamicgvppricing="false" data-disableensureassets="true" data-disablegiftwithpurchase="false" data-disablepricematchguarantee="false" data-disableupdateoncart="false" data-disableusepricewithcart="false" data-easyreplenishprice="false" data-enablealignright="false" data-enablemmtpricing="false" data-enablereference="false" data-fixedheight="false" data-ispricefetching="false" data-layout="medium" data-openboxcondition="" data-openboxfacet="false" data-pricewithbundle="false" data-randomgenerateduniqueid="8541438289898411" data-serverrendering="true" data-showgwp="false" data-skuid="6414016" data-suppressmemberbadges="false" data-suppressrestrictedprice="false" data-unlockedretailoption="false" data-version="8.2043.12" data-viewtype="price"></div></div></div>
#
#  			<script>
#  			initializer.initializeComponent({"creatorNamespace":"pricing","componentId":"price","contractVersion":"v1","componentVersion":"1.2043.12"}, "pricing-price-2261336", "{\"app\":{\"instanceId\":\"pricing-price-2261336\",\"skuId\":\"6414016\",\"layout\":\"medium\",\"context\":\"PLP-PriceBlock\",\"openBoxCondition\":\"\",\"buyingOptionsOnly\":\"true\",\"enableAlignRight\":false,\"enableReference\":false,\"enableMMTPricing\":false,\"openBoxFacet\":\"false\",\"priceDomain\":{\"skuId\":\"6414016\",\"regularPrice\":59.99,\"currentPrice\":59.99,\"priceEventType\":\"regular\",\"totalSavings\":0,\"totalSavingsPercent\":0,\"customerPrice\":59.99,\"isMAP\":false,\"isPriceMatchGuarantee\":true,\"gspUnitPrice\":59.99,\"dotComDisplayStatus\":\"active\",\"locationId\":\"960\",\"currentAsOfDate\":\"2021-01-05T05:11:26 GMT\"},\"bundlePriceGVPServer\":{},\"mmtItemPriceServerData\":{},\"isPriceFetching\":false,\"priceWithBundle\":false,\"cookies\":{},\"disableDynamicGVPPricing\":false,\"configuration\":{\"allAccessModalNodeId\":\"all-access-modal-content\",\"gifts-with-purchase\":{\"enableInstanceIdInjection\":true,\"disableOfferLinkService\":false,\"features\":{\"clientSideRenderingOnly\":true,\"showNewGWPModalContent\":false}},\"bundle-and-save\":{\"features\":{\"showNewModalContent\":false,\"showNewExperience\":true}},\"customer-account-based-offer\":{\"features\":{\"showNewCABOModalContent\":false}},\"rnPriceBlock\":{\"showRegularGwp\":true,\"showComplexGwp\":true},\"mmtPricing\":true,\"regularPriceThreshold\":0.99,\"features\":{\"caboWhenNotUsePriceWithCart\":true},\"enableComplexGwp\":false,\"gwpEmbedClientSideOnly\":true,\"returnsMessagingState\":\"on\",\"returnsMessagingAB\":[\"CMT\",22,\"8-f\"],\"useDynamicSMPSpacing\":true,\"enablePriceShimmer\":false,\"dynamicPricingContextBlacklist\":[],\"dynamicPricingHrefBlacklist\":[]},\"returnsMessagingProps\":null},\"metaLayer\":{\"env_assets\":\"https:\\u002F\\u002Fassets.bbystatic.com\",\"env_piscesUrl\":\"https:\\u002F\\u002Fpisces.bbystatic.com\"}}", "en-US");
#  		</script>
#  		</div></div></div></div></div></div></div>
#
#  			<script>
#  			initializer.initializeComponent({"creatorNamespace":"shop","componentId":"sku-list-item","contractVersion":"v2","componentVersion":"20.16.17"}, "shop-sku-list-item-183dd6dc-cb9f-4433-b3ce-63cd860a4e8c", "{\"app\":{\"skuId\":\"6414016\",\"deviceClass\":\"l\",\"instanceId\":\"shop-sku-list-item-183dd6dc-cb9f-4433-b3ce-63cd860a4e8c\",\"inViewport\":false,\"isSponsored\":false,\"variationId\":\"d13057a2-a346-41bd-8424-0c946c92c8c8\",\"highlightedVariationSkuId\":\"6414016\",\"lazyLoadOffset\":-400,\"disableFulfillmentForVariation\":false},\"metaLayer\":{\"env_piscesUrl\":\"https:\\u002F\\u002Fpisces.bbystatic.com\",\"env_appServer\":\"https:\\u002F\\u002Fwww.bestbuy.com\"},\"searchDerived\":{\"isOpenBoxFacetSelected\":false},\"sku\":{\"customerRatings\":4.8,\"image\":{\"alt\":\"Mortal Kombat 11: Ultimate Edition - PlayStation 5 - Front_Zoom\",\"src\":\"image2\\u002FBestBuy_US\\u002Fimages\\u002Fproducts\\u002F6414\\u002F6414016_sd.jpg\"},\"link\":\"\\u002Fsite\\u002Fmortal-kombat-11-ultimate-edition-playstation-5\\u002F6414016.p?skuId=6414016\",\"numberOfReviews\":191,\"name\":\"Mortal Kombat 11: Ultimate Edition - PlayStation 5\",\"skuId\":\"6414016\",\"publisher\":\"Warner Bros. Games\",\"esrbRating\":\"M (Mature 17+)\",\"releaseDate\":{\"notYetAnnounced\":false,\"date\":\"11\\u002F17\\u002F2020\"},\"isOpenBoxAvailable\":false,\"isNew\":false,\"isOpenBoxOnly\":false,\"productVariation\":{\"variationSkuList\":[{\"skuId\":\"6414016\",\"image\":null,\"link\":\"https:\\u002F\\u002Fwww.bestbuy.com\\u002Fsite\\u002Fmortal-kombat-11-ultimate-edition-playstation-5\\u002F6414016.p?skuId=6414016\",\"name\":\"Mortal Kombat 11: Ultimate Edition - PlayStation 5\",\"hoverName\":\"PlayStation 5\"},{\"skuId\":\"6414030\",\"image\":null,\"link\":\"https:\\u002F\\u002Fwww.bestbuy.com\\u002Fsite\\u002Fmortal-kombat-11-ultimate-edition-xbox-one-xbox-series-x\\u002F6414030.p?skuId=6414030\",\"name\":\"Mortal Kombat 11: Ultimate Edition - Xbox One, Xbox Series X\",\"hoverName\":\"Xbox One \\u002F Xbox Series X\"}],\"variationName\":\"Platform\"},\"detailDisplayText\":\"SEE_MORE_OPTIONS\"}}", "en-US");
#  		</script>
#  		</div></div></div></li>]

# %%
prices = []
for j in each_item:
    price_block = j.find(class_ = "price-block")
    price = price_block.find(class_ = "sku-list-item-price")
    actual_price = price.find(class_ = "priceView-hero-price priceView-customer-price")
    if actual_price != None:
        #print(actual_price.get_text())
        price = actual_price.find({"span": "aria-hidden"})
        #print(price.get_text())
        prices.append(price.get_text())
prices
# Out:
# ['$99.99',
#  '$29.99',
#  '$49.99',
#  '$39.99',
#  '$59.99',
#  '$69.99',
#  '$69.99',
#  '$39.99',
#  '$69.99',
#  '$69.99',
#  '$79.99',
#  '$59.99',
#  '$69.99',
#  '$29.99',
#  '$59.99',
#  '$49.99',
#  '$99.99',
#  '$59.99',
#  '$79.99',
#  '$49.99',
#  '$49.99',
#  '$79.99',
#  '$49.99',
#  '$59.99']

# %%
game_titles = []
for j in each_item:
    title = j.find(class_ = "sku-title")
    #print(title)
    game_title = title.find(class_ = "sku-header")
    
    #actual_price = price.find(class_ = "priceView-hero-price priceView-customer-price")
    if game_title != None:
        #print(actual_price.get_text())
        #price = actual_price.find({"span": "aria-hidden"})
        #print(price.get_text())
        game_titles.append(game_title.get_text())
game_titles
# Out:
# ['NBA 2K21 Mamba Forever Edition - PlayStation 5',
#  'Immortals Fenyx Rising Standard Edition - PlayStation 5',
#  "Marvel's Spider-Man: Miles Morales Standard Launch Edition - PlayStation 5",
#  'Cyberpunk 2077 Standard Edition - PlayStation 4, PlayStation 5',
#  'DIRT 5 - PlayStation 5',
#  'Hitman 3 - PlayStation 5',
#  'FIFA 21 - PlayStation 5',
#  "Marvel's Spider-Man: Miles Morales Ultimate Launch Edition - PlayStation 5",
#  "Assassin's Creed Valhalla Standard Edition - PlayStation 5",
#  'LEGO Star Wars: The Skywalker Saga Deluxe Edition - PlayStation 5',
#  'NBA 2K21 Standard Edition - PlayStation 5',
#  'Hitman 3 Deluxe Edition - PlayStation 5',
#  'Sackboy: A Big Adventure Standard - PlayStation 5',
#  "Demon's Souls Standard Edition - PlayStation 5",
#  'Watch Dogs: Legion - PlayStation 5',
#  'Madden NFL 21 - PlayStation 4, PlayStation 5',
#  'WRC 9 - PlayStation 5',
#  'New!Back 4 Blood Ultimate Edition - PlayStation 5',
#  'Outriders Day 1 Edition - PlayStation 5',
#  'DEATHLOOP Deluxe Edition - PlayStation 5',
#  'Overcooked! All you Can Eat - PlayStation 5',
#  'Planet Coaster - PlayStation 5',
#  'Godfall Ascended Edition - PlayStation 5',
#  'Godfall - PlayStation 5',
#  'Mortal Kombat 11: Ultimate Edition - PlayStation 5']

# %%
game_ratings = []
for j in each_item:
    rating = j.find(class_ = "variation-info")
    game_ratings.append(rating.find_next("div").find_next("div").find_next("div").find_next("div").find_next("div").find_next("a").get_text())
game_ratings
# Out:
# ['E (Everyone)',
#  'T (Teen 13+)',
#  'T (Teen 13+)',
#  'M (Mature 17+)',
#  'E (Everyone)',
#  'M (Mature 17+)',
#  'E (Everyone)',
#  'T (Teen 13+)',
#  'PlayStation 4 / PlayStation 5',
#  'Nintendo Switch / Nintendo Switch Lite',
#  'Nintendo Switch',
#  'M (Mature 17+)',
#  'E (Everyone)',
#  'M (Mature 17+)',
#  'M (Mature 17+)',
#  'E (Everyone)',
#  'E (Everyone)',
#  'PlayStation 4',
#  'RP (Rating Pending)',
#  'RP (Rating Pending)',
#  'User rating, 5 out of 5 stars with 7 reviews.(7)',
#  'RP (Rating Pending)',
#  'T (Teen 13+)',
#  'T (Teen 13+)',
#  'selectedPlayStation 5']

# %%
publishers = []
for j in each_item:
    publisher = j.find(class_ = "variation-info")
    publisher_publisher = publisher.find(class_ = "attribute-title")
    publisher_publisher_publisher = publisher.find(class_ = "sku-value")
    publishers.append(publisher_publisher.get_text() + " " + publisher_publisher_publisher.get_text())
    #publishers.append(rating.find_next("div").find_next("div"))
publishers
# Out:
# ['Publisher: 2K',
#  'Publisher: Ubisoft',
#  'Publisher: Sony Interactive Entertainment',
#  'Publisher: WB Games',
#  'Publisher: Nordic Games',
#  'Publisher: IO Interactive',
#  'Publisher: Electronic Arts',
#  'Publisher: Sony Interactive Entertainment',
#  'Publisher: Ubisoft',
#  'Publisher: WB Games',
#  'Publisher: 2K',
#  'Publisher: Limited Run Games',
#  'Publisher: Sony Interactive Entertainment',
#  'Publisher: Sony Interactive Entertainment',
#  'Publisher: Ubisoft',
#  'Publisher: Electronic Arts',
#  'Publisher: Maximum Games',
#  'Publisher: Warner Bros. Games',
#  'Publisher: Square Enix',
#  'Publisher: Bethesda',
#  'Publisher: Sold Out',
#  'Publisher: Sold Out',
#  'Publisher: Gearbox Publishing',
#  'Publisher: Gearbox Publishing',
#  'Publisher: Warner Bros. Games']

# %%
dates = []
for j in each_item:
    date = j.find(class_ = "variation-info")
    #publisher_publisher = publisher.find(class_ = "attribute-title")
    #publisher_publisher_publisher = publisher.find(class_ = "sku-value")
    dates.append(date.find_next("div").find_next("div").find_next("div").find_next("div").get_text())
    #publishers.append(rating.find_next("div").find_next("div"))
dates
# Out:
# ['Release Date: 11/12/2020',
#  'Release Date: 12/03/2020',
#  'Release Date: 11/12/2020',
#  'Release Date: 12/10/2020',
#  'Release Date: 11/19/2020',
#  'Release Date: 01/20/2021',
#  'Release Date: 12/04/2020',
#  'Release Date: 11/12/2020',
#  'PlayStation 5',
#  'PlayStation 5',
#  'PlayStation 5',
#  'Release Date: 01/20/2021',
#  'Release Date: 11/12/2020',
#  'Release Date: 11/12/2020',
#  'Release Date: 11/24/2020',
#  'Release Date: 08/28/2020',
#  'Release Date: 12/08/2020',
#  'PlayStation 5',
#  'Release Date: 02/02/2021',
#  'Release Date: 05/21/2021',
#  'ESRB Rating: RP (Rating Pending)',
#  'Release Date: 11/10/2020',
#  'Release Date: 11/12/2020',
#  'Release Date: 11/12/2020',
#  'PlayStation 5']

# %%
reviews = []
for j in each_item:
    review = j.find(class_ = "variation-info")
    #publisher_publisher = publisher.find(class_ = "attribute-title")
    #publisher_publisher_publisher = publisher.find(class_ = "sku-value")
    review_rating = review.find(class_ = "ugc-ratings-reviews c-ratings-reviews-v4 c-ratings-reviews-v4-size-small")
    reviews.append(review_rating.get_text())
    #publishers.append(rating.find_next("div").find_next("div"))
#dates
reviews
# Out:
# ['User rating, 4.7 out of 5 stars with 334 reviews.(334)',
#  'User rating, 4.7 out of 5 stars with 147 reviews.(147)',
#  'User rating, 4.8 out of 5 stars with 1011 reviews.(1,011)',
#  'User rating, 3.3 out of 5 stars with 1494 reviews.(1,494)',
#  'User rating, 4.6 out of 5 stars with 25 reviews.(25)',
#  'Not yet reviewedNot yet reviewed',
#  'User rating, 4.8 out of 5 stars with 20 reviews.(20)',
#  'User rating, 4.9 out of 5 stars with 1097 reviews.(1,097)',
#  'User rating, 4.7 out of 5 stars with 511 reviews.(511)',
#  'Not yet reviewedNot yet reviewed',
#  'User rating, 4.6 out of 5 stars with 256 reviews.(256)',
#  'Not yet reviewedNot yet reviewed',
#  'User rating, 4.9 out of 5 stars with 251 reviews.(251)',
#  'User rating, 4.8 out of 5 stars with 753 reviews.(753)',
#  'User rating, 4.3 out of 5 stars with 380 reviews.(380)',
#  'User rating, 4.4 out of 5 stars with 1350 reviews.(1,350)',
#  'User rating, 4.4 out of 5 stars with 7 reviews.(7)',
#  'Not yet reviewedNot yet reviewed',
#  'Not yet reviewedNot yet reviewed',
#  'Not yet reviewedNot yet reviewed',
#  'User rating, 5 out of 5 stars with 7 reviews.(7)',
#  'User rating, 4.9 out of 5 stars with 23 reviews.(23)',
#  'User rating, 4.1 out of 5 stars with 62 reviews.(62)',
#  'User rating, 3.7 out of 5 stars with 152 reviews.(152)',
#  'User rating, 4.8 out of 5 stars with 191 reviews.(191)']

# %%
next_resp = requests.get("https://www.bestbuy.com/site/searchpage.jsp?_dyncharset=UTF-8&browsedCategory=pcmcat1587395108347&cp=2&id=pcat17071&iht=n&ks=960&list=y&sc=Global&st=categoryid%24pcmcat1587395108347&type=page&usc=All%20Categories", headers = header)
next_soup = BeautifulSoup(next_resp.text, 'html5lib')
next_items = next_soup.find(class_ = "sku-item-list")
next_each_item = next_items.find_all(class_ = "sku-item")

# %%
for j in next_each_item:
        # Price
        next_price_block = j.find(class_ = "price-block")
        next_price = next_price_block.find(class_ = "sku-list-item-price")
        #next_actual_price = next_price.find(class_ = "pricing-price")
        #next_actual_price = next_price.find(class_ = "sr-only")
        next_actual_price = next_price.find(class_ = "priceView-hero-price priceView-customer-price")
        #if next_actual_price != None:
        price = next_actual_price.find({"span": "aria-hidden"})
                #print(price.get_text())

        prices.append(price.get_text())
        #elif next_actual_price == None:
        #prices.append('NaN')
        #prices.append('NaN')
prices
len(prices)
# Out:
# 49

# %%
for j in next_each_item:
        # Price
    if game_title != None:

            # Game Titles
            title = j.find(class_ = "sku-title")
            game_title = title.find(class_ = "sku-header")
            game_titles.append(game_title.get_text())
    else:
        game_titles.append('NaN')
game_titles
len(game_titles)
# Out:
# 50

# %%
for j in next_each_item:
        # Price
    rating = j.find(class_ = "variation-info")
    game_ratings.append(rating.find_next("div").find_next("div").find_next("div").find_next("div").find_next("div").get_text())
game_ratings
len(game_ratings)
# Out:
# 50

# %%
for j in next_each_item:
    publisher = j.find(class_ = "variation-info")
    publisher_publisher = publisher.find(class_ = "attribute-title")
    publisher_publisher_publisher = publisher.find(class_ = "sku-value")
    publishers.append(publisher_publisher.get_text() + " " + publisher_publisher_publisher.get_text())
publishers
len(publishers)
# Out:
# 50

# %%
for j in next_each_item:
    date = j.find(class_ = "variation-info")
    dates.append(date.find_next("div").find_next("div").find_next("div").find_next("div").get_text())
dates
len(dates)
# Out:
# 50

# %%
for j in next_each_item:
    review = j.find(class_ = "variation-info")
    review_rating = review.find(class_ = "ugc-ratings-reviews c-ratings-reviews-v4 c-ratings-reviews-v4-size-small")
    reviews.append(review_rating.get_text())
reviews
len(reviews)
# Out:
# 50

# %%
prices.append('NaN')
len(prices)
# Out:
# 50

# %% [markdown]
# # Web Scraping for Pages 2 and 3

# %%
len(prices)
# Out:
# 153

# %%
prices
# Out:
# ['$39.99',
#  '$29.99',
#  '$49.99',
#  '$39.99',
#  '$69.99',
#  '$59.99',
#  '$69.99',
#  '$69.99',
#  '$59.99',
#  '$29.99',
#  '$49.99',
#  '$99.99',
#  '$69.99',
#  '$69.99',
#  '$49.99',
#  '$69.99',
#  '$49.99',
#  '$49.99',
#  '$49.99',
#  '$79.99',
#  '$59.99',
#  '$29.99',
#  '$59.99',
#  '$69.99',
#  '$49.99',
#  '$29.99',
#  '$59.99',
#  '$29.99',
#  '$99.99',
#  '$69.99',
#  '$29.99',
#  '$59.99',
#  '$99.99',
#  '$59.99',
#  '$39.99',
#  '$59.99',
#  '$39.99',
#  '$79.99',
#  '$99.99',
#  '$89.99',
#  '$109.99',
#  '$69.99',
#  '$59.99',
#  '$49.99',
#  '$69.99',
#  '$39.99',
#  '$99.99',
#  '$59.99',
#  '$59.99',
#  '$49.99',
#  '$34.99',
#  '$49.99',
#  '$49.99',
#  '$49.99',
#  '$49.99',
#  '$49.99',
#  '$49.99',
#  '$49.99',
#  '$49.99',
#  '$49.99',
#  '$49.99',
#  '$49.99',
#  '$49.99',
#  '$49.99',
#  '$49.99',
#  '$49.99',
#  '$49.99',
#  '$49.99',
#  '$49.99',
#  '$49.99',
#  '$49.99',
#  '$49.99',
#  '$49.99',
#  '$49.99',
#  '$49.99',
#  '$49.99',
#  '$49.99',
#  '$49.99',
#  '$49.99',
#  '$49.99',
#  '$49.99',
#  '$69.99',
#  '$49.99',
#  '$29.99',
#  '$59.99',
#  '$29.99',
#  '$99.99',
#  '$69.99',
#  '$29.99',
#  '$59.99',
#  '$99.99',
#  '$59.99',
#  '$39.99',
#  '$59.99',
#  '$39.99',
#  '$79.99',
#  '$99.99',
#  '$89.99',
#  '$109.99',
#  '$69.99',
#  '$59.99',
#  '$49.99',
#  '$69.99',
#  '$39.99',
#  '$99.99',
#  '$59.99',
#  '$59.99',
#  '$49.99',
#  '$34.99',
#  '$49.99',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  '$69.99',
#  '$49.99',
#  '$29.99',
#  '$59.99',
#  '$29.99',
#  '$99.99',
#  '$69.99',
#  '$29.99',
#  '$59.99',
#  '$99.99',
#  '$59.99',
#  '$39.99',
#  '$59.99',
#  '$39.99',
#  '$79.99',
#  '$99.99',
#  '$89.99',
#  '$109.99',
#  '$69.99',
#  '$59.99',
#  '$49.99',
#  '$69.99',
#  '$39.99',
#  '$99.99',
#  '$59.99',
#  '$59.99',
#  '$49.99',
#  '$34.99',
#  '$49.99',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  '$69.99',
#  '$49.99',
#  '$29.99',
#  '$59.99',
#  '$29.99',
#  '$99.99',
#  '$69.99',
#  '$29.99',
#  '$59.99',
#  '$99.99',
#  '$59.99',
#  '$39.99',
#  '$59.99',
#  '$39.99',
#  '$79.99',
#  '$99.99',
#  '$89.99',
#  '$109.99',
#  '$69.99',
#  '$59.99',
#  '$49.99',
#  '$69.99',
#  '$39.99',
#  '$99.99',
#  '$59.99',
#  '$59.99',
#  '$49.99',
#  '$34.99',
#  '$49.99',
#  '$69.99',
#  '$49.99',
#  '$29.99',
#  '$59.99',
#  '$29.99',
#  '$99.99',
#  '$69.99',
#  '$29.99',
#  '$59.99',
#  '$99.99',
#  '$59.99',
#  '$39.99',
#  '$59.99',
#  '$39.99',
#  '$79.99',
#  '$99.99',
#  '$89.99',
#  '$109.99',
#  '$69.99',
#  '$59.99',
#  '$49.99',
#  '$69.99',
#  '$39.99',
#  '$99.99',
#  '$59.99',
#  '$59.99',
#  '$49.99',
#  '$34.99',
#  '$49.99',
#  '$69.99Your price for this item is $69.99',
#  '$49.99Your price for this item is $49.99',
#  '$29.99Your price for this item is $29.99',
#  '$59.99Your price for this item is $59.99',
#  '$29.99Your price for this item is $29.99',
#  '$99.99Your price for this item is $99.99',
#  '$69.99Your price for this item is $69.99',
#  '$29.99Your price for this item is $29.99',
#  '$59.99Your price for this item is $59.99',
#  '$99.99Your price for this item is $99.99',
#  '$59.99Your price for this item is $59.99',
#  '$39.99Your price for this item is $39.99',
#  '$59.99Your price for this item is $59.99',
#  '$39.99Your price for this item is $39.99',
#  '$79.99Your price for this item is $79.99',
#  '$99.99Your price for this item is $99.99',
#  '$89.99Your price for this item is $89.99',
#  '$109.99Your price for this item is $109.99',
#  '$69.99Your price for this item is $69.99',
#  '$59.99Your price for this item is $59.99',
#  '$49.99Your price for this item is $49.99',
#  '$69.99Your price for this item is $69.99',
#  '$39.99Your price for this item is $39.99',
#  '$99.99Your price for this item is $99.99',
#  '$59.99Your price for this item is $59.99',
#  '$59.99Your price for this item is $59.99',
#  '$49.99Your price for this item is $49.99',
#  '$34.99Your price for this item is $34.99',
#  '$49.99Your price for this item is $49.99',
#  '$69.99Your price for this item is $69.99',
#  '$49.99Your price for this item is $49.99',
#  '$29.99Your price for this item is $29.99',
#  '$59.99Your price for this item is $59.99',
#  '$29.99Your price for this item is $29.99',
#  '$99.99Your price for this item is $99.99',
#  '$69.99Your price for this item is $69.99',
#  '$29.99Your price for this item is $29.99',
#  '$59.99Your price for this item is $59.99',
#  '$99.99Your price for this item is $99.99',
#  '$59.99Your price for this item is $59.99',
#  '$39.99Your price for this item is $39.99',
#  '$59.99Your price for this item is $59.99',
#  '$39.99Your price for this item is $39.99',
#  '$79.99Your price for this item is $79.99',
#  '$99.99Your price for this item is $99.99',
#  '$89.99Your price for this item is $89.99',
#  '$109.99Your price for this item is $109.99',
#  '$69.99Your price for this item is $69.99',
#  '$59.99Your price for this item is $59.99',
#  '$49.99Your price for this item is $49.99',
#  '$69.99Your price for this item is $69.99',
#  '$39.99Your price for this item is $39.99',
#  '$99.99Your price for this item is $99.99',
#  '$59.99Your price for this item is $59.99',
#  '$59.99Your price for this item is $59.99',
#  '$49.99Your price for this item is $49.99',
#  '$34.99Your price for this item is $34.99',
#  '$49.99Your price for this item is $49.99',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  ' Price Match Guarantee',
#  'Your price for this item is $69.99',
#  'Your price for this item is $49.99',
#  'Your price for this item is $29.99',
#  'Your price for this item is $59.99',
#  'Your price for this item is $29.99',
#  'Your price for this item is $99.99',
#  'Your price for this item is $69.99',
#  'Your price for this item is $29.99',
#  'Your price for this item is $59.99',
#  'Your price for this item is $99.99',
#  'Your price for this item is $59.99',
#  'Your price for this item is $39.99',
#  'Your price for this item is $59.99',
#  'Your price for this item is $39.99',
#  'Your price for this item is $79.99',
#  'Your price for this item is $99.99',
#  'Your price for this item is $89.99',
#  'Your price for this item is $109.99',
#  'Your price for this item is $69.99',
#  'Your price for this item is $59.99',
#  'Your price for this item is $49.99',
#  'Your price for this item is $69.99',
#  'Your price for this item is $39.99',
#  'Your price for this item is $99.99',
#  'Your price for this item is $59.99',
#  'Your price for this item is $59.99',
#  'Your price for this item is $49.99',
#  'Your price for this item is $34.99',
#  'Your price for this item is $49.99',
#  'Your price for this item is $69.99',
#  'Your price for this item is $49.99',
#  'Your price for this item is $29.99',
#  'Your price for this item is $59.99',
#  'Your price for this item is $29.99',
#  'Your price for this item is $99.99',
#  'Your price for this item is $69.99',
#  'Your price for this item is $29.99',
#  'Your price for this item is $59.99',
#  'Your price for this item is $99.99',
#  'Your price for this item is $59.99',
#  'Your price for this item is $39.99',
#  'Your price for this item is $59.99',
#  'Your price for this item is $39.99',
#  'Your price for this item is $79.99',
#  'Your price for this item is $99.99',
#  'Your price for this item is $89.99',
#  'Your price for this item is $109.99',
#  'Your price for this item is $69.99',
#  'Your price for this item is $59.99',
#  'Your price for this item is $49.99',
#  'Your price for this item is $69.99',
#  'Your price for this item is $39.99',
#  'Your price for this item is $99.99',
#  'Your price for this item is $59.99',
#  'Your price for this item is $59.99',
#  'Your price for this item is $49.99',
#  'Your price for this item is $34.99',
#  'Your price for this item is $49.99']

# %%
dct = {
    'Game Title': game_titles,
    'Game Rating': game_ratings,
    'Game Publisher': publishers,
    'Game Release Date': dates,
    'Review': reviews,
    'Price': prices
}

# %%
df = pd.DataFrame(dct)

# %%
df.to_csv("Video_Game_Info.csv")
