# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("Video_Game_Info.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                                         Game Title  \
# 0           0  Assassin's Creed Valhalla Standard Edition - P...
# 1           1  Marvel's Spider-Man: Miles Morales Ultimate La...
# 2           2  Call of Duty: Black Ops Cold War Standard Edit...
# 3           3  Marvel's Spider-Man: Miles Morales Standard La...
# 4           4  Cyberpunk 2077 Standard Edition - PlayStation ...
#
#       Game Rating                             Game Publisher  \
# 0  M (Mature 17+)                         Publisher: Ubisoft
# 1    T (Teen 13+)  Publisher: Sony Interactive Entertainment
# 2  M (Mature 17+)           Publisher: Activision Publishing
# 3    T (Teen 13+)  Publisher: Sony Interactive Entertainment
# 4  M (Mature 17+)                        Publisher: WB Games
#
#           Game Release Date  \
# 0  Release Date: 11/12/2020
# 1  Release Date: 11/12/2020
# 2  Release Date: 11/13/2020
# 3  Release Date: 11/12/2020
# 4  Release Date: 12/10/2020
#
# ...

# %%
df.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
df
# Out:
#                                            Game Title  \
# 0   Assassin's Creed Valhalla Standard Edition - P...
# 1   Marvel's Spider-Man: Miles Morales Ultimate La...
# 2   Call of Duty: Black Ops Cold War Standard Edit...
# 3   Marvel's Spider-Man: Miles Morales Standard La...
# 4   Cyberpunk 2077 Standard Edition - PlayStation ...
# 5             Hitman 3 Deluxe Edition - PlayStation 5
# 6                  Watch Dogs: Legion - PlayStation 5
# 7        Madden NFL 21 - PlayStation 4, PlayStation 5
# 8    Madden NFL 21 Next Level Edition - PlayStation 5
# 9           NBA 2K21 Standard Edition - PlayStation 5
# 10             Godfall Deluxe Edition - PlayStation 5
# 11     Demon's Souls Standard Edition - PlayStation 5
# 12  Immortals Fenyx Rising Standard Edition - Play...
# 13           Godfall Ascended Edition - PlayStation 5
# 14                            Godfall - PlayStation 5
# 15  Mortal Kombat 11: Ultimate Edition - PlayStati...
# ...

# %%
df['Review'] = df['Review'].str.replace('User rating,', '')

# %%
#df['Review'] = df['Review'].str.replace('Not yet reviewedNot yet reviewed', '')

# %%
df
# Out:
#                                            Game Title  \
# 0   Assassin's Creed Valhalla Standard Edition - P...
# 1   Marvel's Spider-Man: Miles Morales Ultimate La...
# 2   Call of Duty: Black Ops Cold War Standard Edit...
# 3   Marvel's Spider-Man: Miles Morales Standard La...
# 4   Cyberpunk 2077 Standard Edition - PlayStation ...
# 5             Hitman 3 Deluxe Edition - PlayStation 5
# 6                  Watch Dogs: Legion - PlayStation 5
# 7        Madden NFL 21 - PlayStation 4, PlayStation 5
# 8    Madden NFL 21 Next Level Edition - PlayStation 5
# 9           NBA 2K21 Standard Edition - PlayStation 5
# 10             Godfall Deluxe Edition - PlayStation 5
# 11     Demon's Souls Standard Edition - PlayStation 5
# 12  Immortals Fenyx Rising Standard Edition - Play...
# 13           Godfall Ascended Edition - PlayStation 5
# 14                            Godfall - PlayStation 5
# 15  Mortal Kombat 11: Ultimate Edition - PlayStati...
# ...

# %%
#df = df.dropna(axis = 0)
df
# Out:
#                                            Game Title  \
# 0   Assassin's Creed Valhalla Standard Edition - P...
# 1   Marvel's Spider-Man: Miles Morales Ultimate La...
# 2   Call of Duty: Black Ops Cold War Standard Edit...
# 3   Marvel's Spider-Man: Miles Morales Standard La...
# 4   Cyberpunk 2077 Standard Edition - PlayStation ...
# 5             Hitman 3 Deluxe Edition - PlayStation 5
# 6                  Watch Dogs: Legion - PlayStation 5
# 7        Madden NFL 21 - PlayStation 4, PlayStation 5
# 8    Madden NFL 21 Next Level Edition - PlayStation 5
# 9           NBA 2K21 Standard Edition - PlayStation 5
# 10             Godfall Deluxe Edition - PlayStation 5
# 11     Demon's Souls Standard Edition - PlayStation 5
# 12  Immortals Fenyx Rising Standard Edition - Play...
# 13           Godfall Ascended Edition - PlayStation 5
# 14                            Godfall - PlayStation 5
# 15  Mortal Kombat 11: Ultimate Edition - PlayStati...
# ...

# %%
#df['Review'] = df['Review'].str.split('with')
# Out:
# <ipython-input-11-1f53578c239c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Review'] = df['Review'].str.split('with')

# %%
df = df[df['Review'] != 'Not yet reviewedNot yet reviewed']

# %%
df.Review = df.Review.apply(lambda x: x.split('.'))
# Out:
# C:\Users\Rithi\anaconda3\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
ratings_lst = []
for i in df.Review:
    if len(i) == 2:
        ratings_lst.append(i[1])
    else:
        ratings_lst.append(i[2])
ratings_lst
# Out:
# ['(514)',
#  '(1,106)',
#  '(1,258)',
#  '(1,020)',
#  '(1,534)',
#  '(384)',
#  '(1,361)',
#  '(80)',
#  '(258)',
#  '(14)',
#  '(757)',
#  '(149)',
#  '(62)',
#  '(153)',
#  '(197)',
#  '(254)',
#  '(5)',
#  '(7)',
#  '(21)',
#  '(258)',
#  '(23)',
#  '(101)',
#  '(48)',
#  '(734)',
#  '(25)',
#  '(79)',
#  '(35)',
#  '(67)',
#  '(7)',
#  '(27)',
#  '(336)',
#  '(15)']

# %%
df['Ratings'] = pd.Series(ratings_lst, index = df.index)
# Out:
# <ipython-input-86-c238df3357ac>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Ratings'] = pd.Series(ratings_lst, index = df.index)

# %%
df
# Out:
#                                            Game Title  \
# 0   Assassin's Creed Valhalla Standard Edition - P...
# 1   Marvel's Spider-Man: Miles Morales Ultimate La...
# 2   Call of Duty: Black Ops Cold War Standard Edit...
# 3   Marvel's Spider-Man: Miles Morales Standard La...
# 4   Cyberpunk 2077 Standard Edition - PlayStation ...
# 6                  Watch Dogs: Legion - PlayStation 5
# 7        Madden NFL 21 - PlayStation 4, PlayStation 5
# 8    Madden NFL 21 Next Level Edition - PlayStation 5
# 9           NBA 2K21 Standard Edition - PlayStation 5
# 10             Godfall Deluxe Edition - PlayStation 5
# 11     Demon's Souls Standard Edition - PlayStation 5
# 12  Immortals Fenyx Rising Standard Edition - Play...
# 13           Godfall Ascended Edition - PlayStation 5
# 14                            Godfall - PlayStation 5
# 15  Mortal Kombat 11: Ultimate Edition - PlayStati...
# 19  Sackboy: A Big Adventure Standard - PlayStation 5
# ...

# %%
df.Review = df.Review.apply(lambda x: x[0:2])
# Out:
# C:\Users\Rithi\anaconda3\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df.Review = df.Review.apply(lambda c: '.'.join(c))

# %%
df.Review = df.Review.str.rstrip('with')
# Out:
# C:\Users\Rithi\anaconda3\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df.Review = df.Review.apply(lambda y: y.split('with'))

# %%
df.Review = df.Review.apply(lambda u: u[0])

# %%
df.Review = df.Review.apply(lambda i: ''.join(i))

# %%
df
# Out:
#                                            Game Title  \
# 0   Assassin's Creed Valhalla Standard Edition - P...
# 1   Marvel's Spider-Man: Miles Morales Ultimate La...
# 2   Call of Duty: Black Ops Cold War Standard Edit...
# 3   Marvel's Spider-Man: Miles Morales Standard La...
# 4   Cyberpunk 2077 Standard Edition - PlayStation ...
# 6                  Watch Dogs: Legion - PlayStation 5
# 7        Madden NFL 21 - PlayStation 4, PlayStation 5
# 8    Madden NFL 21 Next Level Edition - PlayStation 5
# 9           NBA 2K21 Standard Edition - PlayStation 5
# 10             Godfall Deluxe Edition - PlayStation 5
# 11     Demon's Souls Standard Edition - PlayStation 5
# 12  Immortals Fenyx Rising Standard Edition - Play...
# 13           Godfall Ascended Edition - PlayStation 5
# 14                            Godfall - PlayStation 5
# 15  Mortal Kombat 11: Ultimate Edition - PlayStati...
# 19  Sackboy: A Big Adventure Standard - PlayStation 5
# ...

# %%
df['Game Release Date'] = df['Game Release Date'].str.strip('Release Date:')
# Out:
# <ipython-input-94-088f429857b0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Game Release Date'] = df['Game Release Date'].str.strip('Release Date:')

# %%
df['Game Publisher'] = df['Game Publisher'].str.replace('Publisher: ', '')
# Out:
# <ipython-input-95-dbbff5cae3d6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Game Publisher'] = df['Game Publisher'].str.replace('Publisher: ', '')

# %%
df
# Out:
#                                            Game Title  \
# 0   Assassin's Creed Valhalla Standard Edition - P...
# 1   Marvel's Spider-Man: Miles Morales Ultimate La...
# 2   Call of Duty: Black Ops Cold War Standard Edit...
# 3   Marvel's Spider-Man: Miles Morales Standard La...
# 4   Cyberpunk 2077 Standard Edition - PlayStation ...
# 6                  Watch Dogs: Legion - PlayStation 5
# 7        Madden NFL 21 - PlayStation 4, PlayStation 5
# 8    Madden NFL 21 Next Level Edition - PlayStation 5
# 9           NBA 2K21 Standard Edition - PlayStation 5
# 10             Godfall Deluxe Edition - PlayStation 5
# 11     Demon's Souls Standard Edition - PlayStation 5
# 12  Immortals Fenyx Rising Standard Edition - Play...
# 13           Godfall Ascended Edition - PlayStation 5
# 14                            Godfall - PlayStation 5
# 15  Mortal Kombat 11: Ultimate Edition - PlayStati...
# 19  Sackboy: A Big Adventure Standard - PlayStation 5
# ...

# %%
x = df[['Game Release Date', 'Review']].values
y = df['Price'].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size = 0.3, random_state = 48)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()
model.add(Dense(4, activation = 'relu'))

# %%
model.compile()

# %%
model.fit()
